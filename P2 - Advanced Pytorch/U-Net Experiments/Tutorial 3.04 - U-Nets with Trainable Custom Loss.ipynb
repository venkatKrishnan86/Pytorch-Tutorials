# %% [markdown]
# # Importing Packages

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from torchsummary import summary
from torchmetrics import JaccardIndex

import time
import copy
import os

# %%
torch.manual_seed(10)

# %%
data_dir = '../../../../IIT/IIT Sem 7/IE 643/Challenge_Dataset/Images'
mask_dir = '../../../../IIT/IIT Sem 7/IE 643/Challenge_Dataset/Masks'

# %%
data_transforms = {
    'Train': transforms.Compose([
        transforms.Resize((128,128)),
        transforms.ColorJitter(),
        # transforms.Grayscale(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ]),
    'Validation': transforms.Compose([
        transforms.Resize((128,128)),
        # transforms.Grayscale(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])
}
mask_transforms = {
    'Train': transforms.Compose([
        transforms.Resize((128,128)),
        transforms.Grayscale(),
        transforms.ToTensor()
    ]),
    'Validation': transforms.Compose([
        transforms.Resize((128,128)),
        transforms.Grayscale(),
        transforms.ToTensor()
    ])
}

# %% [markdown]
# ## PyTorch Custom Dataset

# %%
class ImageMaskDataset(Dataset):
    def __init__(self, data_dir, mask_dir, train = True, transform = None, mask_transform = None) -> None:
        super(ImageMaskDataset, self).__init__()
        self.imgs = []
        self.transform = transform
        if train:
            for file1 in os.scandir(data_dir+'/Train'):
                file2 = mask_dir+'/Train/'+file1.name[:-3]+'png'
                if self.transform is not None:
                    self.imgs.append((self.transform(Image.open(file1.path).convert('RGB')),mask_transform(Image.open(file2))))
                else:
                    self.imgs.append((Image.open(file1.path).convert('RGB'),Image.open(file2)))
        else:
            for file1 in os.scandir(data_dir+'/Validation'):
                file2 = mask_dir+'/Validation/'+file1.name[:-3]+'png'
                if self.transform is not None:
                    self.imgs.append((self.transform(Image.open(file1.path).convert('RGB')),mask_transform(Image.open(file2))))
                else:
                    self.imgs.append((Image.open(file1.path).convert('RGB'),Image.open(file2)))
                    # if self.imgs[-1][0].shape[0] == 1:
                    #     self.imgs[-1] = (self.imgs[-1][0].repeat(3,1,1), self.imgs[-1][1])
    
    def __len__(self):
        return len(self.imgs)
    
    def __getitem__(self, index):
        return self.imgs[index]

# %%
train_data = ImageMaskDataset(data_dir, mask_dir, train = True, transform=data_transforms['Train'], mask_transform=mask_transforms['Train'])
val_data = ImageMaskDataset(data_dir, mask_dir, train = False, transform=data_transforms['Validation'], mask_transform=mask_transforms['Validation'])

# %%
train_loader = DataLoader(
    train_data,
    batch_size = 64,
    shuffle = True,
)
val_loader = DataLoader(
    val_data,
    batch_size = 64,
    shuffle = True,
)

# %% [markdown]
# ## Image plot

# %%
def image_show(image, mask, pred = None):
    image = image*0.5 + 0.5
    mask = mask*0.5 + 0.5
    plt.figure(figsize=(20,10))
    if pred is not None:
        plt.subplot(1,3,1)
        plt.title('Image')
        plt.imshow(image.numpy().transpose((1,2,0)), cmap='gray')
        plt.subplot(1,3,2)
        plt.title('True Mask')
        plt.imshow(mask.numpy().transpose((1,2,0)), cmap='gray')
        plt.subplot(1,3,3)
        plt.title('Predicted Mask')
        plt.imshow(pred.detach().numpy().transpose((1,2,0)), cmap='gray')
    else:
        plt.subplot(1,3,1)
        plt.title('Image')
        plt.imshow(image.numpy().transpose((1,2,0)), cmap='gray')
        plt.subplot(1,3,2)
        plt.title('Mask')
        plt.imshow(mask.numpy().transpose((1,2,0)), cmap='gray')

# %%
dataiter = iter(train_loader)
image, mask = next(dataiter)
index = 0
image_show(image[index], mask[index])

# %%
device = torch.device('mps' if torch.backends.mps.is_available() else 'cpu') # mps: Metal Performance Shaders - For Apple M1 GPU
device
# Out:
# device(type='mps')

# %% [markdown]
# # U-Net

# %%
class UNet(nn.Module):
    def __init__(self) -> None:
        super(UNet, self).__init__()
        # ENCODER
        self.conv11 = nn.Conv2d(3, 8, 7, 1, 'same') # 200, 200, 3 --> 200, 200, 8
        self.norm11 = nn.BatchNorm2d(8)
        self.conv12 = nn.Conv2d(8, 32, 5, 1, 'same') # 200, 200, 8 --> 200, 200, 32
        self.norm12 = nn.BatchNorm2d(32)
        self.conv13 = nn.Conv2d(32, 64, 3, 1, 'same') # 200, 200, 32 --> 200, 200, 64
        self.norm13 = nn.BatchNorm2d(64)

        self.maxpool1 = nn.MaxPool2d(2,2) # 100, 100, 64

        self.conv21 = nn.Conv2d(64, 128, 7, 1, 'same') # 100, 100, 64 --> 100, 100, 128
        self.norm21 = nn.BatchNorm2d(128)
        self.conv22 = nn.Conv2d(128, 128, 5, 1, 'same') # 100, 100, 128 --> 100, 100, 128
        self.norm22 = nn.BatchNorm2d(128)
        self.conv23 = nn.Conv2d(128, 128, 3, 1, 'same') # 100, 100, 128 --> 100, 100, 128
        self.norm23 = nn.BatchNorm2d(128)

        self.maxpool2 = nn.MaxPool2d(2,2) # 50, 50, 128

        self.conv31 = nn.Conv2d(128, 256, 5, 1, 'same') # 50, 50, 128 --> 50, 50, 256
        self.norm31 = nn.BatchNorm2d(256)
        self.conv32 = nn.Conv2d(256, 256, 5, 1, 'same') # 50, 50, 256 --> 50, 50, 256
        self.norm32 = nn.BatchNorm2d(256)
        self.conv33 = nn.Conv2d(256, 256, 3, 1, 'same') # 50, 50, 256 --> 50, 50, 256
        self.norm33 = nn.BatchNorm2d(256)

        self.maxpool3 = nn.MaxPool2d(2,2) # 25, 25, 128

        self.conv41 = nn.Conv2d(256, 512, 3, 1, 1) # 25, 25, 256 --> 25, 25, 512
        self.norm41 = nn.BatchNorm2d(512)
        self.conv42 = nn.Conv2d(512, 512, 3, 1, 1) # 25, 25, 256 --> 25, 25, 512
        self.norm42 = nn.BatchNorm2d(512)
        self.conv43 = nn.Conv2d(512, 512, 3, 1, 1) # 25, 25, 256 --> 25, 25, 512
        self.norm43 = nn.BatchNorm2d(512)

        # DECODER
        self.convT1 = nn.ConvTranspose2d(512, 256, 2, 2)

        self.conv51 = nn.Conv2d(512, 512, 3, 1, 'same')
        self.norm51 = nn.BatchNorm2d(512)
        self.conv52 = nn.Conv2d(512, 512, 3, 1, 'same')
        self.norm52 = nn.BatchNorm2d(512)
        self.conv53 = nn.Conv2d(512, 512, 5, 1, 'same')
        self.norm53 = nn.BatchNorm2d(512)

        self.convT2 = nn.ConvTranspose2d(512, 128, 2, 2)

        self.conv61 = nn.Conv2d(256, 256, 3, 1, 'same')
        self.norm61 = nn.BatchNorm2d(256)
        self.conv62 = nn.Conv2d(256, 256, 5, 1, 'same')
        self.norm62 = nn.BatchNorm2d(256)
        self.conv63 = nn.Conv2d(256, 256, 5, 1, 'same')
        self.norm63 = nn.BatchNorm2d(256)

        self.convT3 = nn.ConvTranspose2d(256, 64, 2, 2)

        self.conv71 = nn.Conv2d(128, 64, 3, 1, 'same')
        self.norm71 = nn.BatchNorm2d(64)
        self.conv72 = nn.Conv2d(64, 16, 5, 1, 'same')
        self.norm72 = nn.BatchNorm2d(16)
        self.conv73 = nn.Conv2d(16, 1, 7, 1, 'same')
        self.norm73 = nn.BatchNorm2d(1)

    def forward(self, x):
        # ENCODER
        x = torch.relu(self.norm11(self.conv11(x)))
        x = torch.relu(self.norm12(self.conv12(x)))
        x_temp1 = torch.relu(self.norm13(self.conv13(x)))

        x = self.maxpool1(x_temp1)

        x = torch.relu(self.norm21(self.conv21(x)))
        x = torch.relu(self.norm22(self.conv22(x)))
        x_temp2 = torch.relu(self.norm23(self.conv23(x)))

        x = self.maxpool2(x_temp2)

        x = torch.relu(self.norm31(self.conv31(x)))
        x = torch.relu(self.norm32(self.conv32(x)))
        x_temp3 = torch.relu(self.norm33(self.conv33(x)))

        x = self.maxpool3(x_temp3)

        x = torch.relu(self.norm41(self.conv41(x)))
        x = torch.relu(self.norm42(self.conv42(x)))
        x = torch.relu(self.norm43(self.conv43(x)))

        # DECODER
        x = self.convT1(x)

        x = torch.cat((x,x_temp3), 1)

        x = torch.relu(self.norm51(self.conv51(x)))
        x = torch.relu(self.norm52(self.conv52(x)))
        x = torch.relu(self.norm53(self.conv53(x)))

        x = self.convT2(x)

        x = torch.cat((x,x_temp2), 1)

        x = torch.relu(self.norm61(self.conv61(x)))
        x = torch.relu(self.norm62(self.conv62(x)))
        x = torch.relu(self.norm63(self.conv63(x)))

        x = self.convT3(x)   

        x = torch.cat((x,x_temp1), 1)

        x = torch.relu(self.norm71(self.conv71(x)))
        x = torch.relu(self.norm72(self.conv72(x)))
        x = torch.sigmoid(self.norm73(self.conv73(x)))

        return x

# %%
unet = UNet().to(device)

# %%
summary(copy.deepcopy(unet).to('cpu'), (3, 128,128))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 8, 128, 128]           1,184
#        BatchNorm2d-2          [-1, 8, 128, 128]              16
#             Conv2d-3         [-1, 32, 128, 128]           6,432
#        BatchNorm2d-4         [-1, 32, 128, 128]              64
#             Conv2d-5         [-1, 64, 128, 128]          18,496
#        BatchNorm2d-6         [-1, 64, 128, 128]             128
#          MaxPool2d-7           [-1, 64, 64, 64]               0
#             Conv2d-8          [-1, 128, 64, 64]         401,536
#        BatchNorm2d-9          [-1, 128, 64, 64]             256
#            Conv2d-10          [-1, 128, 64, 64]         409,728
#       BatchNorm2d-11          [-1, 128, 64, 64]             256
#            Conv2d-12          [-1, 128, 64, 64]         147,584
#       BatchNorm2d-13          [-1, 128, 64, 64]             256
#         MaxPool2d-14          [-1, 128, 32, 32]               0
#            Conv2d-15          [-1, 256, 32, 32]         819,456
#       BatchNorm2d-16          [-1, 256, 32, 32]             512
#            Conv2d-17          [-1, 256, 32, 32]       1,638,656
#       BatchNorm2d-18          [-1, 256, 32, 32]             512
#            Conv2d-19          [-1, 256, 32, 32]         590,080
#       BatchNorm2d-20          [-1, 256, 32, 32]             512
#         MaxPool2d-21          [-1, 256, 16, 16]               0
#            Conv2d-22          [-1, 512, 16, 16]       1,180,160
#       BatchNorm2d-23          [-1, 512, 16, 16]           1,024
#            Conv2d-24          [-1, 512, 16, 16]       2,359,808
#       BatchNorm2d-25          [-1, 512, 16, 16]           1,024
#            Conv2d-26          [-1, 512, 16, 16]       2,359,808
#       BatchNorm2d-27          [-1, 512, 16, 16]           1,024
#   ConvTranspose2d-28          [-1, 256, 32, 32]         524,544
#            Conv2d-29          [-1, 512, 32, 32]       2,359,808
#       BatchNorm2d-30          [-1, 512, 32, 32]           1,024
#            Conv2d-31          [-1, 512, 32, 32]       2,359,808
#       BatchNorm2d-32          [-1, 512, 32, 32]           1,024
#            Conv2d-33          [-1, 512, 32, 32]       6,554,112
#       BatchNorm2d-34          [-1, 512, 32, 32]           1,024
#   ConvTranspose2d-35          [-1, 128, 64, 64]         262,272
#            Conv2d-36          [-1, 256, 64, 64]         590,080
#       BatchNorm2d-37          [-1, 256, 64, 64]             512
#            Conv2d-38          [-1, 256, 64, 64]       1,638,656
#       BatchNorm2d-39          [-1, 256, 64, 64]             512
#            Conv2d-40          [-1, 256, 64, 64]       1,638,656
#       BatchNorm2d-41          [-1, 256, 64, 64]             512
#   ConvTranspose2d-42         [-1, 64, 128, 128]          65,600
#            Conv2d-43         [-1, 64, 128, 128]          73,792
#       BatchNorm2d-44         [-1, 64, 128, 128]             128
#            Conv2d-45         [-1, 16, 128, 128]          25,616
#       BatchNorm2d-46         [-1, 16, 128, 128]              32
#            Conv2d-47          [-1, 1, 128, 128]             785
#       BatchNorm2d-48          [-1, 1, 128, 128]               2
# ================================================================
# Total params: 26,037,011
# Trainable params: 26,037,011
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 177.75
# Params size (MB): 99.32
# Estimated Total Size (MB): 277.26
# ----------------------------------------------------------------

# %% [markdown]
# # Loss and Optimizer

# %%
criterion1 = nn.BCELoss()
criterion2 = nn.MSELoss()
w1 = torch.rand(1, requires_grad=True, device=device).to(device)

optimizer = torch.optim.Adam(unet.parameters(), lr=5e-1)
optimizer2 = torch.optim.Adam([w1], lr = 1e-2)

scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size = 1, gamma=0.5)

# %%
num_epochs = 20
batches = len(train_loader)
losses = []

# %%
tic = time.time()
for epoch in range(num_epochs):
    print(f'Epoch {epoch+1}/{num_epochs} (LR: {scheduler.get_last_lr()[0]:.5f})')
    for i, (images,masks) in enumerate(train_loader):
        images = images.to(device)
        masks = torch.round(masks.to(device))

        preds = unet.forward(images)
        loss = w1*criterion1(preds, masks) + (1-w1)*criterion2(preds, masks)

        optimizer.zero_grad()
        optimizer2.zero_grad()
        loss.backward()
        optimizer.step()
        optimizer2.step()
        with torch.no_grad():
            w1.clamp_(0, 1) # Constrained Optimization

        print(f'Step {i+1}/{batches}; Loss = {loss.item():.4f}')
        losses.append(loss.item())
    scheduler.step()
print('Finished Training!')
print(f'Time Taken = {(time.time() - tic)//60:.0f}m {(time.time() - tic)%60:.0f}s')
# Out:
# Epoch 1/20 (LR: 0.50000)
# Step 1/16; Loss = 0.4334
# Step 2/16; Loss = 0.2944
# Step 3/16; Loss = 0.2365
# Step 4/16; Loss = 0.2154
# Step 5/16; Loss = 0.2194
# Step 6/16; Loss = 0.2162
# Step 7/16; Loss = 0.2246
# Step 8/16; Loss = 0.1889
# Step 9/16; Loss = 0.1932
# Step 10/16; Loss = 0.1830
# Step 11/16; Loss = 0.2213
# Step 12/16; Loss = 0.1802
# Step 13/16; Loss = 0.1692
# Step 14/16; Loss = 0.1624
# Step 15/16; Loss = 0.1661
# Step 16/16; Loss = 0.1644
# Epoch 2/20 (LR: 0.25000)
# Step 1/16; Loss = 0.1654
# Step 2/16; Loss = 0.1611
# Step 3/16; Loss = 0.1485
# Step 4/16; Loss = 0.1547
# Step 5/16; Loss = 0.1400
# Step 6/16; Loss = 0.1485
# Step 7/16; Loss = 0.1394
# Step 8/16; Loss = 0.1468
# Step 9/16; Loss = 0.1233
# Step 10/16; Loss = 0.1363
# Step 11/16; Loss = 0.1299
# Step 12/16; Loss = 0.1157
# Step 13/16; Loss = 0.1089
# Step 14/16; Loss = 0.1253
# Step 15/16; Loss = 0.1062
# Step 16/16; Loss = 0.1082
# Epoch 3/20 (LR: 0.12500)
# Step 1/16; Loss = 0.1108
# Step 2/16; Loss = 0.1127
# Step 3/16; Loss = 0.1175
# Step 4/16; Loss = 0.1161
# Step 5/16; Loss = 0.1163
# Step 6/16; Loss = 0.1008
# Step 7/16; Loss = 0.1088
# Step 8/16; Loss = 0.1189
# Step 9/16; Loss = 0.1076
# Step 10/16; Loss = 0.1105
# Step 11/16; Loss = 0.0963
# Step 12/16; Loss = 0.1069
# Step 13/16; Loss = 0.1081
# Step 14/16; Loss = 0.1225
# Step 15/16; Loss = 0.1167
# Step 16/16; Loss = 0.1128
# Epoch 4/20 (LR: 0.06250)
# Step 1/16; Loss = 0.0937
# Step 2/16; Loss = 0.1097
# Step 3/16; Loss = 0.0962
# Step 4/16; Loss = 0.1076
# Step 5/16; Loss = 0.1053
# Step 6/16; Loss = 0.1234
# Step 7/16; Loss = 0.1204
# Step 8/16; Loss = 0.1058
# Step 9/16; Loss = 0.1007
# Step 10/16; Loss = 0.1262
# Step 11/16; Loss = 0.1178
# Step 12/16; Loss = 0.1168
# Step 13/16; Loss = 0.1056
# Step 14/16; Loss = 0.1122
# Step 15/16; Loss = 0.1174
# Step 16/16; Loss = 0.0991
# Epoch 5/20 (LR: 0.03125)
# Step 1/16; Loss = 0.1256
# Step 2/16; Loss = 0.1067
# Step 3/16; Loss = 0.1089
# Step 4/16; Loss = 0.1145
# Step 5/16; Loss = 0.1185
# Step 6/16; Loss = 0.1110
# Step 7/16; Loss = 0.1000
# Step 8/16; Loss = 0.0986
# Step 9/16; Loss = 0.1107
# Step 10/16; Loss = 0.1154
# Step 11/16; Loss = 0.1030
# Step 12/16; Loss = 0.1074
# Step 13/16; Loss = 0.1088
# Step 14/16; Loss = 0.1005
# Step 15/16; Loss = 0.1068
# Step 16/16; Loss = 0.1153
# Epoch 6/20 (LR: 0.01562)
# Step 1/16; Loss = 0.1119
# Step 2/16; Loss = 0.0970
# Step 3/16; Loss = 0.1198
# Step 4/16; Loss = 0.1048
# Step 5/16; Loss = 0.1064
# Step 6/16; Loss = 0.1010
# Step 7/16; Loss = 0.1182
# Step 8/16; Loss = 0.1126
# Step 9/16; Loss = 0.1087
# Step 10/16; Loss = 0.1137
# Step 11/16; Loss = 0.1100
# Step 12/16; Loss = 0.1113
# Step 13/16; Loss = 0.1029
# Step 14/16; Loss = 0.1171
# Step 15/16; Loss = 0.0963
# Step 16/16; Loss = 0.1165
# Epoch 7/20 (LR: 0.00781)
# Step 1/16; Loss = 0.1076
# Step 2/16; Loss = 0.1016
# Step 3/16; Loss = 0.1210
# Step 4/16; Loss = 0.1166
# Step 5/16; Loss = 0.1062
# Step 6/16; Loss = 0.1047
# Step 7/16; Loss = 0.1107
# Step 8/16; Loss = 0.1051
# Step 9/16; Loss = 0.1169
# Step 10/16; Loss = 0.1078
# Step 11/16; Loss = 0.1141
# Step 12/16; Loss = 0.1102
# Step 13/16; Loss = 0.0989
# Step 14/16; Loss = 0.1159
# Step 15/16; Loss = 0.0958
# Step 16/16; Loss = 0.1112
# Epoch 8/20 (LR: 0.00391)
# Step 1/16; Loss = 0.0970
# Step 2/16; Loss = 0.1218
# Step 3/16; Loss = 0.1073
# Step 4/16; Loss = 0.1145
# Step 5/16; Loss = 0.1275
# Step 6/16; Loss = 0.1081
# Step 7/16; Loss = 0.1100
# Step 8/16; Loss = 0.1116
# Step 9/16; Loss = 0.1003
# Step 10/16; Loss = 0.0977
# Step 11/16; Loss = 0.1069
# Step 12/16; Loss = 0.1231
# Step 13/16; Loss = 0.1053
# Step 14/16; Loss = 0.0987
# Step 15/16; Loss = 0.1040
# Step 16/16; Loss = 0.1050
# Epoch 9/20 (LR: 0.00195)
# Step 1/16; Loss = 0.1090
# Step 2/16; Loss = 0.1067
# Step 3/16; Loss = 0.1180
# Step 4/16; Loss = 0.1064
# Step 5/16; Loss = 0.1077
# Step 6/16; Loss = 0.1061
# Step 7/16; Loss = 0.1006
# Step 8/16; Loss = 0.1048
# Step 9/16; Loss = 0.1160
# Step 10/16; Loss = 0.1194
# Step 11/16; Loss = 0.1113
# Step 12/16; Loss = 0.1102
# Step 13/16; Loss = 0.1144
# Step 14/16; Loss = 0.0967
# Step 15/16; Loss = 0.1130
# Step 16/16; Loss = 0.0934
# Epoch 10/20 (LR: 0.00098)
# Step 1/16; Loss = 0.1171
# Step 2/16; Loss = 0.1197
# Step 3/16; Loss = 0.1153
# Step 4/16; Loss = 0.1054
# Step 5/16; Loss = 0.1133
# Step 6/16; Loss = 0.1052
# Step 7/16; Loss = 0.1062
# Step 8/16; Loss = 0.1016
# Step 9/16; Loss = 0.1042
# Step 10/16; Loss = 0.1070
# Step 11/16; Loss = 0.1139
# Step 12/16; Loss = 0.1061
# Step 13/16; Loss = 0.1006
# Step 14/16; Loss = 0.1160
# Step 15/16; Loss = 0.1012
# Step 16/16; Loss = 0.0992
# Epoch 11/20 (LR: 0.00049)
# Step 1/16; Loss = 0.1153
# Step 2/16; Loss = 0.1175
# Step 3/16; Loss = 0.1254
# Step 4/16; Loss = 0.1009
# Step 5/16; Loss = 0.1076
# Step 6/16; Loss = 0.1044
# Step 7/16; Loss = 0.1103
# Step 8/16; Loss = 0.1136
# Step 9/16; Loss = 0.0928
# Step 10/16; Loss = 0.1139
# Step 11/16; Loss = 0.0927
# Step 12/16; Loss = 0.1176
# Step 13/16; Loss = 0.0981
# Step 14/16; Loss = 0.1041
# Step 15/16; Loss = 0.1095
# Step 16/16; Loss = 0.1161
# Epoch 12/20 (LR: 0.00024)
# Step 1/16; Loss = 0.1027
# Step 2/16; Loss = 0.1163
# Step 3/16; Loss = 0.1097
# Step 4/16; Loss = 0.1103
# Step 5/16; Loss = 0.1124
# Step 6/16; Loss = 0.1131
# Step 7/16; Loss = 0.1113
# Step 8/16; Loss = 0.1105
# Step 9/16; Loss = 0.1140
# Step 10/16; Loss = 0.0999
# Step 11/16; Loss = 0.1026
# Step 12/16; Loss = 0.1069
# Step 13/16; Loss = 0.1094
# Step 14/16; Loss = 0.1006
# Step 15/16; Loss = 0.1083
# Step 16/16; Loss = 0.1108
# Epoch 13/20 (LR: 0.00012)
# Step 1/16; Loss = 0.1027
# Step 2/16; Loss = 0.0988
# Step 3/16; Loss = 0.1069
# Step 4/16; Loss = 0.1102
# Step 5/16; Loss = 0.1103
# Step 6/16; Loss = 0.1095
# Step 7/16; Loss = 0.1032
# Step 8/16; Loss = 0.1102
# Step 9/16; Loss = 0.1071
# Step 10/16; Loss = 0.1057
# Step 11/16; Loss = 0.1165
# Step 12/16; Loss = 0.1123
# Step 13/16; Loss = 0.1004
# Step 14/16; Loss = 0.1075
# Step 15/16; Loss = 0.1172
# Step 16/16; Loss = 0.1237
# Epoch 14/20 (LR: 0.00006)
# Step 1/16; Loss = 0.1001
# Step 2/16; Loss = 0.1132
# Step 3/16; Loss = 0.1000
# Step 4/16; Loss = 0.1090
# Step 5/16; Loss = 0.1044
# Step 6/16; Loss = 0.1093
# Step 7/16; Loss = 0.1074
# Step 8/16; Loss = 0.1081
# Step 9/16; Loss = 0.1006
# Step 10/16; Loss = 0.1083
# Step 11/16; Loss = 0.1171
# Step 12/16; Loss = 0.1252
# Step 13/16; Loss = 0.0937
# Step 14/16; Loss = 0.1198
# Step 15/16; Loss = 0.1053
# Step 16/16; Loss = 0.1205
# Epoch 15/20 (LR: 0.00003)
# Step 1/16; Loss = 0.1070
# Step 2/16; Loss = 0.1152
# Step 3/16; Loss = 0.1130
# Step 4/16; Loss = 0.1248
# Step 5/16; Loss = 0.0978
# Step 6/16; Loss = 0.1221
# Step 7/16; Loss = 0.1098
# Step 8/16; Loss = 0.0963
# Step 9/16; Loss = 0.0965
# Step 10/16; Loss = 0.1073
# Step 11/16; Loss = 0.0948
# Step 12/16; Loss = 0.1182
# Step 13/16; Loss = 0.0918
# Step 14/16; Loss = 0.1238
# Step 15/16; Loss = 0.1123
# Step 16/16; Loss = 0.1068
# Epoch 16/20 (LR: 0.00002)
# Step 1/16; Loss = 0.1130
# Step 2/16; Loss = 0.1155
# Step 3/16; Loss = 0.1092
# Step 4/16; Loss = 0.1026
# Step 5/16; Loss = 0.1302
# Step 6/16; Loss = 0.1030
# Step 7/16; Loss = 0.0976
# Step 8/16; Loss = 0.1054
# Step 9/16; Loss = 0.1107
# Step 10/16; Loss = 0.1325
# Step 11/16; Loss = 0.0953
# Step 12/16; Loss = 0.0971
# Step 13/16; Loss = 0.0997
# Step 14/16; Loss = 0.1083
# Step 15/16; Loss = 0.1068
# Step 16/16; Loss = 0.1146
# Epoch 17/20 (LR: 0.00001)
# Step 1/16; Loss = 0.1095
# Step 2/16; Loss = 0.1329
# Step 3/16; Loss = 0.1054
# Step 4/16; Loss = 0.1068
# Step 5/16; Loss = 0.1156
# Step 6/16; Loss = 0.0943
# Step 7/16; Loss = 0.1105
# Step 8/16; Loss = 0.1162
# Step 9/16; Loss = 0.1273
# Step 10/16; Loss = 0.1103
# Step 11/16; Loss = 0.1052
# Step 12/16; Loss = 0.1015
# Step 13/16; Loss = 0.1053
# Step 14/16; Loss = 0.0850
# Step 15/16; Loss = 0.1152
# Step 16/16; Loss = 0.0909
# Epoch 18/20 (LR: 0.00000)
# Step 1/16; Loss = 0.1148
# Step 2/16; Loss = 0.1004
# Step 3/16; Loss = 0.1234
# Step 4/16; Loss = 0.1071
# Step 5/16; Loss = 0.1042
# Step 6/16; Loss = 0.1125
# Step 7/16; Loss = 0.1159
# Step 8/16; Loss = 0.1129
# Step 9/16; Loss = 0.1073
# Step 10/16; Loss = 0.1106
# Step 11/16; Loss = 0.0989
# Step 12/16; Loss = 0.1049
# Step 13/16; Loss = 0.1102
# Step 14/16; Loss = 0.1139
# Step 15/16; Loss = 0.1030
# Step 16/16; Loss = 0.0924
# Epoch 19/20 (LR: 0.00000)
# Step 1/16; Loss = 0.1095
# Step 2/16; Loss = 0.1052
# Step 3/16; Loss = 0.1065
# Step 4/16; Loss = 0.0967
# Step 5/16; Loss = 0.1225
# Step 6/16; Loss = 0.1104
# Step 7/16; Loss = 0.1203
# Step 8/16; Loss = 0.1097
# Step 9/16; Loss = 0.1081
# Step 10/16; Loss = 0.1142
# Step 11/16; Loss = 0.1038
# Step 12/16; Loss = 0.1017
# Step 13/16; Loss = 0.1084
# Step 14/16; Loss = 0.1091
# Step 15/16; Loss = 0.0956
# Step 16/16; Loss = 0.1204
# Epoch 20/20 (LR: 0.00000)
# Step 1/16; Loss = 0.0978
# Step 2/16; Loss = 0.1097
# Step 3/16; Loss = 0.1051
# Step 4/16; Loss = 0.1105
# Step 5/16; Loss = 0.1008
# Step 6/16; Loss = 0.1026
# Step 7/16; Loss = 0.1070
# Step 8/16; Loss = 0.1108
# Step 9/16; Loss = 0.1105
# Step 10/16; Loss = 0.1064
# Step 11/16; Loss = 0.1286
# Step 12/16; Loss = 0.1172
# Step 13/16; Loss = 0.1146
# Step 14/16; Loss = 0.1096
# Step 15/16; Loss = 0.1021
# Step 16/16; Loss = 0.1006
# Finished Training!
# Time Taken = 14m 43s

# %%
plt.figure(figsize=(20,10))
plt.plot(losses)
plt.title('Loss')
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
torch.save(unet, '../models/U-Net_Image_Segmentation_IE643_Trainable_Custom_Loss.pt')

# %%
unet = torch.load('../models/U-Net_Image_Segmentation_IE643_Trainable_Custom_Loss.pt')
unet.eval()
# Out:
# UNet(
#   (conv11): Conv2d(3, 8, kernel_size=(7, 7), stride=(1, 1), padding=same)
#   (norm11): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv12): Conv2d(8, 32, kernel_size=(5, 5), stride=(1, 1), padding=same)
#   (norm12): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv13): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm13): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv21): Conv2d(64, 128, kernel_size=(7, 7), stride=(1, 1), padding=same)
#   (norm21): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv22): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=same)
#   (norm22): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv23): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm23): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv31): Conv2d(128, 256, kernel_size=(5, 5), stride=(1, 1), padding=same)
#   (norm31): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv32): Conv2d(256, 256, kernel_size=(5, 5), stride=(1, 1), padding=same)
#   (norm32): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv33): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm33): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv41): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv42): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm42): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv43): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm43): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (convT1): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2))
#   (conv51): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm51): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv52): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm52): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv53): Conv2d(512, 512, kernel_size=(5, 5), stride=(1, 1), padding=same)
#   (norm53): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (convT2): ConvTranspose2d(512, 128, kernel_size=(2, 2), stride=(2, 2))
#   (conv61): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm61): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv62): Conv2d(256, 256, kernel_size=(5, 5), stride=(1, 1), padding=same)
#   (norm62): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv63): Conv2d(256, 256, kernel_size=(5, 5), stride=(1, 1), padding=same)
#   (norm63): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (convT3): ConvTranspose2d(256, 64, kernel_size=(2, 2), stride=(2, 2))
#   (conv71): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm71): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv72): Conv2d(64, 16, kernel_size=(5, 5), stride=(1, 1), padding=same)
#   (norm72): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv73): Conv2d(16, 1, kernel_size=(7, 7), stride=(1, 1), padding=same)
#   (norm73): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
image, mask = next(iter(train_loader))
image = image.to(device)
mask = mask.to('cpu')
pred = unet(image).cpu()
pred1 = torch.round(pred)
image = image.to('cpu')
image_show(image[0], mask[0], pred1[0])

# %%
IoU = JaccardIndex(num_classes=2)
IoU(pred, torch.round(mask).type(torch.int16))
# Out:
# tensor(0.5397)

# %%
IoU = JaccardIndex(num_classes=2)
IoU_value = 0
for image, mask in train_loader:
    image = image.to(device)
    mask = mask.to('cpu')
    pred = unet(image).cpu()
    pred = torch.round(pred)
    IoU_value += IoU(pred, torch.round(mask).type(torch.int16)).item()
print(f'Intersection Over Union value = {IoU_value/len(train_loader)}')
# Out:
# Intersection Over Union value = 0.540095865726471

# %%
image, mask = next(iter(val_loader))
image = image.to(device)
mask = mask.to('cpu')
pred = unet(image).cpu()
pred1 = torch.round(pred)
image = image.to('cpu')
image_show(image[0], mask[0], pred1[0])

# %%
IoU = JaccardIndex(num_classes=2)
IoU(pred, torch.round(mask).type(torch.int16))
# Out:
# tensor(0.5184)

# %%
IoU = JaccardIndex(num_classes=2)
IoU_value = 0
for image, mask in val_loader:
    image = image.to(device)
    mask = mask.to('cpu')
    pred = unet(image).cpu()
    pred = torch.round(pred)
    IoU_value += IoU(pred, torch.round(mask).type(torch.int16)).item()
print(f'Intersection Over Union value = {IoU_value/len(val_loader)}')
# Out:
# Intersection Over Union value = 0.521561861038208
