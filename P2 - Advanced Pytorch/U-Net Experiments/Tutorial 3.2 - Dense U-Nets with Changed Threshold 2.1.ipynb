# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from torchsummary import summary

import time
import copy
import os

# %%
data_dir = '../../../../IIT/IIT Sem 7/IE 643/Challenge_Dataset/Images'
mask_dir = '../../../../IIT/IIT Sem 7/IE 643/Challenge_Dataset/Masks'

# %%
data_transforms = {
    'Train': transforms.Compose([
        transforms.Resize((128,128)),
        transforms.ColorJitter(),
        # transforms.Grayscale(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ]),
    'Train2': transforms.Compose([
        transforms.Resize((128,128)),
        transforms.RandomHorizontalFlip(p=1),
        # transforms.Grayscale(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ]),
    'Validation': transforms.Compose([
        transforms.Resize((128,128)),
        # transforms.Grayscale(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])
}
mask_transforms = {
    'Train': transforms.Compose([
        transforms.Resize((128,128)),
        transforms.Grayscale(),
        transforms.ToTensor()
    ]),
    'Train2': transforms.Compose([
        transforms.Resize((128,128)),
        transforms.RandomHorizontalFlip(p=1),
        transforms.Grayscale(),
        transforms.ToTensor(),
    ]),
    'Validation': transforms.Compose([
        transforms.Resize((128,128)),
        transforms.Grayscale(),
        transforms.ToTensor()
    ])
}

# %%
class ImageMaskDataset(Dataset):
    def __init__(self, data_dir, mask_dir, train = True, transform = None, transform2 = None, mask_transform = None, mask_transform2 = None) -> None:
        super(ImageMaskDataset, self).__init__()
        self.imgs = []
        self.transform = transform
        if train:
            for file1 in os.scandir(data_dir+'/Train'):
                file2 = mask_dir+'/Train/'+file1.name[:-3]+'png'
                if self.transform is not None:
                    self.imgs.append((self.transform(Image.open(file1.path).convert('RGB')),mask_transform(Image.open(file2))))
                    for i in range(len(transform2)):
                        self.imgs.append((transform2[i](Image.open(file1.path).convert('RGB')),mask_transform2[i](Image.open(file2))))
                else:
                    self.imgs.append((Image.open(file1.path).convert('RGB'),Image.open(file2)))
        else:
            for file1 in os.scandir(data_dir+'/Validation'):
                file2 = mask_dir+'/Validation/'+file1.name[:-3]+'png'
                if self.transform is not None:
                    self.imgs.append((self.transform(Image.open(file1.path).convert('RGB')),mask_transform(Image.open(file2))))
                else:
                    self.imgs.append((Image.open(file1.path).convert('RGB'),Image.open(file2)))
                    # if self.imgs[-1][0].shape[0] == 1:
                    #     self.imgs[-1] = (self.imgs[-1][0].repeat(3,1,1), self.imgs[-1][1])
    
    def __len__(self):
        return len(self.imgs)
    
    def __getitem__(self, index):
        return self.imgs[index]

# %%
train_data = ImageMaskDataset(data_dir, mask_dir, train = True, transform=data_transforms['Train'], transform2=[data_transforms['Train2']], mask_transform=mask_transforms['Train'], mask_transform2=[mask_transforms['Train2']])
val_data = ImageMaskDataset(data_dir, mask_dir, train = False, transform=data_transforms['Validation'], mask_transform=mask_transforms['Validation'])

# %%
train_loader = DataLoader(
    train_data,
    batch_size = 16,
    shuffle = True,
)
val_loader = DataLoader(
    val_data,
    batch_size = 16,
    shuffle = True,
)

# %%
def image_show(image, mask, pred = None):
    image = image*0.5 + 0.5
    mask = mask*0.5 + 0.5
    plt.figure(figsize=(20,10))
    if pred is not None:
        plt.subplot(1,3,1)
        plt.title('Image')
        plt.imshow(image.numpy().transpose((1,2,0)), cmap='gray')
        plt.subplot(1,3,2)
        plt.title('True Mask')
        plt.imshow(mask.numpy().transpose((1,2,0)), cmap='gray')
        plt.subplot(1,3,3)
        plt.title('Predicted Mask')
        plt.imshow(pred.detach().numpy().transpose((1,2,0)), cmap='gray')
    else:
        plt.subplot(1,3,1)
        plt.title('Image')
        plt.imshow(image.numpy().transpose((1,2,0)), cmap='gray')
        plt.subplot(1,3,2)
        plt.title('Mask')
        plt.imshow(mask.numpy().transpose((1,2,0)), cmap='gray')

# %%
dataiter = iter(train_loader)
image, mask = next(dataiter)
index = 0
image_show(image[index], mask[index])

# %%
device = torch.device('mps' if torch.backends.mps.is_available() else 'cpu')
device
# Out:
# device(type='mps')

# %%
class DenseBlock(nn.Sequential):
    def __init__(self, channels: int, output_channels: int) -> None:
        super(DenseBlock, self).__init__()
        self.conv1 = nn.Conv2d(channels+0*output_channels, output_channels, 9, 1, 'same')
        self.norm1 = nn.BatchNorm2d(output_channels)
        self.conv2 = nn.Conv2d(channels+1*output_channels, output_channels, 9, 1, 'same')
        self.norm2 = nn.BatchNorm2d(output_channels)
        self.conv3 = nn.Conv2d(channels+2*output_channels, output_channels, 7, 1, 'same')
        self.norm3 = nn.BatchNorm2d(output_channels)
        self.conv4 = nn.Conv2d(channels+3*output_channels, output_channels, 7, 1, 'same')
        self.norm4 = nn.BatchNorm2d(output_channels)
        self.conv5 = nn.Conv2d(channels+4*output_channels, output_channels, 5, 1, 'same')
        self.norm5 = nn.BatchNorm2d(output_channels)
        self.conv6 = nn.Conv2d(channels+5*output_channels, output_channels, 5, 1, 'same')
        self.norm6 = nn.BatchNorm2d(output_channels)
        self.conv7 = nn.Conv2d(channels+6*output_channels, output_channels, 3, 1, 'same')
        self.norm7 = nn.BatchNorm2d(output_channels)
        self.conv8 = nn.Conv2d(channels+7*output_channels, output_channels, 3, 1, 'same')
        self.norm8 = nn.BatchNorm2d(output_channels)
        self.convFinal = nn.Conv2d(channels+8*output_channels, channels, 1)
        self.normFinal = nn.BatchNorm2d(channels)
    
    def forward(self, x):
        temp = x
        x_temp = torch.relu(self.norm1(self.conv1(temp)))
        temp = torch.cat((temp, x_temp), 1)
        x_temp = torch.relu(self.norm2(self.conv2(temp)))
        temp = torch.cat((temp, x_temp), 1)
        x_temp = torch.relu(self.norm3(self.conv3(temp)))
        temp = torch.cat((temp, x_temp), 1)
        x_temp = torch.relu(self.norm4(self.conv4(temp)))
        temp = torch.cat((temp, x_temp), 1)
        x_temp = torch.relu(self.norm5(self.conv5(temp)))
        temp = torch.cat((temp, x_temp), 1)
        x_temp = torch.relu(self.norm6(self.conv6(temp)))
        temp = torch.cat((temp, x_temp), 1)
        x_temp = torch.relu(self.norm7(self.conv7(temp)))
        temp = torch.cat((temp, x_temp), 1)
        x_temp = torch.relu(self.norm8(self.conv8(temp)))
        temp = torch.cat((temp, x_temp), 1)
        x = torch.relu(self.normFinal(self.convFinal(temp)))
        return x

# %%
den = DenseBlock(512,64)
summary(den, (512,16,16))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 16, 16]       2,654,272
#        BatchNorm2d-2           [-1, 64, 16, 16]             128
#             Conv2d-3           [-1, 64, 16, 16]       2,986,048
#        BatchNorm2d-4           [-1, 64, 16, 16]             128
#             Conv2d-5           [-1, 64, 16, 16]       2,007,104
#        BatchNorm2d-6           [-1, 64, 16, 16]             128
#             Conv2d-7           [-1, 64, 16, 16]       2,207,808
#        BatchNorm2d-8           [-1, 64, 16, 16]             128
#             Conv2d-9           [-1, 64, 16, 16]       1,228,864
#       BatchNorm2d-10           [-1, 64, 16, 16]             128
#            Conv2d-11           [-1, 64, 16, 16]       1,331,264
#       BatchNorm2d-12           [-1, 64, 16, 16]             128
#            Conv2d-13           [-1, 64, 16, 16]         516,160
#       BatchNorm2d-14           [-1, 64, 16, 16]             128
#            Conv2d-15           [-1, 64, 16, 16]         553,024
#       BatchNorm2d-16           [-1, 64, 16, 16]             128
#            Conv2d-17          [-1, 512, 16, 16]         524,800
#       BatchNorm2d-18          [-1, 512, 16, 16]           1,024
# ================================================================
# Total params: 14,011,392
# Trainable params: 14,011,392
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.50
# Forward/backward pass size (MB): 4.00
# Params size (MB): 53.45
# Estimated Total Size (MB): 57.95
# ----------------------------------------------------------------

# %%
class UNet(nn.Module):
    def __init__(self) -> None:
        super(UNet, self).__init__()

        # ENCODER
        self.conv1 = nn.Conv2d(3, 64, 3, 1, 'same') # 128, 128, 3 --> 128, 128, 64
        self.norm1 = nn.BatchNorm2d(64)
        self.denseBlock1 = DenseBlock(64, 16).to(device)

        self.maxpool1 = nn.MaxPool2d(2,2) # 64, 64, 64

        self.conv2 = nn.Conv2d(64, 128, 3, 1, 'same') # 64, 64, 64 --> 64, 64, 128
        self.norm2 = nn.BatchNorm2d(128)
        self.denseBlock2 = DenseBlock(128, 32).to(device) # 64, 64, 128

        self.maxpool2 = nn.MaxPool2d(2,2) # 32, 32, 128

        self.conv3 = nn.Conv2d(128, 256, 3, 1, 'same') # 32, 32, 128 --> 32, 32, 256
        self.norm3 = nn.BatchNorm2d(256)
        self.denseBlock3 = DenseBlock(256, 64).to(device) # 32, 32, 256

        self.maxpool3 = nn.MaxPool2d(2,2) # 16, 16, 256

        self.conv4 = nn.Conv2d(256, 512, 3, 1, 1) # 16, 16, 256 --> 16, 16, 512
        self.norm4 = nn.BatchNorm2d(512)
        self.denseBlock4 = DenseBlock(512, 128).to(device) # 16, 16, 512

        self.maxpool4 = nn.MaxPool2d(2,2) # 8, 8, 512

        self.conv41 = nn.Conv2d(512, 1024, 3, 1, 1) # 8, 8, 1024 --> 8, 8, 1024
        self.norm41 = nn.BatchNorm2d(1024)
        self.denseBlock41 = DenseBlock(1024, 256).to(device) # 8, 8, 1024


        # DECODER
        self.convT0 = nn.ConvTranspose2d(1024, 512, 2, 2)

        self.denseBlock42 = DenseBlock(1024, 256).to(device)

        self.convT1 = nn.ConvTranspose2d(1024, 256, 2, 2)

        self.denseBlock5 = DenseBlock(512, 128).to(device)

        self.convT2 = nn.ConvTranspose2d(512, 128, 2, 2)

        self.denseBlock6 = DenseBlock(256, 64).to(device)

        self.convT3 = nn.ConvTranspose2d(256, 64, 2, 2)

        self.denseBlock7 = DenseBlock(128, 32).to(device)

        self.conv71 = nn.Conv2d(128, 64, 3, 1, 'same')
        self.norm71 = nn.BatchNorm2d(64)
        self.conv72 = nn.Conv2d(64, 16, 5, 1, 'same')
        self.norm72 = nn.BatchNorm2d(16)
        self.conv73 = nn.Conv2d(16, 1, 1, 1, 'same')
        self.norm73 = nn.BatchNorm2d(1)

    def forward(self, x):
        # ENCODER
        x = torch.relu(self.norm1(self.conv1(x)))
        x_temp1 = self.denseBlock1(x)

        x = self.maxpool1(x_temp1)

        x = torch.relu(self.norm2(self.conv2(x)))
        x_temp2 = self.denseBlock2(x)

        x = self.maxpool2(x_temp2)

        x = torch.relu(self.norm3(self.conv3(x)))
        x_temp3 = self.denseBlock3(x)

        x = self.maxpool3(x_temp3)

        x = torch.relu(self.norm4(self.conv4(x)))
        x_temp4 = self.denseBlock4(x)

        x = self.maxpool3(x_temp4)

        x = torch.relu(self.norm41(self.conv41(x)))
        x = self.denseBlock41(x)

        # DECODER
        x = self.convT0(x)

        x = torch.cat((x,x_temp4), 1)

        x = self.denseBlock42(x)

        x = self.convT1(x)

        x = torch.cat((x,x_temp3), 1)

        x = self.denseBlock5(x)

        x = self.convT2(x)

        x = torch.cat((x,x_temp2), 1)

        x = self.denseBlock6(x)

        x = self.convT3(x)   

        x = torch.cat((x,x_temp1), 1)

        x = self.denseBlock7(x)

        x = torch.relu(self.norm71(self.conv71(x)))
        x = torch.relu(self.norm72(self.conv72(x)))
        x = torch.sigmoid(self.norm73(self.conv73(x)))

        return x

# %%
unet = UNet().to(device)

# %%
summary(copy.deepcopy(unet).to('cpu'), (3, 128,128))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 128, 128]           1,792
#        BatchNorm2d-2         [-1, 64, 128, 128]             128
#             Conv2d-3         [-1, 16, 128, 128]          82,960
#        BatchNorm2d-4         [-1, 16, 128, 128]              32
#             Conv2d-5         [-1, 16, 128, 128]         103,696
#        BatchNorm2d-6         [-1, 16, 128, 128]              32
#             Conv2d-7         [-1, 16, 128, 128]          75,280
#        BatchNorm2d-8         [-1, 16, 128, 128]              32
#             Conv2d-9         [-1, 16, 128, 128]          87,824
#       BatchNorm2d-10         [-1, 16, 128, 128]              32
#            Conv2d-11         [-1, 16, 128, 128]          51,216
#       BatchNorm2d-12         [-1, 16, 128, 128]              32
#            Conv2d-13         [-1, 16, 128, 128]          57,616
#       BatchNorm2d-14         [-1, 16, 128, 128]              32
#            Conv2d-15         [-1, 16, 128, 128]          23,056
#       BatchNorm2d-16         [-1, 16, 128, 128]              32
#            Conv2d-17         [-1, 16, 128, 128]          25,360
#       BatchNorm2d-18         [-1, 16, 128, 128]              32
#            Conv2d-19         [-1, 64, 128, 128]          12,352
#       BatchNorm2d-20         [-1, 64, 128, 128]             128
#         MaxPool2d-21           [-1, 64, 64, 64]               0
#            Conv2d-22          [-1, 128, 64, 64]          73,856
#       BatchNorm2d-23          [-1, 128, 64, 64]             256
#            Conv2d-24           [-1, 32, 64, 64]         331,808
#       BatchNorm2d-25           [-1, 32, 64, 64]              64
#            Conv2d-26           [-1, 32, 64, 64]         414,752
#       BatchNorm2d-27           [-1, 32, 64, 64]              64
#            Conv2d-28           [-1, 32, 64, 64]         301,088
#       BatchNorm2d-29           [-1, 32, 64, 64]              64
#            Conv2d-30           [-1, 32, 64, 64]         351,264
#       BatchNorm2d-31           [-1, 32, 64, 64]              64
#            Conv2d-32           [-1, 32, 64, 64]         204,832
#       BatchNorm2d-33           [-1, 32, 64, 64]              64
#            Conv2d-34           [-1, 32, 64, 64]         230,432
#       BatchNorm2d-35           [-1, 32, 64, 64]              64
#            Conv2d-36           [-1, 32, 64, 64]          92,192
#       BatchNorm2d-37           [-1, 32, 64, 64]              64
#            Conv2d-38           [-1, 32, 64, 64]         101,408
#       BatchNorm2d-39           [-1, 32, 64, 64]              64
#            Conv2d-40          [-1, 128, 64, 64]          49,280
#       BatchNorm2d-41          [-1, 128, 64, 64]             256
#         MaxPool2d-42          [-1, 128, 32, 32]               0
#            Conv2d-43          [-1, 256, 32, 32]         295,168
#       BatchNorm2d-44          [-1, 256, 32, 32]             512
#            Conv2d-45           [-1, 64, 32, 32]       1,327,168
#       BatchNorm2d-46           [-1, 64, 32, 32]             128
#            Conv2d-47           [-1, 64, 32, 32]       1,658,944
#       BatchNorm2d-48           [-1, 64, 32, 32]             128
#            Conv2d-49           [-1, 64, 32, 32]       1,204,288
#       BatchNorm2d-50           [-1, 64, 32, 32]             128
#            Conv2d-51           [-1, 64, 32, 32]       1,404,992
#       BatchNorm2d-52           [-1, 64, 32, 32]             128
#            Conv2d-53           [-1, 64, 32, 32]         819,264
#       BatchNorm2d-54           [-1, 64, 32, 32]             128
#            Conv2d-55           [-1, 64, 32, 32]         921,664
#       BatchNorm2d-56           [-1, 64, 32, 32]             128
#            Conv2d-57           [-1, 64, 32, 32]         368,704
#       BatchNorm2d-58           [-1, 64, 32, 32]             128
#            Conv2d-59           [-1, 64, 32, 32]         405,568
#       BatchNorm2d-60           [-1, 64, 32, 32]             128
#            Conv2d-61          [-1, 256, 32, 32]         196,864
#       BatchNorm2d-62          [-1, 256, 32, 32]             512
#         MaxPool2d-63          [-1, 256, 16, 16]               0
#            Conv2d-64          [-1, 512, 16, 16]       1,180,160
#       BatchNorm2d-65          [-1, 512, 16, 16]           1,024
#            Conv2d-66          [-1, 128, 16, 16]       5,308,544
#       BatchNorm2d-67          [-1, 128, 16, 16]             256
#            Conv2d-68          [-1, 128, 16, 16]       6,635,648
#       BatchNorm2d-69          [-1, 128, 16, 16]             256
#            Conv2d-70          [-1, 128, 16, 16]       4,817,024
#       BatchNorm2d-71          [-1, 128, 16, 16]             256
#            Conv2d-72          [-1, 128, 16, 16]       5,619,840
#       BatchNorm2d-73          [-1, 128, 16, 16]             256
#            Conv2d-74          [-1, 128, 16, 16]       3,276,928
#       BatchNorm2d-75          [-1, 128, 16, 16]             256
#            Conv2d-76          [-1, 128, 16, 16]       3,686,528
#       BatchNorm2d-77          [-1, 128, 16, 16]             256
#            Conv2d-78          [-1, 128, 16, 16]       1,474,688
#       BatchNorm2d-79          [-1, 128, 16, 16]             256
#            Conv2d-80          [-1, 128, 16, 16]       1,622,144
#       BatchNorm2d-81          [-1, 128, 16, 16]             256
#            Conv2d-82          [-1, 512, 16, 16]         786,944
#       BatchNorm2d-83          [-1, 512, 16, 16]           1,024
#         MaxPool2d-84            [-1, 512, 8, 8]               0
#            Conv2d-85           [-1, 1024, 8, 8]       4,719,616
#       BatchNorm2d-86           [-1, 1024, 8, 8]           2,048
#            Conv2d-87            [-1, 256, 8, 8]      21,233,920
#       BatchNorm2d-88            [-1, 256, 8, 8]             512
#            Conv2d-89            [-1, 256, 8, 8]      26,542,336
#       BatchNorm2d-90            [-1, 256, 8, 8]             512
#            Conv2d-91            [-1, 256, 8, 8]      19,267,840
#       BatchNorm2d-92            [-1, 256, 8, 8]             512
#            Conv2d-93            [-1, 256, 8, 8]      22,479,104
#       BatchNorm2d-94            [-1, 256, 8, 8]             512
#            Conv2d-95            [-1, 256, 8, 8]      13,107,456
#       BatchNorm2d-96            [-1, 256, 8, 8]             512
#            Conv2d-97            [-1, 256, 8, 8]      14,745,856
#       BatchNorm2d-98            [-1, 256, 8, 8]             512
#            Conv2d-99            [-1, 256, 8, 8]       5,898,496
#      BatchNorm2d-100            [-1, 256, 8, 8]             512
#           Conv2d-101            [-1, 256, 8, 8]       6,488,320
#      BatchNorm2d-102            [-1, 256, 8, 8]             512
#           Conv2d-103           [-1, 1024, 8, 8]       3,146,752
#      BatchNorm2d-104           [-1, 1024, 8, 8]           2,048
#  ConvTranspose2d-105          [-1, 512, 16, 16]       2,097,664
#           Conv2d-106          [-1, 256, 16, 16]      21,233,920
#      BatchNorm2d-107          [-1, 256, 16, 16]             512
#           Conv2d-108          [-1, 256, 16, 16]      26,542,336
#      BatchNorm2d-109          [-1, 256, 16, 16]             512
#           Conv2d-110          [-1, 256, 16, 16]      19,267,840
#      BatchNorm2d-111          [-1, 256, 16, 16]             512
#           Conv2d-112          [-1, 256, 16, 16]      22,479,104
#      BatchNorm2d-113          [-1, 256, 16, 16]             512
#           Conv2d-114          [-1, 256, 16, 16]      13,107,456
#      BatchNorm2d-115          [-1, 256, 16, 16]             512
#           Conv2d-116          [-1, 256, 16, 16]      14,745,856
#      BatchNorm2d-117          [-1, 256, 16, 16]             512
#           Conv2d-118          [-1, 256, 16, 16]       5,898,496
#      BatchNorm2d-119          [-1, 256, 16, 16]             512
#           Conv2d-120          [-1, 256, 16, 16]       6,488,320
#      BatchNorm2d-121          [-1, 256, 16, 16]             512
#           Conv2d-122         [-1, 1024, 16, 16]       3,146,752
#      BatchNorm2d-123         [-1, 1024, 16, 16]           2,048
#  ConvTranspose2d-124          [-1, 256, 32, 32]       1,048,832
#           Conv2d-125          [-1, 128, 32, 32]       5,308,544
#      BatchNorm2d-126          [-1, 128, 32, 32]             256
#           Conv2d-127          [-1, 128, 32, 32]       6,635,648
#      BatchNorm2d-128          [-1, 128, 32, 32]             256
#           Conv2d-129          [-1, 128, 32, 32]       4,817,024
#      BatchNorm2d-130          [-1, 128, 32, 32]             256
#           Conv2d-131          [-1, 128, 32, 32]       5,619,840
#      BatchNorm2d-132          [-1, 128, 32, 32]             256
#           Conv2d-133          [-1, 128, 32, 32]       3,276,928
#      BatchNorm2d-134          [-1, 128, 32, 32]             256
#           Conv2d-135          [-1, 128, 32, 32]       3,686,528
#      BatchNorm2d-136          [-1, 128, 32, 32]             256
#           Conv2d-137          [-1, 128, 32, 32]       1,474,688
#      BatchNorm2d-138          [-1, 128, 32, 32]             256
#           Conv2d-139          [-1, 128, 32, 32]       1,622,144
#      BatchNorm2d-140          [-1, 128, 32, 32]             256
#           Conv2d-141          [-1, 512, 32, 32]         786,944
#      BatchNorm2d-142          [-1, 512, 32, 32]           1,024
#  ConvTranspose2d-143          [-1, 128, 64, 64]         262,272
#           Conv2d-144           [-1, 64, 64, 64]       1,327,168
#      BatchNorm2d-145           [-1, 64, 64, 64]             128
#           Conv2d-146           [-1, 64, 64, 64]       1,658,944
#      BatchNorm2d-147           [-1, 64, 64, 64]             128
#           Conv2d-148           [-1, 64, 64, 64]       1,204,288
#      BatchNorm2d-149           [-1, 64, 64, 64]             128
#           Conv2d-150           [-1, 64, 64, 64]       1,404,992
#      BatchNorm2d-151           [-1, 64, 64, 64]             128
#           Conv2d-152           [-1, 64, 64, 64]         819,264
#      BatchNorm2d-153           [-1, 64, 64, 64]             128
#           Conv2d-154           [-1, 64, 64, 64]         921,664
#      BatchNorm2d-155           [-1, 64, 64, 64]             128
#           Conv2d-156           [-1, 64, 64, 64]         368,704
#      BatchNorm2d-157           [-1, 64, 64, 64]             128
#           Conv2d-158           [-1, 64, 64, 64]         405,568
#      BatchNorm2d-159           [-1, 64, 64, 64]             128
#           Conv2d-160          [-1, 256, 64, 64]         196,864
#      BatchNorm2d-161          [-1, 256, 64, 64]             512
#  ConvTranspose2d-162         [-1, 64, 128, 128]          65,600
#           Conv2d-163         [-1, 32, 128, 128]         331,808
#      BatchNorm2d-164         [-1, 32, 128, 128]              64
#           Conv2d-165         [-1, 32, 128, 128]         414,752
#      BatchNorm2d-166         [-1, 32, 128, 128]              64
#           Conv2d-167         [-1, 32, 128, 128]         301,088
#      BatchNorm2d-168         [-1, 32, 128, 128]              64
#           Conv2d-169         [-1, 32, 128, 128]         351,264
#      BatchNorm2d-170         [-1, 32, 128, 128]              64
#           Conv2d-171         [-1, 32, 128, 128]         204,832
#      BatchNorm2d-172         [-1, 32, 128, 128]              64
#           Conv2d-173         [-1, 32, 128, 128]         230,432
#      BatchNorm2d-174         [-1, 32, 128, 128]              64
#           Conv2d-175         [-1, 32, 128, 128]          92,192
#      BatchNorm2d-176         [-1, 32, 128, 128]              64
#           Conv2d-177         [-1, 32, 128, 128]         101,408
#      BatchNorm2d-178         [-1, 32, 128, 128]              64
#           Conv2d-179        [-1, 128, 128, 128]          49,280
#      BatchNorm2d-180        [-1, 128, 128, 128]             256
#           Conv2d-181         [-1, 64, 128, 128]          73,792
#      BatchNorm2d-182         [-1, 64, 128, 128]             128
#           Conv2d-183         [-1, 16, 128, 128]          25,616
#      BatchNorm2d-184         [-1, 16, 128, 128]              32
#           Conv2d-185          [-1, 1, 128, 128]              17
#      BatchNorm2d-186          [-1, 1, 128, 128]               2
# ================================================================
# Total params: 363,437,059
# Trainable params: 363,437,059
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 343.00
# Params size (MB): 1386.40
# Estimated Total Size (MB): 1729.59
# ----------------------------------------------------------------

# %% [markdown]
# # IoU Function

# %%
def binaryJaccardIndex(preds, masks):
    intersection = 0
    union = 0
    for pred, mask in zip(preds, masks):
        for pred_row, mask_row in zip(pred[0],mask[0]):
            for i,j in zip(pred_row, mask_row):
                if i==1 or j==1:
                    union+=1
                if i==1 and j==1:
                    intersection+=1
    return(intersection/union)

# %% [markdown]
# # Binary Cross Entropy Loss

# %%
criterion = nn.BCELoss()
optimizer = torch.optim.SGD(unet.parameters(), lr=5e-1)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size = 1, gamma=0.6)

# %%
num_epochs = 20
batches = len(train_loader)
losses = []
print(batches)
# Out:
# 125

# %%
best_weights = copy.deepcopy(unet.state_dict())
max = 0
val_iou_score = 0
tic = time.time()
for epoch in range(num_epochs):
    unet.train()
    print(f'Epoch {epoch+1}/{num_epochs}; LR = {scheduler.get_last_lr()[0]}')
    for i, (images,masks) in enumerate(train_loader):
        images = images.to(device)
        masks = torch.round(masks).to(device)

        preds = unet(images)
        loss = criterion(preds, masks)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        print(f'Step {i+1}/{batches}; Loss = {loss.item():.4f}')
        losses.append(loss.item())
    scheduler.step() # Decaying learning rate per 25 epochs by 0.2 times
    with torch.no_grad():
        unet.eval()
        val_iou_score = 0
        for images, masks in val_loader:
            image = image.to(device)
            mask = mask.to('cpu')
            pred = unet(image).cpu()
            pred = torch.round(pred)
            val_iou_score += binaryJaccardIndex(pred, torch.round(mask).type(torch.int16))
        val_iou_score = val_iou_score/len(val_loader)

        if (max <= val_iou_score):
            print('SAVED MODEL WEIGHTS')
            max = val_iou_score
            best_weights = copy.deepcopy(unet.state_dict())
    
    print(f'Validation IoU Score: {val_iou_score:.4f}')
    print(f'Validation Dice Score: {(2*val_iou_score)/(1+val_iou_score):.4f}')
    print("-"*20)
print('Finished Training!')
print(f'Time Taken = {(time.time() - tic)//60:.0f}m {(time.time() - tic)%60:.0f}s')
# Out:
# Epoch 1/20; LR = 0.5
# Step 1/125; Loss = 0.6282
# Step 2/125; Loss = 0.5760
# Step 3/125; Loss = 0.5007
# Step 4/125; Loss = 0.5152
# Step 5/125; Loss = 0.4807
# Step 6/125; Loss = 0.5553
# Step 7/125; Loss = 0.4842
# Step 8/125; Loss = 0.4539
# Step 9/125; Loss = 0.4524
# Step 10/125; Loss = 0.4392
# Step 11/125; Loss = 0.4507
# Step 12/125; Loss = 0.3832
# Step 13/125; Loss = 0.3743
# Step 14/125; Loss = 0.4023
# Step 15/125; Loss = 0.4115
# Step 16/125; Loss = 0.4210
# Step 17/125; Loss = 0.4413
# Step 18/125; Loss = 0.3952
# Step 19/125; Loss = 0.3653
# Step 20/125; Loss = 0.4035
# Step 21/125; Loss = 0.4490
# Step 22/125; Loss = 0.4333
# Step 23/125; Loss = 0.3567
# Step 24/125; Loss = 0.4641
# Step 25/125; Loss = 0.3754
# Step 26/125; Loss = 0.3561
# Step 27/125; Loss = 0.4019
# Step 28/125; Loss = 0.4059
# Step 29/125; Loss = 0.4003
# Step 30/125; Loss = 0.4793
# Step 31/125; Loss = 0.4300
# Step 32/125; Loss = 0.4237
# Step 33/125; Loss = 0.4184
# Step 34/125; Loss = 0.4223
# Step 35/125; Loss = 0.3612
# Step 36/125; Loss = 0.3423
# Step 37/125; Loss = 0.3564
# Step 38/125; Loss = 0.4051
# Step 39/125; Loss = 0.4035
# Step 40/125; Loss = 0.4098
# Step 41/125; Loss = 0.3430
# Step 42/125; Loss = 0.3261
# Step 43/125; Loss = 0.3357
# Step 44/125; Loss = 0.4299
# Step 45/125; Loss = 0.4711
# Step 46/125; Loss = 0.3669
# Step 47/125; Loss = 0.3449
# Step 48/125; Loss = 0.3139
# Step 49/125; Loss = 0.4022
# Step 50/125; Loss = 0.3429
# Step 51/125; Loss = 0.3490
# Step 52/125; Loss = 0.3462
# Step 53/125; Loss = 0.3215
# Step 54/125; Loss = 0.4025
# Step 55/125; Loss = 0.3819
# Step 56/125; Loss = 0.4069
# Step 57/125; Loss = 0.3966
# Step 58/125; Loss = 0.3929
# Step 59/125; Loss = 0.3553
# Step 60/125; Loss = 0.3976
# Step 61/125; Loss = 0.3728
# Step 62/125; Loss = 0.3581
# Step 63/125; Loss = 0.3657
# Step 64/125; Loss = 0.3897
# Step 65/125; Loss = 0.3626
# Step 66/125; Loss = 0.3719
# Step 67/125; Loss = 0.3611
# Step 68/125; Loss = 0.3574
# Step 69/125; Loss = 0.3282
# Step 70/125; Loss = 0.3550
# Step 71/125; Loss = 0.3706
# Step 72/125; Loss = 0.3131
# Step 73/125; Loss = 0.3929
# Step 74/125; Loss = 0.3214
# Step 75/125; Loss = 0.3498
# Step 76/125; Loss = 0.3056
# Step 77/125; Loss = 0.3149
# Step 78/125; Loss = 0.2837
# Step 79/125; Loss = 0.3827
# Step 80/125; Loss = 0.3678
# Step 81/125; Loss = 0.3074
# Step 82/125; Loss = 0.2581
# Step 83/125; Loss = 0.3183
# Step 84/125; Loss = 0.3985
# Step 85/125; Loss = 0.3513
# Step 86/125; Loss = 0.3458
# Step 87/125; Loss = 0.4015
# Step 88/125; Loss = 0.2906
# Step 89/125; Loss = 0.3792
# Step 90/125; Loss = 0.3128
# Step 91/125; Loss = 0.3893
# Step 92/125; Loss = 0.3875
# Step 93/125; Loss = 0.3818
# Step 94/125; Loss = 0.3425
# Step 95/125; Loss = 0.3512
# Step 96/125; Loss = 0.3341
# Step 97/125; Loss = 0.3426
# Step 98/125; Loss = 0.2955
# Step 99/125; Loss = 0.3720
# Step 100/125; Loss = 0.3269
# Step 101/125; Loss = 0.3830
# Step 102/125; Loss = 0.2825
# Step 103/125; Loss = 0.3244
# Step 104/125; Loss = 0.3414
# Step 105/125; Loss = 0.2933
# Step 106/125; Loss = 0.3447
# Step 107/125; Loss = 0.3548
# Step 108/125; Loss = 0.2818
# Step 109/125; Loss = 0.3534
# Step 110/125; Loss = 0.3678
# Step 111/125; Loss = 0.3208
# Step 112/125; Loss = 0.2933
# Step 113/125; Loss = 0.3777
# Step 114/125; Loss = 0.2994
# Step 115/125; Loss = 0.4234
# Step 116/125; Loss = 0.2972
# Step 117/125; Loss = 0.3345
# Step 118/125; Loss = 0.3868
# Step 119/125; Loss = 0.3631
# Step 120/125; Loss = 0.2741
# Step 121/125; Loss = 0.4380
# Step 122/125; Loss = 0.3120
# Step 123/125; Loss = 0.3260
# Step 124/125; Loss = 0.4241
# Step 125/125; Loss = 0.3159
# SAVED MODEL WEIGHTS
# Validation IoU Score: 0.3229
# Validation Dice Score: 0.4881
# --------------------
# Epoch 2/20; LR = 0.3
# Step 1/125; Loss = 0.3597
# Step 2/125; Loss = 0.4574
# Step 3/125; Loss = 0.4033
# Step 4/125; Loss = 0.2992
# Step 5/125; Loss = 0.4118
# Step 6/125; Loss = 0.2866
# Step 7/125; Loss = 0.3940
# Step 8/125; Loss = 0.3172
# Step 9/125; Loss = 0.2964
# Step 10/125; Loss = 0.3614
# Step 11/125; Loss = 0.3481
# Step 12/125; Loss = 0.3552
# Step 13/125; Loss = 0.3247
# Step 14/125; Loss = 0.3040
# Step 15/125; Loss = 0.3249
# Step 16/125; Loss = 0.4056
# Step 17/125; Loss = 0.3367
# Step 18/125; Loss = 0.2914
# Step 19/125; Loss = 0.3052
# Step 20/125; Loss = 0.3693
# Step 21/125; Loss = 0.3011
# Step 22/125; Loss = 0.3955
# Step 23/125; Loss = 0.3395
# Step 24/125; Loss = 0.3466
# Step 25/125; Loss = 0.3020
# Step 26/125; Loss = 0.2739
# Step 27/125; Loss = 0.4037
# Step 28/125; Loss = 0.3040
# Step 29/125; Loss = 0.3756
# Step 30/125; Loss = 0.3764
# Step 31/125; Loss = 0.2721
# Step 32/125; Loss = 0.3899
# Step 33/125; Loss = 0.3834
# Step 34/125; Loss = 0.3210
# Step 35/125; Loss = 0.3490
# Step 36/125; Loss = 0.3812
# Step 37/125; Loss = 0.3707
# Step 38/125; Loss = 0.2901
# Step 39/125; Loss = 0.3639
# Step 40/125; Loss = 0.4229
# Step 41/125; Loss = 0.3238
# Step 42/125; Loss = 0.3759
# Step 43/125; Loss = 0.3251
# Step 44/125; Loss = 0.4014
# Step 45/125; Loss = 0.2774
# Step 46/125; Loss = 0.3332
# Step 47/125; Loss = 0.2860
# Step 48/125; Loss = 0.3296
# Step 49/125; Loss = 0.3082
# Step 50/125; Loss = 0.3788
# Step 51/125; Loss = 0.2947
# Step 52/125; Loss = 0.3357
# Step 53/125; Loss = 0.3051
# Step 54/125; Loss = 0.3166
# Step 55/125; Loss = 0.3540
# Step 56/125; Loss = 0.2792
# Step 57/125; Loss = 0.3546
# Step 58/125; Loss = 0.3318
# Step 59/125; Loss = 0.3436
# Step 60/125; Loss = 0.2833
# Step 61/125; Loss = 0.3137
# Step 62/125; Loss = 0.3041
# Step 63/125; Loss = 0.3766
# Step 64/125; Loss = 0.3090
# Step 65/125; Loss = 0.3686
# Step 66/125; Loss = 0.3066
# Step 67/125; Loss = 0.2890
# Step 68/125; Loss = 0.2933
# Step 69/125; Loss = 0.2686
# Step 70/125; Loss = 0.3362
# Step 71/125; Loss = 0.3233
# Step 72/125; Loss = 0.3559
# Step 73/125; Loss = 0.3605
# Step 74/125; Loss = 0.3025
# Step 75/125; Loss = 0.2771
# Step 76/125; Loss = 0.3177
# Step 77/125; Loss = 0.2760
# Step 78/125; Loss = 0.3104
# Step 79/125; Loss = 0.2706
# Step 80/125; Loss = 0.3380
# Step 81/125; Loss = 0.3592
# Step 82/125; Loss = 0.2686
# Step 83/125; Loss = 0.3354
# Step 84/125; Loss = 0.3977
# Step 85/125; Loss = 0.3336
# Step 86/125; Loss = 0.3192
# Step 87/125; Loss = 0.3029
# Step 88/125; Loss = 0.3049
# Step 89/125; Loss = 0.3307
# Step 90/125; Loss = 0.3301
# Step 91/125; Loss = 0.3992
# Step 92/125; Loss = 0.4537
# Step 93/125; Loss = 0.4430
# Step 94/125; Loss = 0.4036
# Step 95/125; Loss = 0.3075
# Step 96/125; Loss = 0.3851
# Step 97/125; Loss = 0.3220
# Step 98/125; Loss = 0.2959
# Step 99/125; Loss = 0.2786
# Step 100/125; Loss = 0.4069
# Step 101/125; Loss = 0.3257
# Step 102/125; Loss = 0.2662
# Step 103/125; Loss = 0.2586
# Step 104/125; Loss = 0.3772
# Step 105/125; Loss = 0.2643
# Step 106/125; Loss = 0.3784
# Step 107/125; Loss = 0.3653
# Step 108/125; Loss = 0.2976
# Step 109/125; Loss = 0.3399
# Step 110/125; Loss = 0.2864
# Step 111/125; Loss = 0.3701
# Step 112/125; Loss = 0.3464
# Step 113/125; Loss = 0.3186
# Step 114/125; Loss = 0.3590
# Step 115/125; Loss = 0.3216
# Step 116/125; Loss = 0.4211
# Step 117/125; Loss = 0.3826
# Step 118/125; Loss = 0.3344
# Step 119/125; Loss = 0.3638
# Step 120/125; Loss = 0.3369
# Step 121/125; Loss = 0.3648
# Step 122/125; Loss = 0.3303
# Step 123/125; Loss = 0.2977
# Step 124/125; Loss = 0.3238
# Step 125/125; Loss = 0.3357
# Validation IoU Score: 0.3033
# Validation Dice Score: 0.4655
# --------------------
# Epoch 3/20; LR = 0.18
# Step 1/125; Loss = 0.3498
# Step 2/125; Loss = 0.3703
# Step 3/125; Loss = 0.3027
# Step 4/125; Loss = 0.2789
# Step 5/125; Loss = 0.2720
# Step 6/125; Loss = 0.3491
# Step 7/125; Loss = 0.2811
# Step 8/125; Loss = 0.2960
# Step 9/125; Loss = 0.3299
# Step 10/125; Loss = 0.3652
# Step 11/125; Loss = 0.3585
# Step 12/125; Loss = 0.2951
# Step 13/125; Loss = 0.3814
# Step 14/125; Loss = 0.3499
# Step 15/125; Loss = 0.2943
# Step 16/125; Loss = 0.3756
# Step 17/125; Loss = 0.3313
# Step 18/125; Loss = 0.3108
# Step 19/125; Loss = 0.3465
# Step 20/125; Loss = 0.3388
# Step 21/125; Loss = 0.2629
# Step 22/125; Loss = 0.3328
# Step 23/125; Loss = 0.2785
# Step 24/125; Loss = 0.3177
# Step 25/125; Loss = 0.3116
# Step 26/125; Loss = 0.3402
# Step 27/125; Loss = 0.2901
# Step 28/125; Loss = 0.4026
# Step 29/125; Loss = 0.3364
# Step 30/125; Loss = 0.4192
# Step 31/125; Loss = 0.2946
# Step 32/125; Loss = 0.3225
# Step 33/125; Loss = 0.3712
# Step 34/125; Loss = 0.3364
# Step 35/125; Loss = 0.2739
# Step 36/125; Loss = 0.3469
# Step 37/125; Loss = 0.3223
# Step 38/125; Loss = 0.2933
# Step 39/125; Loss = 0.3112
# Step 40/125; Loss = 0.2681
# Step 41/125; Loss = 0.2585
# Step 42/125; Loss = 0.3150
# Step 43/125; Loss = 0.3042
# Step 44/125; Loss = 0.2939
# Step 45/125; Loss = 0.3470
# Step 46/125; Loss = 0.3098
# Step 47/125; Loss = 0.3581
# Step 48/125; Loss = 0.3141
# Step 49/125; Loss = 0.2534
# Step 50/125; Loss = 0.3375
# Step 51/125; Loss = 0.3074
# Step 52/125; Loss = 0.3715
# Step 53/125; Loss = 0.4024
# Step 54/125; Loss = 0.3322
# Step 55/125; Loss = 0.2818
# Step 56/125; Loss = 0.2965
# Step 57/125; Loss = 0.3523
# Step 58/125; Loss = 0.3991
# Step 59/125; Loss = 0.3680
# Step 60/125; Loss = 0.2988
# Step 61/125; Loss = 0.3209
# Step 62/125; Loss = 0.2652
# Step 63/125; Loss = 0.3143
# Step 64/125; Loss = 0.2646
# Step 65/125; Loss = 0.2296
# Step 66/125; Loss = 0.3316
# Step 67/125; Loss = 0.3218
# Step 68/125; Loss = 0.3442
# Step 69/125; Loss = 0.3363
# Step 70/125; Loss = 0.3524
# Step 71/125; Loss = 0.3000
# Step 72/125; Loss = 0.3215
# Step 73/125; Loss = 0.3493
# Step 74/125; Loss = 0.3684
# Step 75/125; Loss = 0.3062
# Step 76/125; Loss = 0.2870
# Step 77/125; Loss = 0.3135
# Step 78/125; Loss = 0.3010
# Step 79/125; Loss = 0.2873
# Step 80/125; Loss = 0.2922
# Step 81/125; Loss = 0.3465
# Step 82/125; Loss = 0.3028
# Step 83/125; Loss = 0.3792
# Step 84/125; Loss = 0.3522
# Step 85/125; Loss = 0.3914
# Step 86/125; Loss = 0.3236
# Step 87/125; Loss = 0.3217
# Step 88/125; Loss = 0.3311
# Step 89/125; Loss = 0.3166
# Step 90/125; Loss = 0.2636
# Step 91/125; Loss = 0.2890
# Step 92/125; Loss = 0.3284
# Step 93/125; Loss = 0.3370
# Step 94/125; Loss = 0.2588
# Step 95/125; Loss = 0.3510
# Step 96/125; Loss = 0.4481
# Step 97/125; Loss = 0.3587
# Step 98/125; Loss = 0.3891
# Step 99/125; Loss = 0.2985
# Step 100/125; Loss = 0.3393
# Step 101/125; Loss = 0.2804
# Step 102/125; Loss = 0.3441
# Step 103/125; Loss = 0.3766
# Step 104/125; Loss = 0.3217
# Step 105/125; Loss = 0.2475
# Step 106/125; Loss = 0.3122
# Step 107/125; Loss = 0.3358
# Step 108/125; Loss = 0.2729
# Step 109/125; Loss = 0.2985
# Step 110/125; Loss = 0.3389
# Step 111/125; Loss = 0.3346
# Step 112/125; Loss = 0.2861
# Step 113/125; Loss = 0.3277
# Step 114/125; Loss = 0.3996
# Step 115/125; Loss = 0.4136
# Step 116/125; Loss = 0.3143
# Step 117/125; Loss = 0.2725
# Step 118/125; Loss = 0.3959
# Step 119/125; Loss = 0.3055
# Step 120/125; Loss = 0.2838
# Step 121/125; Loss = 0.3408
# Step 122/125; Loss = 0.3119
# Step 123/125; Loss = 0.3215
# Step 124/125; Loss = 0.4393
# Step 125/125; Loss = 0.3332
# Validation IoU Score: 0.2805
# Validation Dice Score: 0.4380
# --------------------
# Epoch 4/20; LR = 0.108
# Step 1/125; Loss = 0.3503
# Step 2/125; Loss = 0.2970
# Step 3/125; Loss = 0.3239
# Step 4/125; Loss = 0.2499
# Step 5/125; Loss = 0.2808
# Step 6/125; Loss = 0.3025
# Step 7/125; Loss = 0.2970
# Step 8/125; Loss = 0.3340
# Step 9/125; Loss = 0.2866
# Step 10/125; Loss = 0.3079
# Step 11/125; Loss = 0.2638
# Step 12/125; Loss = 0.2769
# Step 13/125; Loss = 0.3196
# Step 14/125; Loss = 0.2984
# Step 15/125; Loss = 0.3186
# Step 16/125; Loss = 0.2874
# Step 17/125; Loss = 0.2886
# Step 18/125; Loss = 0.2978
# Step 19/125; Loss = 0.3506
# Step 20/125; Loss = 0.2892
# Step 21/125; Loss = 0.2808
# Step 22/125; Loss = 0.3025
# Step 23/125; Loss = 0.2491
# Step 24/125; Loss = 0.4411
# Step 25/125; Loss = 0.2619
# Step 26/125; Loss = 0.3076
# Step 27/125; Loss = 0.2647
# Step 28/125; Loss = 0.2937
# Step 29/125; Loss = 0.2873
# Step 30/125; Loss = 0.2504
# Step 31/125; Loss = 0.2952
# Step 32/125; Loss = 0.2909
# Step 33/125; Loss = 0.2965
# Step 34/125; Loss = 0.2401
# Step 35/125; Loss = 0.2752
# Step 36/125; Loss = 0.2680
# Step 37/125; Loss = 0.3510
# Step 38/125; Loss = 0.2819
# Step 39/125; Loss = 0.3413
# Step 40/125; Loss = 0.3382
# Step 41/125; Loss = 0.3234
# Step 42/125; Loss = 0.3171
# Step 43/125; Loss = 0.3269
# Step 44/125; Loss = 0.3198
# Step 45/125; Loss = 0.2905
# Step 46/125; Loss = 0.2898
# Step 47/125; Loss = 0.2812
# Step 48/125; Loss = 0.3441
# Step 49/125; Loss = 0.3729
# Step 50/125; Loss = 0.4104
# Step 51/125; Loss = 0.3017
# Step 52/125; Loss = 0.2721
# Step 53/125; Loss = 0.2760
# Step 54/125; Loss = 0.3104
# Step 55/125; Loss = 0.3415
# Step 56/125; Loss = 0.2926
# Step 57/125; Loss = 0.3730
# Step 58/125; Loss = 0.3824
# Step 59/125; Loss = 0.3097
# Step 60/125; Loss = 0.3026
# Step 61/125; Loss = 0.2894
# Step 62/125; Loss = 0.2813
# Step 63/125; Loss = 0.3159
# Step 64/125; Loss = 0.3442
# Step 65/125; Loss = 0.3610
# Step 66/125; Loss = 0.3070
# Step 67/125; Loss = 0.3275
# Step 68/125; Loss = 0.3460
# Step 69/125; Loss = 0.2479
# Step 70/125; Loss = 0.2995
# Step 71/125; Loss = 0.4345
# Step 72/125; Loss = 0.3269
# Step 73/125; Loss = 0.2671
# Step 74/125; Loss = 0.2768
# Step 75/125; Loss = 0.2947
# Step 76/125; Loss = 0.2316
# Step 77/125; Loss = 0.3074
# Step 78/125; Loss = 0.3060
# Step 79/125; Loss = 0.3270
# Step 80/125; Loss = 0.3666
# Step 81/125; Loss = 0.3471
# Step 82/125; Loss = 0.3421
# Step 83/125; Loss = 0.2767
# Step 84/125; Loss = 0.2518
# Step 85/125; Loss = 0.4871
# Step 86/125; Loss = 0.3283
# Step 87/125; Loss = 0.3196
# Step 88/125; Loss = 0.3073
# Step 89/125; Loss = 0.3094
# Step 90/125; Loss = 0.2971
# Step 91/125; Loss = 0.3281
# Step 92/125; Loss = 0.3300
# Step 93/125; Loss = 0.2731
# Step 94/125; Loss = 0.3337
# Step 95/125; Loss = 0.2996
# Step 96/125; Loss = 0.3119
# Step 97/125; Loss = 0.3213
# Step 98/125; Loss = 0.3424
# Step 99/125; Loss = 0.3206
# Step 100/125; Loss = 0.3142
# Step 101/125; Loss = 0.3281
# Step 102/125; Loss = 0.3177
# Step 103/125; Loss = 0.3226
# Step 104/125; Loss = 0.2833
# Step 105/125; Loss = 0.3049
# Step 106/125; Loss = 0.2803
# Step 107/125; Loss = 0.3008
# Step 108/125; Loss = 0.2557
# Step 109/125; Loss = 0.2701
# Step 110/125; Loss = 0.3135
# Step 111/125; Loss = 0.3489
# Step 112/125; Loss = 0.3435
# Step 113/125; Loss = 0.3117
# Step 114/125; Loss = 0.3123
# Step 115/125; Loss = 0.2916
# Step 116/125; Loss = 0.3220
# Step 117/125; Loss = 0.2741
# Step 118/125; Loss = 0.4307
# Step 119/125; Loss = 0.2762
# Step 120/125; Loss = 0.3786
# Step 121/125; Loss = 0.2771
# Step 122/125; Loss = 0.3113
# Step 123/125; Loss = 0.3175
# Step 124/125; Loss = 0.2855
# Step 125/125; Loss = 0.2555
# SAVED MODEL WEIGHTS
# Validation IoU Score: 0.4202
# Validation Dice Score: 0.5917
# --------------------
# Epoch 5/20; LR = 0.0648
# Step 1/125; Loss = 0.3608
# Step 2/125; Loss = 0.2950
# Step 3/125; Loss = 0.3023
# Step 4/125; Loss = 0.2846
# Step 5/125; Loss = 0.2817
# Step 6/125; Loss = 0.2829
# Step 7/125; Loss = 0.2443
# Step 8/125; Loss = 0.3027
# Step 9/125; Loss = 0.2973
# Step 10/125; Loss = 0.2769
# Step 11/125; Loss = 0.3094
# Step 12/125; Loss = 0.2959
# Step 13/125; Loss = 0.3268
# Step 14/125; Loss = 0.3432
# Step 15/125; Loss = 0.2977
# Step 16/125; Loss = 0.2664
# Step 17/125; Loss = 0.3277
# Step 18/125; Loss = 0.3108
# Step 19/125; Loss = 0.2810
# Step 20/125; Loss = 0.3259
# Step 21/125; Loss = 0.3185
# Step 22/125; Loss = 0.2976
# Step 23/125; Loss = 0.2354
# Step 24/125; Loss = 0.3433
# Step 25/125; Loss = 0.3274
# Step 26/125; Loss = 0.2732
# Step 27/125; Loss = 0.2497
# Step 28/125; Loss = 0.2384
# Step 29/125; Loss = 0.3529
# Step 30/125; Loss = 0.3113
# Step 31/125; Loss = 0.2820
# Step 32/125; Loss = 0.2927
# Step 33/125; Loss = 0.2888
# Step 34/125; Loss = 0.3146
# Step 35/125; Loss = 0.2452
# Step 36/125; Loss = 0.3030
# Step 37/125; Loss = 0.3491
# Step 38/125; Loss = 0.2798
# Step 39/125; Loss = 0.3277
# Step 40/125; Loss = 0.3120
# Step 41/125; Loss = 0.2846
# Step 42/125; Loss = 0.3411
# Step 43/125; Loss = 0.2387
# Step 44/125; Loss = 0.3328
# Step 45/125; Loss = 0.2760
# Step 46/125; Loss = 0.2902
# Step 47/125; Loss = 0.3040
# Step 48/125; Loss = 0.3165
# Step 49/125; Loss = 0.2937
# Step 50/125; Loss = 0.3475
# Step 51/125; Loss = 0.3352
# Step 52/125; Loss = 0.3241
# Step 53/125; Loss = 0.2659
# Step 54/125; Loss = 0.3329
# Step 55/125; Loss = 0.2868
# Step 56/125; Loss = 0.3114
# Step 57/125; Loss = 0.2550
# Step 58/125; Loss = 0.2823
# Step 59/125; Loss = 0.2581
# Step 60/125; Loss = 0.2807
# Step 61/125; Loss = 0.3183
# Step 62/125; Loss = 0.3102
# Step 63/125; Loss = 0.3121
# Step 64/125; Loss = 0.2902
# Step 65/125; Loss = 0.3844
# Step 66/125; Loss = 0.2441
# Step 67/125; Loss = 0.3064
# Step 68/125; Loss = 0.2733
# Step 69/125; Loss = 0.2875
# Step 70/125; Loss = 0.3508
# Step 71/125; Loss = 0.2794
# Step 72/125; Loss = 0.2811
# Step 73/125; Loss = 0.3374
# Step 74/125; Loss = 0.2928
# Step 75/125; Loss = 0.3510
# Step 76/125; Loss = 0.2531
# Step 77/125; Loss = 0.2630
# Step 78/125; Loss = 0.3271
# Step 79/125; Loss = 0.2493
# Step 80/125; Loss = 0.2452
# Step 81/125; Loss = 0.2379
# Step 82/125; Loss = 0.2829
# Step 83/125; Loss = 0.3024
# Step 84/125; Loss = 0.2822
# Step 85/125; Loss = 0.3036
# Step 86/125; Loss = 0.3235
# Step 87/125; Loss = 0.3505
# Step 88/125; Loss = 0.2338
# Step 89/125; Loss = 0.2470
# Step 90/125; Loss = 0.2555
# Step 91/125; Loss = 0.3253
# Step 92/125; Loss = 0.3059
# Step 93/125; Loss = 0.2640
# Step 94/125; Loss = 0.2784
# Step 95/125; Loss = 0.2579
# Step 96/125; Loss = 0.2198
# Step 97/125; Loss = 0.2776
# Step 98/125; Loss = 0.2656
# Step 99/125; Loss = 0.4656
# Step 100/125; Loss = 0.3675
# Step 101/125; Loss = 0.3457
# Step 102/125; Loss = 0.2707
# Step 103/125; Loss = 0.3276
# Step 104/125; Loss = 0.3016
# Step 105/125; Loss = 0.3588
# Step 106/125; Loss = 0.2617
# Step 107/125; Loss = 0.2986
# Step 108/125; Loss = 0.2698
# Step 109/125; Loss = 0.2508
# Step 110/125; Loss = 0.3310
# Step 111/125; Loss = 0.2945
# Step 112/125; Loss = 0.3043
# Step 113/125; Loss = 0.2964
# Step 114/125; Loss = 0.2549
# Step 115/125; Loss = 0.3252
# Step 116/125; Loss = 0.2662
# Step 117/125; Loss = 0.2815
# Step 118/125; Loss = 0.2877
# Step 119/125; Loss = 0.2252
# Step 120/125; Loss = 0.2386
# Step 121/125; Loss = 0.2649
# Step 122/125; Loss = 0.2352
# Step 123/125; Loss = 0.3211
# Step 124/125; Loss = 0.2760
# Step 125/125; Loss = 0.3177
# SAVED MODEL WEIGHTS
# Validation IoU Score: 0.4675
# Validation Dice Score: 0.6372
# --------------------
# Epoch 6/20; LR = 0.03888
# Step 1/125; Loss = 0.2550
# Step 2/125; Loss = 0.2822
# Step 3/125; Loss = 0.2627
# Step 4/125; Loss = 0.3419
# Step 5/125; Loss = 0.2768
# Step 6/125; Loss = 0.3275
# Step 7/125; Loss = 0.2839
# Step 8/125; Loss = 0.2477
# Step 9/125; Loss = 0.2779
# Step 10/125; Loss = 0.2960
# Step 11/125; Loss = 0.2829
# Step 12/125; Loss = 0.2026
# Step 13/125; Loss = 0.2761
# Step 14/125; Loss = 0.3401
# Step 15/125; Loss = 0.2734
# Step 16/125; Loss = 0.2882
# Step 17/125; Loss = 0.2643
# Step 18/125; Loss = 0.2196
# Step 19/125; Loss = 0.3775
# Step 20/125; Loss = 0.3460
# Step 21/125; Loss = 0.2314
# Step 22/125; Loss = 0.3336
# Step 23/125; Loss = 0.2412
# Step 24/125; Loss = 0.2694
# Step 25/125; Loss = 0.3593
# Step 26/125; Loss = 0.3041
# Step 27/125; Loss = 0.3063
# Step 28/125; Loss = 0.2978
# Step 29/125; Loss = 0.2831
# Step 30/125; Loss = 0.2925
# Step 31/125; Loss = 0.2833
# Step 32/125; Loss = 0.3039
# Step 33/125; Loss = 0.2677
# Step 34/125; Loss = 0.2808
# Step 35/125; Loss = 0.2781
# Step 36/125; Loss = 0.2652
# Step 37/125; Loss = 0.2745
# Step 38/125; Loss = 0.2639
# Step 39/125; Loss = 0.3126
# Step 40/125; Loss = 0.2893
# Step 41/125; Loss = 0.2345
# Step 42/125; Loss = 0.3512
# Step 43/125; Loss = 0.2311
# Step 44/125; Loss = 0.2414
# Step 45/125; Loss = 0.3158
# Step 46/125; Loss = 0.3146
# Step 47/125; Loss = 0.2664
# Step 48/125; Loss = 0.2140
# Step 49/125; Loss = 0.2511
# Step 50/125; Loss = 0.2507
# Step 51/125; Loss = 0.3124
# Step 52/125; Loss = 0.2615
# Step 53/125; Loss = 0.2660
# Step 54/125; Loss = 0.2522
# Step 55/125; Loss = 0.2915
# Step 56/125; Loss = 0.2306
# Step 57/125; Loss = 0.2969
# Step 58/125; Loss = 0.2827
# Step 59/125; Loss = 0.3549
# Step 60/125; Loss = 0.2543
# Step 61/125; Loss = 0.2797
# Step 62/125; Loss = 0.2493
# Step 63/125; Loss = 0.2885
# Step 64/125; Loss = 0.2563
# Step 65/125; Loss = 0.2819
# Step 66/125; Loss = 0.3475
# Step 67/125; Loss = 0.2591
# Step 68/125; Loss = 0.2767
# Step 69/125; Loss = 0.2972
# Step 70/125; Loss = 0.2873
# Step 71/125; Loss = 0.2402
# Step 72/125; Loss = 0.2566
# Step 73/125; Loss = 0.3464
# Step 74/125; Loss = 0.3670
# Step 75/125; Loss = 0.2546
# Step 76/125; Loss = 0.2567
# Step 77/125; Loss = 0.2685
# Step 78/125; Loss = 0.2852
# Step 79/125; Loss = 0.2688
# Step 80/125; Loss = 0.3207
# Step 81/125; Loss = 0.2868
# Step 82/125; Loss = 0.2570
# Step 83/125; Loss = 0.2729
# Step 84/125; Loss = 0.2607
# Step 85/125; Loss = 0.3124
# Step 86/125; Loss = 0.2730
# Step 87/125; Loss = 0.2427
# Step 88/125; Loss = 0.2202
# Step 89/125; Loss = 0.2909
# Step 90/125; Loss = 0.3040
# Step 91/125; Loss = 0.2980
# Step 92/125; Loss = 0.2805
# Step 93/125; Loss = 0.2698
# Step 94/125; Loss = 0.2300
# Step 95/125; Loss = 0.2999
# Step 96/125; Loss = 0.2567
# Step 97/125; Loss = 0.2924
# Step 98/125; Loss = 0.2603
# Step 99/125; Loss = 0.3652
# Step 100/125; Loss = 0.2419
# Step 101/125; Loss = 0.2862
# Step 102/125; Loss = 0.2057
# Step 103/125; Loss = 0.2783
# Step 104/125; Loss = 0.2006
# Step 105/125; Loss = 0.2772
# Step 106/125; Loss = 0.2822
# Step 107/125; Loss = 0.3029
# Step 108/125; Loss = 0.2231
# Step 109/125; Loss = 0.2296
# Step 110/125; Loss = 0.2578
# Step 111/125; Loss = 0.3122
# Step 112/125; Loss = 0.2529
# Step 113/125; Loss = 0.3224
# Step 114/125; Loss = 0.3318
# Step 115/125; Loss = 0.3671
# Step 116/125; Loss = 0.3063
# Step 117/125; Loss = 0.2467
# Step 118/125; Loss = 0.2633
# Step 119/125; Loss = 0.2399
# Step 120/125; Loss = 0.2872
# Step 121/125; Loss = 0.2957
# Step 122/125; Loss = 0.2610
# Step 123/125; Loss = 0.2758
# Step 124/125; Loss = 0.3158
# Step 125/125; Loss = 0.2568
# SAVED MODEL WEIGHTS
# Validation IoU Score: 0.5217
# Validation Dice Score: 0.6856
# --------------------
# Epoch 7/20; LR = 0.023327999999999998
# Step 1/125; Loss = 0.2525
# Step 2/125; Loss = 0.2973
# Step 3/125; Loss = 0.3044
# Step 4/125; Loss = 0.2421
# Step 5/125; Loss = 0.2629
# Step 6/125; Loss = 0.2630
# Step 7/125; Loss = 0.2254
# Step 8/125; Loss = 0.2784
# Step 9/125; Loss = 0.2461
# Step 10/125; Loss = 0.2405
# Step 11/125; Loss = 0.2092
# Step 12/125; Loss = 0.2725
# Step 13/125; Loss = 0.2382
# Step 14/125; Loss = 0.2219
# Step 15/125; Loss = 0.2825
# Step 16/125; Loss = 0.2324
# Step 17/125; Loss = 0.2520
# Step 18/125; Loss = 0.2398
# Step 19/125; Loss = 0.3171
# Step 20/125; Loss = 0.2315
# Step 21/125; Loss = 0.3660
# Step 22/125; Loss = 0.2593
# Step 23/125; Loss = 0.2232
# Step 24/125; Loss = 0.2292
# Step 25/125; Loss = 0.2367
# Step 26/125; Loss = 0.2312
# Step 27/125; Loss = 0.2223
# Step 28/125; Loss = 0.2877
# Step 29/125; Loss = 0.2666
# Step 30/125; Loss = 0.2444
# Step 31/125; Loss = 0.2453
# Step 32/125; Loss = 0.2508
# Step 33/125; Loss = 0.2772
# Step 34/125; Loss = 0.2650
# Step 35/125; Loss = 0.2530
# Step 36/125; Loss = 0.2731
# Step 37/125; Loss = 0.2108
# Step 38/125; Loss = 0.2196
# Step 39/125; Loss = 0.2205
# Step 40/125; Loss = 0.3269
# Step 41/125; Loss = 0.2667
# Step 42/125; Loss = 0.2787
# Step 43/125; Loss = 0.2845
# Step 44/125; Loss = 0.2577
# Step 45/125; Loss = 0.2489
# Step 46/125; Loss = 0.2430
# Step 47/125; Loss = 0.2335
# Step 48/125; Loss = 0.2849
# Step 49/125; Loss = 0.2530
# Step 50/125; Loss = 0.2721
# Step 51/125; Loss = 0.2554
# Step 52/125; Loss = 0.2221
# Step 53/125; Loss = 0.2414
# Step 54/125; Loss = 0.2377
# Step 55/125; Loss = 0.2095
# Step 56/125; Loss = 0.2087
# Step 57/125; Loss = 0.2688
# Step 58/125; Loss = 0.2376
# Step 59/125; Loss = 0.2263
# Step 60/125; Loss = 0.3617
# Step 61/125; Loss = 0.2225
# Step 62/125; Loss = 0.2714
# Step 63/125; Loss = 0.2381
# Step 64/125; Loss = 0.2907
# Step 65/125; Loss = 0.2390
# Step 66/125; Loss = 0.3745
# Step 67/125; Loss = 0.3074
# Step 68/125; Loss = 0.2909
# Step 69/125; Loss = 0.2521
# Step 70/125; Loss = 0.2818
# Step 71/125; Loss = 0.2689
# Step 72/125; Loss = 0.3610
# Step 73/125; Loss = 0.2681
# Step 74/125; Loss = 0.3074
# Step 75/125; Loss = 0.2413
# Step 76/125; Loss = 0.2203
# Step 77/125; Loss = 0.3229
# Step 78/125; Loss = 0.2197
# Step 79/125; Loss = 0.2345
# Step 80/125; Loss = 0.2914
# Step 81/125; Loss = 0.2411
# Step 82/125; Loss = 0.2653
# Step 83/125; Loss = 0.2791
# Step 84/125; Loss = 0.2468
# Step 85/125; Loss = 0.2460
# Step 86/125; Loss = 0.2529
# Step 87/125; Loss = 0.2442
# Step 88/125; Loss = 0.2674
# Step 89/125; Loss = 0.2164
# Step 90/125; Loss = 0.2200
# Step 91/125; Loss = 0.2683
# Step 92/125; Loss = 0.2306
# Step 93/125; Loss = 0.2417
# Step 94/125; Loss = 0.3253
# Step 95/125; Loss = 0.2314
# Step 96/125; Loss = 0.2784
# Step 97/125; Loss = 0.2394
# Step 98/125; Loss = 0.2554
# Step 99/125; Loss = 0.2302
# Step 100/125; Loss = 0.3254
# Step 101/125; Loss = 0.3128
# Step 102/125; Loss = 0.2555
# Step 103/125; Loss = 0.2645
# Step 104/125; Loss = 0.2160
# Step 105/125; Loss = 0.2475
# Step 106/125; Loss = 0.3183
# Step 107/125; Loss = 0.2512
# Step 108/125; Loss = 0.2551
# Step 109/125; Loss = 0.2560
# Step 110/125; Loss = 0.2471
# Step 111/125; Loss = 0.2454
# Step 112/125; Loss = 0.2087
# Step 113/125; Loss = 0.2752
# Step 114/125; Loss = 0.2124
# Step 115/125; Loss = 0.2477
# Step 116/125; Loss = 0.2525
# Step 117/125; Loss = 0.2177
# Step 118/125; Loss = 0.2209
# Step 119/125; Loss = 0.2268
# Step 120/125; Loss = 0.2879
# Step 121/125; Loss = 0.2701
# Step 122/125; Loss = 0.1997
# Step 123/125; Loss = 0.2415
# Step 124/125; Loss = 0.3149
# Step 125/125; Loss = 0.2631
# Validation IoU Score: 0.4889
# Validation Dice Score: 0.6567
# --------------------
# Epoch 8/20; LR = 0.013996799999999998
# Step 1/125; Loss = 0.2766
# Step 2/125; Loss = 0.3274
# Step 3/125; Loss = 0.2690
# Step 4/125; Loss = 0.2716
# Step 5/125; Loss = 0.2543
# Step 6/125; Loss = 0.2336
# Step 7/125; Loss = 0.2071
# Step 8/125; Loss = 0.2349
# Step 9/125; Loss = 0.2184
# Step 10/125; Loss = 0.2183
# Step 11/125; Loss = 0.2265
# Step 12/125; Loss = 0.2845
# Step 13/125; Loss = 0.2951
# Step 14/125; Loss = 0.2079
# Step 15/125; Loss = 0.2140
# Step 16/125; Loss = 0.2098
# Step 17/125; Loss = 0.2910
# Step 18/125; Loss = 0.2251
# Step 19/125; Loss = 0.2304
# Step 20/125; Loss = 0.2339
# Step 21/125; Loss = 0.2179
# Step 22/125; Loss = 0.2494
# Step 23/125; Loss = 0.2385
# Step 24/125; Loss = 0.2173
# Step 25/125; Loss = 0.2569
# Step 26/125; Loss = 0.2391
# Step 27/125; Loss = 0.2228
# Step 28/125; Loss = 0.2093
# Step 29/125; Loss = 0.2937
# Step 30/125; Loss = 0.2389
# Step 31/125; Loss = 0.2676
# Step 32/125; Loss = 0.2396
# Step 33/125; Loss = 0.2266
# Step 34/125; Loss = 0.2335
# Step 35/125; Loss = 0.2195
# Step 36/125; Loss = 0.2635
# Step 37/125; Loss = 0.2068
# Step 38/125; Loss = 0.2367
# Step 39/125; Loss = 0.2431
# Step 40/125; Loss = 0.2463
# Step 41/125; Loss = 0.1985
# Step 42/125; Loss = 0.2870
# Step 43/125; Loss = 0.2380
# Step 44/125; Loss = 0.2108
# Step 45/125; Loss = 0.2572
# Step 46/125; Loss = 0.2425
# Step 47/125; Loss = 0.2956
# Step 48/125; Loss = 0.2484
# Step 49/125; Loss = 0.2381
# Step 50/125; Loss = 0.2140
# Step 51/125; Loss = 0.2721
# Step 52/125; Loss = 0.1982
# Step 53/125; Loss = 0.2658
# Step 54/125; Loss = 0.2362
# Step 55/125; Loss = 0.2147
# Step 56/125; Loss = 0.2351
# Step 57/125; Loss = 0.2243
# Step 58/125; Loss = 0.2077
# Step 59/125; Loss = 0.2333
# Step 60/125; Loss = 0.2415
# Step 61/125; Loss = 0.2639
# Step 62/125; Loss = 0.2366
# Step 63/125; Loss = 0.3047
# Step 64/125; Loss = 0.2541
# Step 65/125; Loss = 0.1935
# Step 66/125; Loss = 0.2216
# Step 67/125; Loss = 0.2359
# Step 68/125; Loss = 0.2239
# Step 69/125; Loss = 0.2068
# Step 70/125; Loss = 0.2166
# Step 71/125; Loss = 0.3306
# Step 72/125; Loss = 0.2156
# Step 73/125; Loss = 0.2329
# Step 74/125; Loss = 0.1830
# Step 75/125; Loss = 0.2093
# Step 76/125; Loss = 0.2940
# Step 77/125; Loss = 0.2278
# Step 78/125; Loss = 0.2747
# Step 79/125; Loss = 0.2903
# Step 80/125; Loss = 0.2251
# Step 81/125; Loss = 0.1983
# Step 82/125; Loss = 0.2598
# Step 83/125; Loss = 0.2774
# Step 84/125; Loss = 0.2337
# Step 85/125; Loss = 0.2319
# Step 86/125; Loss = 0.2245
# Step 87/125; Loss = 0.2862
# Step 88/125; Loss = 0.1773
# Step 89/125; Loss = 0.2822
# Step 90/125; Loss = 0.2272
# Step 91/125; Loss = 0.2967
# Step 92/125; Loss = 0.2351
# Step 93/125; Loss = 0.2566
# Step 94/125; Loss = 0.2572
# Step 95/125; Loss = 0.2170
# Step 96/125; Loss = 0.2523
# Step 97/125; Loss = 0.2134
# Step 98/125; Loss = 0.2184
# Step 99/125; Loss = 0.1873
# Step 100/125; Loss = 0.2408
# Step 101/125; Loss = 0.2173
# Step 102/125; Loss = 0.2426
# Step 103/125; Loss = 0.2275
# Step 104/125; Loss = 0.2703
# Step 105/125; Loss = 0.2099
# Step 106/125; Loss = 0.2408
# Step 107/125; Loss = 0.2336
# Step 108/125; Loss = 0.2645
# Step 109/125; Loss = 0.2088
# Step 110/125; Loss = 0.2598
# Step 111/125; Loss = 0.2315
# Step 112/125; Loss = 0.2111
# Step 113/125; Loss = 0.2191
# Step 114/125; Loss = 0.2360
# Step 115/125; Loss = 0.2124
# Step 116/125; Loss = 0.2517
# Step 117/125; Loss = 0.2970
# Step 118/125; Loss = 0.2559
# Step 119/125; Loss = 0.2409
# Step 120/125; Loss = 0.2614
# Step 121/125; Loss = 0.2293
# Step 122/125; Loss = 0.2739
# Step 123/125; Loss = 0.2159
# Step 124/125; Loss = 0.2129
# Step 125/125; Loss = 0.2343
# SAVED MODEL WEIGHTS
# Validation IoU Score: 0.6091
# Validation Dice Score: 0.7571
# --------------------
# Epoch 9/20; LR = 0.008398079999999999
# Step 1/125; Loss = 0.2566
# Step 2/125; Loss = 0.2389
# Step 3/125; Loss = 0.2194
# Step 4/125; Loss = 0.2383
# Step 5/125; Loss = 0.2277
# Step 6/125; Loss = 0.1901
# Step 7/125; Loss = 0.1719
# Step 8/125; Loss = 0.2250
# Step 9/125; Loss = 0.2128
# Step 10/125; Loss = 0.1971
# Step 11/125; Loss = 0.2265
# Step 12/125; Loss = 0.2251
# Step 13/125; Loss = 0.2489
# Step 14/125; Loss = 0.2062
# Step 15/125; Loss = 0.1912
# Step 16/125; Loss = 0.2070
# Step 17/125; Loss = 0.2100
# Step 18/125; Loss = 0.1925
# Step 19/125; Loss = 0.2161
# Step 20/125; Loss = 0.1776
# Step 21/125; Loss = 0.1999
# Step 22/125; Loss = 0.2343
# Step 23/125; Loss = 0.2379
# Step 24/125; Loss = 0.2047
# Step 25/125; Loss = 0.2297
# Step 26/125; Loss = 0.2137
# Step 27/125; Loss = 0.2030
# Step 28/125; Loss = 0.2483
# Step 29/125; Loss = 0.2070
# Step 30/125; Loss = 0.2267
# Step 31/125; Loss = 0.2894
# Step 32/125; Loss = 0.2431
# Step 33/125; Loss = 0.2795
# Step 34/125; Loss = 0.2045
# Step 35/125; Loss = 0.1969
# Step 36/125; Loss = 0.2777
# Step 37/125; Loss = 0.2563
# Step 38/125; Loss = 0.2627
# Step 39/125; Loss = 0.2611
# Step 40/125; Loss = 0.1963
# Step 41/125; Loss = 0.2565
# Step 42/125; Loss = 0.2477
# Step 43/125; Loss = 0.2110
# Step 44/125; Loss = 0.2002
# Step 45/125; Loss = 0.2199
# Step 46/125; Loss = 0.2195
# Step 47/125; Loss = 0.2349
# Step 48/125; Loss = 0.1855
# Step 49/125; Loss = 0.2724
# Step 50/125; Loss = 0.1801
# Step 51/125; Loss = 0.2474
# Step 52/125; Loss = 0.2921
# Step 53/125; Loss = 0.2274
# Step 54/125; Loss = 0.1972
# Step 55/125; Loss = 0.2611
# Step 56/125; Loss = 0.1973
# Step 57/125; Loss = 0.2988
# Step 58/125; Loss = 0.2080
# Step 59/125; Loss = 0.2034
# Step 60/125; Loss = 0.2221
# Step 61/125; Loss = 0.2515
# Step 62/125; Loss = 0.2209
# Step 63/125; Loss = 0.1985
# Step 64/125; Loss = 0.1985
# Step 65/125; Loss = 0.2017
# Step 66/125; Loss = 0.2407
# Step 67/125; Loss = 0.1721
# Step 68/125; Loss = 0.1866
# Step 69/125; Loss = 0.1972
# Step 70/125; Loss = 0.2196
# Step 71/125; Loss = 0.1928
# Step 72/125; Loss = 0.2317
# Step 73/125; Loss = 0.2745
# Step 74/125; Loss = 0.2293
# Step 75/125; Loss = 0.2087
# Step 76/125; Loss = 0.2102
# Step 77/125; Loss = 0.2109
# Step 78/125; Loss = 0.3029
# Step 79/125; Loss = 0.2148
# Step 80/125; Loss = 0.2510
# Step 81/125; Loss = 0.2164
# Step 82/125; Loss = 0.2283
# Step 83/125; Loss = 0.2092
# Step 84/125; Loss = 0.2193
# Step 85/125; Loss = 0.2202
# Step 86/125; Loss = 0.1956
# Step 87/125; Loss = 0.2159
# Step 88/125; Loss = 0.2302
# Step 89/125; Loss = 0.2568
# Step 90/125; Loss = 0.2687
# Step 91/125; Loss = 0.2086
# Step 92/125; Loss = 0.1544
# Step 93/125; Loss = 0.2398
# Step 94/125; Loss = 0.2217
# Step 95/125; Loss = 0.2055
# Step 96/125; Loss = 0.1999
# Step 97/125; Loss = 0.1937
# Step 98/125; Loss = 0.1909
# Step 99/125; Loss = 0.3083
# Step 100/125; Loss = 0.2781
# Step 101/125; Loss = 0.2375
# Step 102/125; Loss = 0.2645
# Step 103/125; Loss = 0.2624
# Step 104/125; Loss = 0.1786
# Step 105/125; Loss = 0.1856
# Step 106/125; Loss = 0.2387
# Step 107/125; Loss = 0.2317
# Step 108/125; Loss = 0.1857
# Step 109/125; Loss = 0.2128
# Step 110/125; Loss = 0.2340
# Step 111/125; Loss = 0.2139
# Step 112/125; Loss = 0.1902
# Step 113/125; Loss = 0.2175
# Step 114/125; Loss = 0.2428
# Step 115/125; Loss = 0.2422
# Step 116/125; Loss = 0.1906
# Step 117/125; Loss = 0.2279
# Step 118/125; Loss = 0.2053
# Step 119/125; Loss = 0.2601
# Step 120/125; Loss = 0.1866
# Step 121/125; Loss = 0.2096
# Step 122/125; Loss = 0.2241
# Step 123/125; Loss = 0.1900
# Step 124/125; Loss = 0.2304
# Step 125/125; Loss = 0.2438
# SAVED MODEL WEIGHTS
# Validation IoU Score: 0.6496
# Validation Dice Score: 0.7876
# --------------------
# Epoch 10/20; LR = 0.005038847999999999
# Step 1/125; Loss = 0.2189
# Step 2/125; Loss = 0.2069
# Step 3/125; Loss = 0.1868
# Step 4/125; Loss = 0.2868
# Step 5/125; Loss = 0.2179
# Step 6/125; Loss = 0.2120
# Step 7/125; Loss = 0.2039
# Step 8/125; Loss = 0.2753
# Step 9/125; Loss = 0.2147
# Step 10/125; Loss = 0.2417
# Step 11/125; Loss = 0.2008
# Step 12/125; Loss = 0.2514
# Step 13/125; Loss = 0.1880
# Step 14/125; Loss = 0.1964
# Step 15/125; Loss = 0.1818
# Step 16/125; Loss = 0.2157
# Step 17/125; Loss = 0.1977
# Step 18/125; Loss = 0.2305
# Step 19/125; Loss = 0.2344
# Step 20/125; Loss = 0.2290
# Step 21/125; Loss = 0.2015
# Step 22/125; Loss = 0.2798
# Step 23/125; Loss = 0.2272
# Step 24/125; Loss = 0.2115
# Step 25/125; Loss = 0.2501
# Step 26/125; Loss = 0.2065
# Step 27/125; Loss = 0.1665
# Step 28/125; Loss = 0.2126
# Step 29/125; Loss = 0.2256
# Step 30/125; Loss = 0.2014
# Step 31/125; Loss = 0.2226
# Step 32/125; Loss = 0.2233
# Step 33/125; Loss = 0.2154
# Step 34/125; Loss = 0.1973
# Step 35/125; Loss = 0.1586
# Step 36/125; Loss = 0.2064
# Step 37/125; Loss = 0.1989
# Step 38/125; Loss = 0.1931
# Step 39/125; Loss = 0.2176
# Step 40/125; Loss = 0.2135
# Step 41/125; Loss = 0.2039
# Step 42/125; Loss = 0.1947
# Step 43/125; Loss = 0.2254
# Step 44/125; Loss = 0.1760
# Step 45/125; Loss = 0.2237
# Step 46/125; Loss = 0.2190
# Step 47/125; Loss = 0.2099
# Step 48/125; Loss = 0.2252
# Step 49/125; Loss = 0.2012
# Step 50/125; Loss = 0.2022
# Step 51/125; Loss = 0.2335
# Step 52/125; Loss = 0.2010
# Step 53/125; Loss = 0.1709
# Step 54/125; Loss = 0.2288
# Step 55/125; Loss = 0.1969
# Step 56/125; Loss = 0.2076
# Step 57/125; Loss = 0.1895
# Step 58/125; Loss = 0.1882
# Step 59/125; Loss = 0.2814
# Step 60/125; Loss = 0.2435
# Step 61/125; Loss = 0.1906
# Step 62/125; Loss = 0.2654
# Step 63/125; Loss = 0.2016
# Step 64/125; Loss = 0.1806
# Step 65/125; Loss = 0.2071
# Step 66/125; Loss = 0.2153
# Step 67/125; Loss = 0.2058
# Step 68/125; Loss = 0.2082
# Step 69/125; Loss = 0.1946
# Step 70/125; Loss = 0.2024
# Step 71/125; Loss = 0.2132
# Step 72/125; Loss = 0.2015
# Step 73/125; Loss = 0.1992
# Step 74/125; Loss = 0.1829
# Step 75/125; Loss = 0.1970
# Step 76/125; Loss = 0.2559
# Step 77/125; Loss = 0.2241
# Step 78/125; Loss = 0.1862
# Step 79/125; Loss = 0.2107
# Step 80/125; Loss = 0.2130
# Step 81/125; Loss = 0.2132
# Step 82/125; Loss = 0.2482
# Step 83/125; Loss = 0.2130
# Step 84/125; Loss = 0.2145
# Step 85/125; Loss = 0.2048
# Step 86/125; Loss = 0.1774
# Step 87/125; Loss = 0.2441
# Step 88/125; Loss = 0.2119
# Step 89/125; Loss = 0.2130
# Step 90/125; Loss = 0.2162
# Step 91/125; Loss = 0.2042
# Step 92/125; Loss = 0.2380
# Step 93/125; Loss = 0.2080
# Step 94/125; Loss = 0.2004
# Step 95/125; Loss = 0.2302
# Step 96/125; Loss = 0.1818
# Step 97/125; Loss = 0.1672
# Step 98/125; Loss = 0.2295
# Step 99/125; Loss = 0.2338
# Step 100/125; Loss = 0.2406
# Step 101/125; Loss = 0.2072
# Step 102/125; Loss = 0.2201
# Step 103/125; Loss = 0.2140
# Step 104/125; Loss = 0.2782
# Step 105/125; Loss = 0.1975
# Step 106/125; Loss = 0.2006
# Step 107/125; Loss = 0.2087
# Step 108/125; Loss = 0.2188
# Step 109/125; Loss = 0.2133
# Step 110/125; Loss = 0.1784
# Step 111/125; Loss = 0.1905
# Step 112/125; Loss = 0.2395
# Step 113/125; Loss = 0.2543
# Step 114/125; Loss = 0.2234
# Step 115/125; Loss = 0.1894
# Step 116/125; Loss = 0.1819
# Step 117/125; Loss = 0.1933
# Step 118/125; Loss = 0.1797
# Step 119/125; Loss = 0.2222
# Step 120/125; Loss = 0.1672
# Step 121/125; Loss = 0.1866
# Step 122/125; Loss = 0.1866
# Step 123/125; Loss = 0.2070
# Step 124/125; Loss = 0.2071
# Step 125/125; Loss = 0.1907
# SAVED MODEL WEIGHTS
# Validation IoU Score: 0.6611
# Validation Dice Score: 0.7960
# --------------------
# Epoch 11/20; LR = 0.0030233087999999996
# Step 1/125; Loss = 0.2377
# Step 2/125; Loss = 0.1667
# Step 3/125; Loss = 0.2101
# Step 4/125; Loss = 0.2182
# Step 5/125; Loss = 0.2294
# Step 6/125; Loss = 0.1894
# Step 7/125; Loss = 0.1878
# Step 8/125; Loss = 0.2078
# Step 9/125; Loss = 0.2041
# Step 10/125; Loss = 0.1896
# Step 11/125; Loss = 0.2901
# Step 12/125; Loss = 0.1691
# Step 13/125; Loss = 0.2227
# Step 14/125; Loss = 0.2085
# Step 15/125; Loss = 0.1930
# Step 16/125; Loss = 0.2104
# Step 17/125; Loss = 0.1927
# Step 18/125; Loss = 0.2585
# Step 19/125; Loss = 0.1746
# Step 20/125; Loss = 0.1947
# Step 21/125; Loss = 0.1876
# Step 22/125; Loss = 0.2009
# Step 23/125; Loss = 0.1935
# Step 24/125; Loss = 0.1890
# Step 25/125; Loss = 0.1912
# Step 26/125; Loss = 0.1706
# Step 27/125; Loss = 0.1886
# Step 28/125; Loss = 0.1988
# Step 29/125; Loss = 0.1537
# Step 30/125; Loss = 0.1818
# Step 31/125; Loss = 0.1996
# Step 32/125; Loss = 0.1642
# Step 33/125; Loss = 0.1976
# Step 34/125; Loss = 0.2162
# Step 35/125; Loss = 0.2038
# Step 36/125; Loss = 0.2219
# Step 37/125; Loss = 0.1771
# Step 38/125; Loss = 0.2444
# Step 39/125; Loss = 0.1899
# Step 40/125; Loss = 0.1793
# Step 41/125; Loss = 0.2046
# Step 42/125; Loss = 0.1885
# Step 43/125; Loss = 0.2225
# Step 44/125; Loss = 0.1898
# Step 45/125; Loss = 0.2076
# Step 46/125; Loss = 0.2047
# Step 47/125; Loss = 0.1969
# Step 48/125; Loss = 0.1915
# Step 49/125; Loss = 0.1809
# Step 50/125; Loss = 0.1695
# Step 51/125; Loss = 0.2349
# Step 52/125; Loss = 0.2626
# Step 53/125; Loss = 0.2191
# Step 54/125; Loss = 0.2080
# Step 55/125; Loss = 0.1656
# Step 56/125; Loss = 0.1756
# Step 57/125; Loss = 0.2656
# Step 58/125; Loss = 0.2204
# Step 59/125; Loss = 0.2212
# Step 60/125; Loss = 0.1839
# Step 61/125; Loss = 0.1756
# Step 62/125; Loss = 0.2304
# Step 63/125; Loss = 0.2096
# Step 64/125; Loss = 0.2026
# Step 65/125; Loss = 0.1883
# Step 66/125; Loss = 0.2402
# Step 67/125; Loss = 0.1688
# Step 68/125; Loss = 0.2077
# Step 69/125; Loss = 0.2024
# Step 70/125; Loss = 0.1979
# Step 71/125; Loss = 0.1965
# Step 72/125; Loss = 0.2078
# Step 73/125; Loss = 0.2165
# Step 74/125; Loss = 0.2731
# Step 75/125; Loss = 0.1818
# Step 76/125; Loss = 0.1842
# Step 77/125; Loss = 0.2443
# Step 78/125; Loss = 0.1846
# Step 79/125; Loss = 0.2131
# Step 80/125; Loss = 0.1736
# Step 81/125; Loss = 0.1824
# Step 82/125; Loss = 0.1803
# Step 83/125; Loss = 0.1922
# Step 84/125; Loss = 0.1837
# Step 85/125; Loss = 0.2041
# Step 86/125; Loss = 0.1830
# Step 87/125; Loss = 0.2837
# Step 88/125; Loss = 0.1820
# Step 89/125; Loss = 0.1611
# Step 90/125; Loss = 0.1694
# Step 91/125; Loss = 0.1751
# Step 92/125; Loss = 0.2032
# Step 93/125; Loss = 0.2244
# Step 94/125; Loss = 0.1913
# Step 95/125; Loss = 0.1728
# Step 96/125; Loss = 0.1679
# Step 97/125; Loss = 0.1959
# Step 98/125; Loss = 0.2041
# Step 99/125; Loss = 0.1615
# Step 100/125; Loss = 0.1915
# Step 101/125; Loss = 0.1923
# Step 102/125; Loss = 0.2338
# Step 103/125; Loss = 0.2191
# Step 104/125; Loss = 0.2057
# Step 105/125; Loss = 0.1777
# Step 106/125; Loss = 0.2061
# Step 107/125; Loss = 0.1973
# Step 108/125; Loss = 0.3229
# Step 109/125; Loss = 0.2208
# Step 110/125; Loss = 0.2230
# Step 111/125; Loss = 0.2124
# Step 112/125; Loss = 0.1858
# Step 113/125; Loss = 0.2493
# Step 114/125; Loss = 0.2156
# Step 115/125; Loss = 0.1807
# Step 116/125; Loss = 0.1832
# Step 117/125; Loss = 0.2038
# Step 118/125; Loss = 0.2365
# Step 119/125; Loss = 0.2329
# Step 120/125; Loss = 0.1838
# Step 121/125; Loss = 0.2452
# Step 122/125; Loss = 0.1952
# Step 123/125; Loss = 0.1671
# Step 124/125; Loss = 0.2268
# Step 125/125; Loss = 0.2080
# SAVED MODEL WEIGHTS
# Validation IoU Score: 0.6889
# Validation Dice Score: 0.8158
# --------------------
# Epoch 12/20; LR = 0.0018139852799999997
# Step 1/125; Loss = 0.1650
# Step 2/125; Loss = 0.1987
# Step 3/125; Loss = 0.1821
# Step 4/125; Loss = 0.2119
# Step 5/125; Loss = 0.1862
# Step 6/125; Loss = 0.2252
# Step 7/125; Loss = 0.2001
# Step 8/125; Loss = 0.1987
# Step 9/125; Loss = 0.1927
# Step 10/125; Loss = 0.3022
# Step 11/125; Loss = 0.2685
# Step 12/125; Loss = 0.2085
# Step 13/125; Loss = 0.1963
# Step 14/125; Loss = 0.1626
# Step 15/125; Loss = 0.1946
# Step 16/125; Loss = 0.1935
# Step 17/125; Loss = 0.2054
# Step 18/125; Loss = 0.2287
# Step 19/125; Loss = 0.1952
# Step 20/125; Loss = 0.1716
# Step 21/125; Loss = 0.1675
# Step 22/125; Loss = 0.2034
# Step 23/125; Loss = 0.1934
# Step 24/125; Loss = 0.1865
# Step 25/125; Loss = 0.1614
# Step 26/125; Loss = 0.1807
# Step 27/125; Loss = 0.1693
# Step 28/125; Loss = 0.2065
# Step 29/125; Loss = 0.1825
# Step 30/125; Loss = 0.1836
# Step 31/125; Loss = 0.2857
# Step 32/125; Loss = 0.2008
# Step 33/125; Loss = 0.1784
# Step 34/125; Loss = 0.1979
# Step 35/125; Loss = 0.2119
# Step 36/125; Loss = 0.1973
# Step 37/125; Loss = 0.2041
# Step 38/125; Loss = 0.1695
# Step 39/125; Loss = 0.1900
# Step 40/125; Loss = 0.2045
# Step 41/125; Loss = 0.1672
# Step 42/125; Loss = 0.1683
# Step 43/125; Loss = 0.1921
# Step 44/125; Loss = 0.1715
# Step 45/125; Loss = 0.1853
# Step 46/125; Loss = 0.1718
# Step 47/125; Loss = 0.1966
# Step 48/125; Loss = 0.1817
# Step 49/125; Loss = 0.1822
# Step 50/125; Loss = 0.1815
# Step 51/125; Loss = 0.2186
# Step 52/125; Loss = 0.1802
# Step 53/125; Loss = 0.2411
# Step 54/125; Loss = 0.1768
# Step 55/125; Loss = 0.1681
# Step 56/125; Loss = 0.2090
# Step 57/125; Loss = 0.1702
# Step 58/125; Loss = 0.1965
# Step 59/125; Loss = 0.2152
# Step 60/125; Loss = 0.1947
# Step 61/125; Loss = 0.1775
# Step 62/125; Loss = 0.2141
# Step 63/125; Loss = 0.1811
# Step 64/125; Loss = 0.1691
# Step 65/125; Loss = 0.1900
# Step 66/125; Loss = 0.1862
# Step 67/125; Loss = 0.2366
# Step 68/125; Loss = 0.1839
# Step 69/125; Loss = 0.2545
# Step 70/125; Loss = 0.1938
# Step 71/125; Loss = 0.1607
# Step 72/125; Loss = 0.1659
# Step 73/125; Loss = 0.2266
# Step 74/125; Loss = 0.1732
# Step 75/125; Loss = 0.2109
# Step 76/125; Loss = 0.2069
# Step 77/125; Loss = 0.1760
# Step 78/125; Loss = 0.1838
# Step 79/125; Loss = 0.2447
# Step 80/125; Loss = 0.2515
# Step 81/125; Loss = 0.2400
# Step 82/125; Loss = 0.1822
# Step 83/125; Loss = 0.1948
# Step 84/125; Loss = 0.1663
# Step 85/125; Loss = 0.2066
# Step 86/125; Loss = 0.1803
# Step 87/125; Loss = 0.1853
# Step 88/125; Loss = 0.2057
# Step 89/125; Loss = 0.1624
# Step 90/125; Loss = 0.2228
# Step 91/125; Loss = 0.1987
# Step 92/125; Loss = 0.2392
# Step 93/125; Loss = 0.2113
# Step 94/125; Loss = 0.2276
# Step 95/125; Loss = 0.2100
# Step 96/125; Loss = 0.2039
# Step 97/125; Loss = 0.1854
# Step 98/125; Loss = 0.1854
# Step 99/125; Loss = 0.2140
# Step 100/125; Loss = 0.2075
# Step 101/125; Loss = 0.1743
# Step 102/125; Loss = 0.2678
# Step 103/125; Loss = 0.2509
# Step 104/125; Loss = 0.1871
# Step 105/125; Loss = 0.1861
# Step 106/125; Loss = 0.1734
# Step 107/125; Loss = 0.1895
# Step 108/125; Loss = 0.1887
# Step 109/125; Loss = 0.1797
# Step 110/125; Loss = 0.2011
# Step 111/125; Loss = 0.1689
# Step 112/125; Loss = 0.1947
# Step 113/125; Loss = 0.1852
# Step 114/125; Loss = 0.3189
# Step 115/125; Loss = 0.1987
# Step 116/125; Loss = 0.2207
# Step 117/125; Loss = 0.1896
# Step 118/125; Loss = 0.1819
# Step 119/125; Loss = 0.1898
# Step 120/125; Loss = 0.1976
# Step 121/125; Loss = 0.1900
# Step 122/125; Loss = 0.2211
# Step 123/125; Loss = 0.2103
# Step 124/125; Loss = 0.1849
# Step 125/125; Loss = 0.1869
# Validation IoU Score: 0.6880
# Validation Dice Score: 0.8151
# --------------------
# Epoch 13/20; LR = 0.0010883911679999997
# Step 1/125; Loss = 0.1719
# Step 2/125; Loss = 0.1758
# Step 3/125; Loss = 0.1984
# Step 4/125; Loss = 0.1800
# Step 5/125; Loss = 0.1780
# Step 6/125; Loss = 0.1906
# Step 7/125; Loss = 0.2071
# Step 8/125; Loss = 0.1685
# Step 9/125; Loss = 0.2183
# Step 10/125; Loss = 0.2427
# Step 11/125; Loss = 0.1650
# Step 12/125; Loss = 0.2341
# Step 13/125; Loss = 0.1740
# Step 14/125; Loss = 0.2081
# Step 15/125; Loss = 0.1870
# Step 16/125; Loss = 0.1977
# Step 17/125; Loss = 0.1620
# Step 18/125; Loss = 0.2018
# Step 19/125; Loss = 0.2083
# Step 20/125; Loss = 0.1850
# Step 21/125; Loss = 0.1740
# Step 22/125; Loss = 0.1759
# Step 23/125; Loss = 0.2030
# Step 24/125; Loss = 0.1815
# Step 25/125; Loss = 0.1926
# Step 26/125; Loss = 0.2001
# Step 27/125; Loss = 0.1936
# Step 28/125; Loss = 0.1690
# Step 29/125; Loss = 0.1878
# Step 30/125; Loss = 0.1866
# Step 31/125; Loss = 0.2434
# Step 32/125; Loss = 0.1588
# Step 33/125; Loss = 0.2358
# Step 34/125; Loss = 0.2330
# Step 35/125; Loss = 0.2052
# Step 36/125; Loss = 0.1896
# Step 37/125; Loss = 0.1666
# Step 38/125; Loss = 0.1742
# Step 39/125; Loss = 0.1999
# Step 40/125; Loss = 0.2557
# Step 41/125; Loss = 0.1711
# Step 42/125; Loss = 0.2004
# Step 43/125; Loss = 0.2461
# Step 44/125; Loss = 0.1656
# Step 45/125; Loss = 0.1877
# Step 46/125; Loss = 0.1897
# Step 47/125; Loss = 0.1954
# Step 48/125; Loss = 0.1939
# Step 49/125; Loss = 0.2037
# Step 50/125; Loss = 0.2086
# Step 51/125; Loss = 0.2157
# Step 52/125; Loss = 0.1947
# Step 53/125; Loss = 0.1706
# Step 54/125; Loss = 0.2095
# Step 55/125; Loss = 0.1609
# Step 56/125; Loss = 0.1830
# Step 57/125; Loss = 0.1785
# Step 58/125; Loss = 0.2056
# Step 59/125; Loss = 0.1639
# Step 60/125; Loss = 0.1958
# Step 61/125; Loss = 0.1814
# Step 62/125; Loss = 0.2028
# Step 63/125; Loss = 0.1709
# Step 64/125; Loss = 0.1760
# Step 65/125; Loss = 0.1975
# Step 66/125; Loss = 0.1724
# Step 67/125; Loss = 0.1531
# Step 68/125; Loss = 0.1762
# Step 69/125; Loss = 0.2228
# Step 70/125; Loss = 0.1661
# Step 71/125; Loss = 0.1727
# Step 72/125; Loss = 0.1744
# Step 73/125; Loss = 0.1754
# Step 74/125; Loss = 0.1855
# Step 75/125; Loss = 0.1770
# Step 76/125; Loss = 0.2130
# Step 77/125; Loss = 0.1885
# Step 78/125; Loss = 0.1789
# Step 79/125; Loss = 0.2036
# Step 80/125; Loss = 0.1689
# Step 81/125; Loss = 0.2237
# Step 82/125; Loss = 0.1613
# Step 83/125; Loss = 0.1922
# Step 84/125; Loss = 0.1979
# Step 85/125; Loss = 0.1645
# Step 86/125; Loss = 0.2137
# Step 87/125; Loss = 0.2366
# Step 88/125; Loss = 0.1723
# Step 89/125; Loss = 0.2385
# Step 90/125; Loss = 0.1785
# Step 91/125; Loss = 0.1756
# Step 92/125; Loss = 0.1821
# Step 93/125; Loss = 0.1731
# Step 94/125; Loss = 0.2130
# Step 95/125; Loss = 0.1661
# Step 96/125; Loss = 0.2419
# Step 97/125; Loss = 0.1993
# Step 98/125; Loss = 0.1832
# Step 99/125; Loss = 0.1805
# Step 100/125; Loss = 0.1830
# Step 101/125; Loss = 0.1868
# Step 102/125; Loss = 0.2116
# Step 103/125; Loss = 0.1904
# Step 104/125; Loss = 0.2516
# Step 105/125; Loss = 0.1973
# Step 106/125; Loss = 0.1938
# Step 107/125; Loss = 0.1820
# Step 108/125; Loss = 0.1829
# Step 109/125; Loss = 0.2512
# Step 110/125; Loss = 0.1598
# Step 111/125; Loss = 0.2004
# Step 112/125; Loss = 0.2149
# Step 113/125; Loss = 0.2243
# Step 114/125; Loss = 0.1984
# Step 115/125; Loss = 0.1847
# Step 116/125; Loss = 0.2025
# Step 117/125; Loss = 0.1865
# Step 118/125; Loss = 0.1858
# Step 119/125; Loss = 0.1866
# Step 120/125; Loss = 0.2152
# Step 121/125; Loss = 0.1699
# Step 122/125; Loss = 0.1775
# Step 123/125; Loss = 0.1714
# Step 124/125; Loss = 0.2537
# Step 125/125; Loss = 0.1824
# SAVED MODEL WEIGHTS
# Validation IoU Score: 0.6957
# Validation Dice Score: 0.8206
# --------------------
# Epoch 14/20; LR = 0.0006530347007999998
# Step 1/125; Loss = 0.1861
# Step 2/125; Loss = 0.1652
# Step 3/125; Loss = 0.1666
# Step 4/125; Loss = 0.1980
# Step 5/125; Loss = 0.1891
# Step 6/125; Loss = 0.2079
# Step 7/125; Loss = 0.1692
# Step 8/125; Loss = 0.1754
# Step 9/125; Loss = 0.2059
# Step 10/125; Loss = 0.2028
# Step 11/125; Loss = 0.1757
# Step 12/125; Loss = 0.2391
# Step 13/125; Loss = 0.1831
# Step 14/125; Loss = 0.1677
# Step 15/125; Loss = 0.2198
# Step 16/125; Loss = 0.2157
# Step 17/125; Loss = 0.1995
# Step 18/125; Loss = 0.1683
# Step 19/125; Loss = 0.1938
# Step 20/125; Loss = 0.1742
# Step 21/125; Loss = 0.1871
# Step 22/125; Loss = 0.1965
# Step 23/125; Loss = 0.1932
# Step 24/125; Loss = 0.2454
# Step 25/125; Loss = 0.2109
# Step 26/125; Loss = 0.1844
# Step 27/125; Loss = 0.2222
# Step 28/125; Loss = 0.1782
# Step 29/125; Loss = 0.1540
# Step 30/125; Loss = 0.1670
# Step 31/125; Loss = 0.1970
# Step 32/125; Loss = 0.1667
# Step 33/125; Loss = 0.1850
# Step 34/125; Loss = 0.2045
# Step 35/125; Loss = 0.1873
# Step 36/125; Loss = 0.2047
# Step 37/125; Loss = 0.2027
# Step 38/125; Loss = 0.1668
# Step 39/125; Loss = 0.2496
# Step 40/125; Loss = 0.1607
# Step 41/125; Loss = 0.2063
# Step 42/125; Loss = 0.1701
# Step 43/125; Loss = 0.2017
# Step 44/125; Loss = 0.1655
# Step 45/125; Loss = 0.1994
# Step 46/125; Loss = 0.1970
# Step 47/125; Loss = 0.1909
# Step 48/125; Loss = 0.2392
# Step 49/125; Loss = 0.1782
# Step 50/125; Loss = 0.1845
# Step 51/125; Loss = 0.2331
# Step 52/125; Loss = 0.1809
# Step 53/125; Loss = 0.1684
# Step 54/125; Loss = 0.2003
# Step 55/125; Loss = 0.1749
# Step 56/125; Loss = 0.1770
# Step 57/125; Loss = 0.1833
# Step 58/125; Loss = 0.1752
# Step 59/125; Loss = 0.1880
# Step 60/125; Loss = 0.1720
# Step 61/125; Loss = 0.1837
# Step 62/125; Loss = 0.1883
# Step 63/125; Loss = 0.2012
# Step 64/125; Loss = 0.1803
# Step 65/125; Loss = 0.2260
# Step 66/125; Loss = 0.1648
# Step 67/125; Loss = 0.1772
# Step 68/125; Loss = 0.1751
# Step 69/125; Loss = 0.1921
# Step 70/125; Loss = 0.2230
# Step 71/125; Loss = 0.1987
# Step 72/125; Loss = 0.1839
# Step 73/125; Loss = 0.1695
# Step 74/125; Loss = 0.1623
# Step 75/125; Loss = 0.2082
# Step 76/125; Loss = 0.1610
# Step 77/125; Loss = 0.1600
# Step 78/125; Loss = 0.2423
# Step 79/125; Loss = 0.2023
# Step 80/125; Loss = 0.1852
# Step 81/125; Loss = 0.1680
# Step 82/125; Loss = 0.1721
# Step 83/125; Loss = 0.1868
# ...
# Step 60/125; Loss = 0.2198
# Step 61/125; Loss = 0.2087
# Step 62/125; Loss = 0.2120
# Step 63/125; Loss = 0.2033
# Step 64/125; Loss = 0.1624
# Step 65/125; Loss = 0.2290
# Step 66/125; Loss = 0.1956
# Step 67/125; Loss = 0.1950
# Step 68/125; Loss = 0.1736
# Step 69/125; Loss = 0.2024
# Step 70/125; Loss = 0.2103
# Step 71/125; Loss = 0.1839
# Step 72/125; Loss = 0.1969
# Step 73/125; Loss = 0.2247
# Step 74/125; Loss = 0.1568
# Step 75/125; Loss = 0.2214
# Step 76/125; Loss = 0.1736
# Step 77/125; Loss = 0.2632
# Step 78/125; Loss = 0.1557
# Step 79/125; Loss = 0.1938
# Step 80/125; Loss = 0.1989
# Step 81/125; Loss = 0.1845
# Step 82/125; Loss = 0.1912
# Step 83/125; Loss = 0.1790
# Step 84/125; Loss = 0.1835
# Step 85/125; Loss = 0.1803
# Step 86/125; Loss = 0.1895
# Step 87/125; Loss = 0.1744
# Step 88/125; Loss = 0.1948
# Step 89/125; Loss = 0.2123
# Step 90/125; Loss = 0.2002
# Step 91/125; Loss = 0.1832
# Step 92/125; Loss = 0.1707
# Step 93/125; Loss = 0.1646
# Step 94/125; Loss = 0.2169
# Step 95/125; Loss = 0.2063
# Step 96/125; Loss = 0.2095
# Step 97/125; Loss = 0.1724
# Step 98/125; Loss = 0.1575
# Step 99/125; Loss = 0.2025
# Step 100/125; Loss = 0.1858
# Step 101/125; Loss = 0.2201
# Step 102/125; Loss = 0.1786
# Step 103/125; Loss = 0.2053
# Step 104/125; Loss = 0.1861
# Step 105/125; Loss = 0.1651
# Step 106/125; Loss = 0.1663
# Step 107/125; Loss = 0.1792
# Step 108/125; Loss = 0.1995
# Step 109/125; Loss = 0.2079
# Step 110/125; Loss = 0.1989
# Step 111/125; Loss = 0.1786
# Step 112/125; Loss = 0.2292
# Step 113/125; Loss = 0.1802
# Step 114/125; Loss = 0.1921
# Step 115/125; Loss = 0.1763
# Step 116/125; Loss = 0.1877
# Step 117/125; Loss = 0.1822
# Step 118/125; Loss = 0.2533
# Step 119/125; Loss = 0.2334
# Step 120/125; Loss = 0.1905
# Step 121/125; Loss = 0.1728
# Step 122/125; Loss = 0.1917
# Step 123/125; Loss = 0.1948
# Step 124/125; Loss = 0.1700
# Step 125/125; Loss = 0.1848
# SAVED MODEL WEIGHTS
# Validation IoU Score: 0.7036
# Validation Dice Score: 0.8260
# --------------------
# Epoch 17/20; LR = 0.00014105549537279992
# Step 1/125; Loss = 0.2110
# Step 2/125; Loss = 0.1687
# Step 3/125; Loss = 0.2002
# Step 4/125; Loss = 0.1847
# Step 5/125; Loss = 0.1727
# Step 6/125; Loss = 0.1958
# Step 7/125; Loss = 0.1928
# Step 8/125; Loss = 0.2060
# Step 9/125; Loss = 0.1771
# Step 10/125; Loss = 0.1761
# Step 11/125; Loss = 0.2355
# Step 12/125; Loss = 0.1679
# Step 13/125; Loss = 0.2101
# Step 14/125; Loss = 0.2029
# Step 15/125; Loss = 0.1967
# Step 16/125; Loss = 0.1810
# Step 17/125; Loss = 0.2318
# Step 18/125; Loss = 0.1755
# Step 19/125; Loss = 0.2325
# Step 20/125; Loss = 0.1989
# Step 21/125; Loss = 0.1973
# Step 22/125; Loss = 0.1771
# Step 23/125; Loss = 0.1559
# Step 24/125; Loss = 0.1757
# Step 25/125; Loss = 0.1936
# Step 26/125; Loss = 0.1563
# Step 27/125; Loss = 0.1711
# Step 28/125; Loss = 0.2338
# Step 29/125; Loss = 0.1760
# Step 30/125; Loss = 0.1728
# Step 31/125; Loss = 0.1955
# Step 32/125; Loss = 0.1598
# Step 33/125; Loss = 0.1829
# Step 34/125; Loss = 0.2119
# Step 35/125; Loss = 0.1775
# Step 36/125; Loss = 0.1698
# Step 37/125; Loss = 0.1728
# Step 38/125; Loss = 0.1653
# Step 39/125; Loss = 0.2016
# Step 40/125; Loss = 0.1846
# Step 41/125; Loss = 0.2093
# Step 42/125; Loss = 0.1623
# Step 43/125; Loss = 0.1881
# Step 44/125; Loss = 0.1628
# Step 45/125; Loss = 0.1717
# Step 46/125; Loss = 0.1853
# Step 47/125; Loss = 0.1868
# Step 48/125; Loss = 0.1800
# Step 49/125; Loss = 0.1709
# Step 50/125; Loss = 0.2074
# Step 51/125; Loss = 0.2059
# Step 52/125; Loss = 0.1661
# Step 53/125; Loss = 0.1714
# Step 54/125; Loss = 0.1866
# Step 55/125; Loss = 0.2347
# Step 56/125; Loss = 0.2022
# Step 57/125; Loss = 0.1831
# Step 58/125; Loss = 0.2154
# Step 59/125; Loss = 0.1728
# Step 60/125; Loss = 0.1839
# Step 61/125; Loss = 0.1926
# Step 62/125; Loss = 0.1655
# Step 63/125; Loss = 0.1850
# Step 64/125; Loss = 0.1666
# Step 65/125; Loss = 0.2160
# Step 66/125; Loss = 0.1883
# Step 67/125; Loss = 0.1587
# Step 68/125; Loss = 0.1990
# Step 69/125; Loss = 0.1639
# Step 70/125; Loss = 0.1847
# Step 71/125; Loss = 0.1688
# Step 72/125; Loss = 0.1843
# Step 73/125; Loss = 0.1682
# Step 74/125; Loss = 0.2040
# Step 75/125; Loss = 0.1753
# Step 76/125; Loss = 0.2003
# Step 77/125; Loss = 0.1642
# Step 78/125; Loss = 0.1990
# Step 79/125; Loss = 0.1832
# Step 80/125; Loss = 0.1871
# Step 81/125; Loss = 0.1771
# Step 82/125; Loss = 0.1961
# Step 83/125; Loss = 0.1987
# Step 84/125; Loss = 0.2451
# Step 85/125; Loss = 0.1745
# Step 86/125; Loss = 0.1776
# Step 87/125; Loss = 0.2147
# Step 88/125; Loss = 0.2009
# Step 89/125; Loss = 0.2136
# Step 90/125; Loss = 0.1585
# Step 91/125; Loss = 0.1770
# Step 92/125; Loss = 0.1768
# Step 93/125; Loss = 0.1637
# Step 94/125; Loss = 0.1857
# Step 95/125; Loss = 0.1897
# Step 96/125; Loss = 0.1854
# Step 97/125; Loss = 0.1711
# Step 98/125; Loss = 0.1805
# Step 99/125; Loss = 0.1887
# Step 100/125; Loss = 0.1668
# Step 101/125; Loss = 0.1694
# Step 102/125; Loss = 0.1376
# Step 103/125; Loss = 0.1962
# Step 104/125; Loss = 0.2073
# Step 105/125; Loss = 0.1766
# Step 106/125; Loss = 0.1827
# Step 107/125; Loss = 0.1604
# Step 108/125; Loss = 0.1754
# Step 109/125; Loss = 0.2513
# Step 110/125; Loss = 0.2189
# Step 111/125; Loss = 0.2703
# Step 112/125; Loss = 0.1903
# Step 113/125; Loss = 0.1853
# Step 114/125; Loss = 0.1646
# Step 115/125; Loss = 0.1782
# Step 116/125; Loss = 0.2076
# Step 117/125; Loss = 0.2193
# Step 118/125; Loss = 0.1839
# Step 119/125; Loss = 0.2112
# Step 120/125; Loss = 0.1598
# Step 121/125; Loss = 0.2122
# Step 122/125; Loss = 0.1531
# Step 123/125; Loss = 0.1819
# Step 124/125; Loss = 0.2211
# Step 125/125; Loss = 0.2040
# Validation IoU Score: 0.7018
# Validation Dice Score: 0.8248
# --------------------
# Epoch 18/20; LR = 8.463329722367995e-05
# Step 1/125; Loss = 0.1857
# Step 2/125; Loss = 0.1796
# Step 3/125; Loss = 0.2406
# Step 4/125; Loss = 0.1524
# Step 5/125; Loss = 0.1826
# Step 6/125; Loss = 0.1977
# Step 7/125; Loss = 0.1707
# Step 8/125; Loss = 0.1767
# Step 9/125; Loss = 0.1630
# Step 10/125; Loss = 0.1737
# Step 11/125; Loss = 0.1881
# Step 12/125; Loss = 0.1717
# Step 13/125; Loss = 0.1678
# Step 14/125; Loss = 0.1583
# Step 15/125; Loss = 0.1825
# Step 16/125; Loss = 0.1938
# Step 17/125; Loss = 0.1881
# Step 18/125; Loss = 0.1697
# Step 19/125; Loss = 0.2150
# Step 20/125; Loss = 0.1592
# Step 21/125; Loss = 0.1700
# Step 22/125; Loss = 0.2078
# Step 23/125; Loss = 0.2371
# Step 24/125; Loss = 0.1978
# Step 25/125; Loss = 0.2510
# Step 26/125; Loss = 0.1627
# Step 27/125; Loss = 0.2004
# Step 28/125; Loss = 0.1482
# Step 29/125; Loss = 0.1863
# Step 30/125; Loss = 0.2020
# Step 31/125; Loss = 0.2202
# Step 32/125; Loss = 0.2166
# Step 33/125; Loss = 0.1668
# Step 34/125; Loss = 0.1662
# Step 35/125; Loss = 0.1871
# Step 36/125; Loss = 0.1812
# Step 37/125; Loss = 0.1688
# Step 38/125; Loss = 0.2108
# Step 39/125; Loss = 0.1947
# Step 40/125; Loss = 0.1831
# Step 41/125; Loss = 0.1848
# Step 42/125; Loss = 0.1771
# Step 43/125; Loss = 0.1925
# Step 44/125; Loss = 0.2149
# Step 45/125; Loss = 0.1685
# Step 46/125; Loss = 0.2293
# Step 47/125; Loss = 0.1829
# Step 48/125; Loss = 0.1876
# Step 49/125; Loss = 0.1768
# Step 50/125; Loss = 0.1899
# Step 51/125; Loss = 0.2208
# Step 52/125; Loss = 0.2670
# Step 53/125; Loss = 0.2046
# Step 54/125; Loss = 0.2077
# Step 55/125; Loss = 0.1899
# Step 56/125; Loss = 0.1854
# Step 57/125; Loss = 0.1910
# Step 58/125; Loss = 0.2235
# Step 59/125; Loss = 0.2039
# Step 60/125; Loss = 0.1992
# Step 61/125; Loss = 0.1995
# Step 62/125; Loss = 0.1828
# Step 63/125; Loss = 0.1652
# Step 64/125; Loss = 0.1587
# Step 65/125; Loss = 0.1874
# Step 66/125; Loss = 0.1706
# Step 67/125; Loss = 0.1750
# Step 68/125; Loss = 0.1645
# Step 69/125; Loss = 0.1889
# Step 70/125; Loss = 0.2018
# Step 71/125; Loss = 0.1763
# Step 72/125; Loss = 0.1751
# Step 73/125; Loss = 0.1631
# Step 74/125; Loss = 0.1901
# Step 75/125; Loss = 0.1757
# Step 76/125; Loss = 0.1583
# Step 77/125; Loss = 0.1885
# Step 78/125; Loss = 0.1971
# Step 79/125; Loss = 0.1604
# Step 80/125; Loss = 0.1790
# Step 81/125; Loss = 0.1594
# Step 82/125; Loss = 0.1839
# Step 83/125; Loss = 0.1979
# Step 84/125; Loss = 0.2659
# Step 85/125; Loss = 0.1773
# Step 86/125; Loss = 0.1704
# Step 87/125; Loss = 0.2056
# Step 88/125; Loss = 0.1525
# Step 89/125; Loss = 0.1872
# Step 90/125; Loss = 0.1795
# Step 91/125; Loss = 0.2456
# Step 92/125; Loss = 0.2028
# Step 93/125; Loss = 0.1549
# Step 94/125; Loss = 0.2186
# Step 95/125; Loss = 0.1642
# Step 96/125; Loss = 0.1680
# Step 97/125; Loss = 0.2115
# Step 98/125; Loss = 0.2016
# Step 99/125; Loss = 0.1973
# Step 100/125; Loss = 0.2460
# Step 101/125; Loss = 0.2667
# Step 102/125; Loss = 0.2005
# Step 103/125; Loss = 0.1880
# Step 104/125; Loss = 0.1708
# Step 105/125; Loss = 0.1626
# Step 106/125; Loss = 0.2081
# Step 107/125; Loss = 0.1948
# Step 108/125; Loss = 0.1565
# Step 109/125; Loss = 0.1715
# Step 110/125; Loss = 0.1808
# Step 111/125; Loss = 0.1748
# Step 112/125; Loss = 0.2352
# Step 113/125; Loss = 0.1672
# Step 114/125; Loss = 0.2314
# Step 115/125; Loss = 0.2268
# Step 116/125; Loss = 0.1849
# Step 117/125; Loss = 0.2310
# Step 118/125; Loss = 0.1998
# Step 119/125; Loss = 0.1704
# Step 120/125; Loss = 0.1799
# Step 121/125; Loss = 0.2371
# Step 122/125; Loss = 0.1727
# Step 123/125; Loss = 0.2092
# Step 124/125; Loss = 0.1941
# Step 125/125; Loss = 0.1863
# Validation IoU Score: 0.6996
# Validation Dice Score: 0.8233
# --------------------
# Epoch 19/20; LR = 5.0779978334207974e-05
# Step 1/125; Loss = 0.1769
# Step 2/125; Loss = 0.1608
# Step 3/125; Loss = 0.1594
# Step 4/125; Loss = 0.2211
# Step 5/125; Loss = 0.2086
# Step 6/125; Loss = 0.1749
# Step 7/125; Loss = 0.2352
# Step 8/125; Loss = 0.1877
# Step 9/125; Loss = 0.2031
# Step 10/125; Loss = 0.1812
# Step 11/125; Loss = 0.1755
# Step 12/125; Loss = 0.1721
# Step 13/125; Loss = 0.2105
# Step 14/125; Loss = 0.1912
# Step 15/125; Loss = 0.1871
# Step 16/125; Loss = 0.1842
# Step 17/125; Loss = 0.1649
# Step 18/125; Loss = 0.2242
# Step 19/125; Loss = 0.1928
# Step 20/125; Loss = 0.1733
# Step 21/125; Loss = 0.1814
# Step 22/125; Loss = 0.1747
# Step 23/125; Loss = 0.2206
# Step 24/125; Loss = 0.1943
# Step 25/125; Loss = 0.2147
# Step 26/125; Loss = 0.2039
# Step 27/125; Loss = 0.1807
# Step 28/125; Loss = 0.1688
# Step 29/125; Loss = 0.1725
# Step 30/125; Loss = 0.1839
# Step 31/125; Loss = 0.1820
# Step 32/125; Loss = 0.1583
# Step 33/125; Loss = 0.2016
# Step 34/125; Loss = 0.1654
# Step 35/125; Loss = 0.1676
# Step 36/125; Loss = 0.1589
# Step 37/125; Loss = 0.1973
# Step 38/125; Loss = 0.1752
# Step 39/125; Loss = 0.2077
# Step 40/125; Loss = 0.1764
# Step 41/125; Loss = 0.1879
# Step 42/125; Loss = 0.1665
# Step 43/125; Loss = 0.2063
# Step 44/125; Loss = 0.1826
# Step 45/125; Loss = 0.1879
# Step 46/125; Loss = 0.2314
# Step 47/125; Loss = 0.1664
# Step 48/125; Loss = 0.1582
# Step 49/125; Loss = 0.1747
# Step 50/125; Loss = 0.2151
# Step 51/125; Loss = 0.1673
# Step 52/125; Loss = 0.2214
# Step 53/125; Loss = 0.1745
# Step 54/125; Loss = 0.1786
# Step 55/125; Loss = 0.1654
# Step 56/125; Loss = 0.1796
# Step 57/125; Loss = 0.2641
# Step 58/125; Loss = 0.1928
# Step 59/125; Loss = 0.1998
# Step 60/125; Loss = 0.1805
# Step 61/125; Loss = 0.1783
# Step 62/125; Loss = 0.1766
# Step 63/125; Loss = 0.1908
# Step 64/125; Loss = 0.1593
# Step 65/125; Loss = 0.1810
# Step 66/125; Loss = 0.1743
# Step 67/125; Loss = 0.1612
# Step 68/125; Loss = 0.1543
# Step 69/125; Loss = 0.2247
# Step 70/125; Loss = 0.2005
# Step 71/125; Loss = 0.1762
# Step 72/125; Loss = 0.2065
# Step 73/125; Loss = 0.1763
# Step 74/125; Loss = 0.1960
# Step 75/125; Loss = 0.1824
# Step 76/125; Loss = 0.1933
# Step 77/125; Loss = 0.2688
# Step 78/125; Loss = 0.1921
# Step 79/125; Loss = 0.1635
# Step 80/125; Loss = 0.1642
# Step 81/125; Loss = 0.1716
# Step 82/125; Loss = 0.1752
# Step 83/125; Loss = 0.1755
# Step 84/125; Loss = 0.1869
# Step 85/125; Loss = 0.2107
# Step 86/125; Loss = 0.1615
# Step 87/125; Loss = 0.1845
# Step 88/125; Loss = 0.1934
# Step 89/125; Loss = 0.2150
# Step 90/125; Loss = 0.1889
# Step 91/125; Loss = 0.1729
# Step 92/125; Loss = 0.1789
# Step 93/125; Loss = 0.2305
# Step 94/125; Loss = 0.1792
# Step 95/125; Loss = 0.1665
# Step 96/125; Loss = 0.1817
# Step 97/125; Loss = 0.1809
# Step 98/125; Loss = 0.1616
# Step 99/125; Loss = 0.1878
# Step 100/125; Loss = 0.2002
# Step 101/125; Loss = 0.1935
# Step 102/125; Loss = 0.1650
# Step 103/125; Loss = 0.1821
# Step 104/125; Loss = 0.2057
# Step 105/125; Loss = 0.1831
# Step 106/125; Loss = 0.2887
# Step 107/125; Loss = 0.1876
# Step 108/125; Loss = 0.1777
# Step 109/125; Loss = 0.1747
# Step 110/125; Loss = 0.1580
# Step 111/125; Loss = 0.1877
# Step 112/125; Loss = 0.1736
# Step 113/125; Loss = 0.2238
# Step 114/125; Loss = 0.1578
# Step 115/125; Loss = 0.1894
# Step 116/125; Loss = 0.1861
# Step 117/125; Loss = 0.2143
# Step 118/125; Loss = 0.1698
# Step 119/125; Loss = 0.1961
# Step 120/125; Loss = 0.1666
# Step 121/125; Loss = 0.1682
# Step 122/125; Loss = 0.1724
# Step 123/125; Loss = 0.1956
# Step 124/125; Loss = 0.2084
# Step 125/125; Loss = 0.1900
# Validation IoU Score: 0.6994
# Validation Dice Score: 0.8231
# --------------------
# Epoch 20/20; LR = 3.0467987000524782e-05
# Step 1/125; Loss = 0.2054
# Step 2/125; Loss = 0.2362
# Step 3/125; Loss = 0.1699
# Step 4/125; Loss = 0.2149
# Step 5/125; Loss = 0.2064
# Step 6/125; Loss = 0.1754
# Step 7/125; Loss = 0.1859
# Step 8/125; Loss = 0.1782
# Step 9/125; Loss = 0.1924
# Step 10/125; Loss = 0.1796
# Step 11/125; Loss = 0.1888
# Step 12/125; Loss = 0.1879
# Step 13/125; Loss = 0.2123
# Step 14/125; Loss = 0.1777
# Step 15/125; Loss = 0.1883
# Step 16/125; Loss = 0.2139
# Step 17/125; Loss = 0.1805
# Step 18/125; Loss = 0.1706
# Step 19/125; Loss = 0.2073
# Step 20/125; Loss = 0.1678
# Step 21/125; Loss = 0.1844
# Step 22/125; Loss = 0.1752
# Step 23/125; Loss = 0.1974
# Step 24/125; Loss = 0.2411
# Step 25/125; Loss = 0.1827
# Step 26/125; Loss = 0.1902
# Step 27/125; Loss = 0.1793
# Step 28/125; Loss = 0.1880
# Step 29/125; Loss = 0.1880
# Step 30/125; Loss = 0.1623
# Step 31/125; Loss = 0.2183
# Step 32/125; Loss = 0.2113
# Step 33/125; Loss = 0.1571
# Step 34/125; Loss = 0.1839
# Step 35/125; Loss = 0.2085
# Step 36/125; Loss = 0.1728
# Step 37/125; Loss = 0.1603
# Step 38/125; Loss = 0.1963
# Step 39/125; Loss = 0.1697
# Step 40/125; Loss = 0.1762
# Step 41/125; Loss = 0.1917
# Step 42/125; Loss = 0.1878
# Step 43/125; Loss = 0.1817
# Step 44/125; Loss = 0.1997
# Step 45/125; Loss = 0.1799
# Step 46/125; Loss = 0.1779
# Step 47/125; Loss = 0.2225
# Step 48/125; Loss = 0.1757
# Step 49/125; Loss = 0.1660
# Step 50/125; Loss = 0.2340
# Step 51/125; Loss = 0.1654
# Step 52/125; Loss = 0.2139
# Step 53/125; Loss = 0.1990
# Step 54/125; Loss = 0.1856
# Step 55/125; Loss = 0.1516
# Step 56/125; Loss = 0.2132
# Step 57/125; Loss = 0.2002
# Step 58/125; Loss = 0.1763
# Step 59/125; Loss = 0.1811
# Step 60/125; Loss = 0.2139
# Step 61/125; Loss = 0.1645
# Step 62/125; Loss = 0.1714
# Step 63/125; Loss = 0.1662
# Step 64/125; Loss = 0.1830
# Step 65/125; Loss = 0.1485
# Step 66/125; Loss = 0.1625
# Step 67/125; Loss = 0.1942
# Step 68/125; Loss = 0.1539
# Step 69/125; Loss = 0.1891
# Step 70/125; Loss = 0.1795
# Step 71/125; Loss = 0.1411
# Step 72/125; Loss = 0.1763
# Step 73/125; Loss = 0.1742
# Step 74/125; Loss = 0.1667
# Step 75/125; Loss = 0.2075
# Step 76/125; Loss = 0.1797
# Step 77/125; Loss = 0.2162
# Step 78/125; Loss = 0.2065
# Step 79/125; Loss = 0.1775
# Step 80/125; Loss = 0.1632
# Step 81/125; Loss = 0.1604
# Step 82/125; Loss = 0.1785
# Step 83/125; Loss = 0.1664
# Step 84/125; Loss = 0.1650
# Step 85/125; Loss = 0.2662
# Step 86/125; Loss = 0.1745
# Step 87/125; Loss = 0.2118
# Step 88/125; Loss = 0.1903
# Step 89/125; Loss = 0.1820
# Step 90/125; Loss = 0.1494
# Step 91/125; Loss = 0.1838
# Step 92/125; Loss = 0.1902
# Step 93/125; Loss = 0.1917
# Step 94/125; Loss = 0.1970
# Step 95/125; Loss = 0.2090
# Step 96/125; Loss = 0.1913
# Step 97/125; Loss = 0.1715
# Step 98/125; Loss = 0.2240
# Step 99/125; Loss = 0.1807
# Step 100/125; Loss = 0.2039
# Step 101/125; Loss = 0.1667
# Step 102/125; Loss = 0.1723
# Step 103/125; Loss = 0.1971
# Step 104/125; Loss = 0.1610
# Step 105/125; Loss = 0.1919
# Step 106/125; Loss = 0.1703
# Step 107/125; Loss = 0.1829
# Step 108/125; Loss = 0.2096
# Step 109/125; Loss = 0.1775
# Step 110/125; Loss = 0.2334
# Step 111/125; Loss = 0.2013
# Step 112/125; Loss = 0.1822
# Step 113/125; Loss = 0.2177
# Step 114/125; Loss = 0.2211
# Step 115/125; Loss = 0.1887
# Step 116/125; Loss = 0.1849
# Step 117/125; Loss = 0.2935
# Step 118/125; Loss = 0.1715
# Step 119/125; Loss = 0.2064
# Step 120/125; Loss = 0.1732
# Step 121/125; Loss = 0.2041
# Step 122/125; Loss = 0.2064
# Step 123/125; Loss = 0.1756
# Step 124/125; Loss = 0.2006
# Step 125/125; Loss = 0.1960
# Validation IoU Score: 0.6980
# Validation Dice Score: 0.8221
# --------------------
# Finished Training!
# Time Taken = 232m 9s

# %%
plt.plot(np.linspace(0,num_epochs,len(losses)),losses)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss vs Epochs')
# Out:
# Text(0.5, 1.0, 'Loss vs Epochs')

# %%
unet.load_state_dict(best_weights)
torch.save(unet, '../models/U-Net_Image_Segmentation_IE643_Final_Dense.pt')

# %%
# unet = torch.load('../models/U-Net_Image_Segmentation_IE643_Final_Dense.pt')
unet.eval()
# Out:
# UNet(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (denseBlock1): DenseBlock(
#     (conv1): Conv2d(64, 16, kernel_size=(9, 9), stride=(1, 1), padding=same)
#     (norm1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(80, 16, kernel_size=(9, 9), stride=(1, 1), padding=same)
#     (norm2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(96, 16, kernel_size=(7, 7), stride=(1, 1), padding=same)
#     (norm3): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv4): Conv2d(112, 16, kernel_size=(7, 7), stride=(1, 1), padding=same)
#     (norm4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv5): Conv2d(128, 16, kernel_size=(5, 5), stride=(1, 1), padding=same)
#     (norm5): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv6): Conv2d(144, 16, kernel_size=(5, 5), stride=(1, 1), padding=same)
#     (norm6): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv7): Conv2d(160, 16, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (norm7): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv8): Conv2d(176, 16, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (norm8): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (convFinal): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (denseBlock2): DenseBlock(
#     (conv1): Conv2d(128, 32, kernel_size=(9, 9), stride=(1, 1), padding=same)
#     (norm1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(160, 32, kernel_size=(9, 9), stride=(1, 1), padding=same)
#     (norm2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(192, 32, kernel_size=(7, 7), stride=(1, 1), padding=same)
#     (norm3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv4): Conv2d(224, 32, kernel_size=(7, 7), stride=(1, 1), padding=same)
#     (norm4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv5): Conv2d(256, 32, kernel_size=(5, 5), stride=(1, 1), padding=same)
#     (norm5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv6): Conv2d(288, 32, kernel_size=(5, 5), stride=(1, 1), padding=same)
#     (norm6): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv7): Conv2d(320, 32, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (norm7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv8): Conv2d(352, 32, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (norm8): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (convFinal): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (denseBlock3): DenseBlock(
#     (conv1): Conv2d(256, 64, kernel_size=(9, 9), stride=(1, 1), padding=same)
#     (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(320, 64, kernel_size=(9, 9), stride=(1, 1), padding=same)
#     (norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(384, 64, kernel_size=(7, 7), stride=(1, 1), padding=same)
#     (norm3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv4): Conv2d(448, 64, kernel_size=(7, 7), stride=(1, 1), padding=same)
#     (norm4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv5): Conv2d(512, 64, kernel_size=(5, 5), stride=(1, 1), padding=same)
#     (norm5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv6): Conv2d(576, 64, kernel_size=(5, 5), stride=(1, 1), padding=same)
#     (norm6): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv7): Conv2d(640, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (norm7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv8): Conv2d(704, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (norm8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (convFinal): Conv2d(768, 256, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv4): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (denseBlock4): DenseBlock(
#     (conv1): Conv2d(512, 128, kernel_size=(9, 9), stride=(1, 1), padding=same)
#     (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(640, 128, kernel_size=(9, 9), stride=(1, 1), padding=same)
#     (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(768, 128, kernel_size=(7, 7), stride=(1, 1), padding=same)
#     (norm3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv4): Conv2d(896, 128, kernel_size=(7, 7), stride=(1, 1), padding=same)
#     (norm4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv5): Conv2d(1024, 128, kernel_size=(5, 5), stride=(1, 1), padding=same)
#     (norm5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv6): Conv2d(1152, 128, kernel_size=(5, 5), stride=(1, 1), padding=same)
#     (norm6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv7): Conv2d(1280, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (norm7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv8): Conv2d(1408, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (norm8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (convFinal): Conv2d(1536, 512, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv41): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm41): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (denseBlock41): DenseBlock(
#     (conv1): Conv2d(1024, 256, kernel_size=(9, 9), stride=(1, 1), padding=same)
#     (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(1280, 256, kernel_size=(9, 9), stride=(1, 1), padding=same)
#     (norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(1536, 256, kernel_size=(7, 7), stride=(1, 1), padding=same)
#     (norm3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv4): Conv2d(1792, 256, kernel_size=(7, 7), stride=(1, 1), padding=same)
#     (norm4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv5): Conv2d(2048, 256, kernel_size=(5, 5), stride=(1, 1), padding=same)
#     (norm5): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv6): Conv2d(2304, 256, kernel_size=(5, 5), stride=(1, 1), padding=same)
#     (norm6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv7): Conv2d(2560, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (norm7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv8): Conv2d(2816, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (norm8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (convFinal): Conv2d(3072, 1024, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (convT0): ConvTranspose2d(1024, 512, kernel_size=(2, 2), stride=(2, 2))
#   (denseBlock42): DenseBlock(
#     (conv1): Conv2d(1024, 256, kernel_size=(9, 9), stride=(1, 1), padding=same)
#     (norm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(1280, 256, kernel_size=(9, 9), stride=(1, 1), padding=same)
#     (norm2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(1536, 256, kernel_size=(7, 7), stride=(1, 1), padding=same)
#     (norm3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv4): Conv2d(1792, 256, kernel_size=(7, 7), stride=(1, 1), padding=same)
#     (norm4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv5): Conv2d(2048, 256, kernel_size=(5, 5), stride=(1, 1), padding=same)
#     (norm5): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv6): Conv2d(2304, 256, kernel_size=(5, 5), stride=(1, 1), padding=same)
#     (norm6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv7): Conv2d(2560, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (norm7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv8): Conv2d(2816, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (norm8): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (convFinal): Conv2d(3072, 1024, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (convT1): ConvTranspose2d(1024, 256, kernel_size=(2, 2), stride=(2, 2))
#   (denseBlock5): DenseBlock(
#     (conv1): Conv2d(512, 128, kernel_size=(9, 9), stride=(1, 1), padding=same)
#     (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(640, 128, kernel_size=(9, 9), stride=(1, 1), padding=same)
#     (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(768, 128, kernel_size=(7, 7), stride=(1, 1), padding=same)
#     (norm3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv4): Conv2d(896, 128, kernel_size=(7, 7), stride=(1, 1), padding=same)
#     (norm4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv5): Conv2d(1024, 128, kernel_size=(5, 5), stride=(1, 1), padding=same)
#     (norm5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv6): Conv2d(1152, 128, kernel_size=(5, 5), stride=(1, 1), padding=same)
#     (norm6): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv7): Conv2d(1280, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (norm7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv8): Conv2d(1408, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (norm8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (convFinal): Conv2d(1536, 512, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (convT2): ConvTranspose2d(512, 128, kernel_size=(2, 2), stride=(2, 2))
#   (denseBlock6): DenseBlock(
#     (conv1): Conv2d(256, 64, kernel_size=(9, 9), stride=(1, 1), padding=same)
#     (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(320, 64, kernel_size=(9, 9), stride=(1, 1), padding=same)
#     (norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(384, 64, kernel_size=(7, 7), stride=(1, 1), padding=same)
#     (norm3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv4): Conv2d(448, 64, kernel_size=(7, 7), stride=(1, 1), padding=same)
#     (norm4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv5): Conv2d(512, 64, kernel_size=(5, 5), stride=(1, 1), padding=same)
#     (norm5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv6): Conv2d(576, 64, kernel_size=(5, 5), stride=(1, 1), padding=same)
#     (norm6): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv7): Conv2d(640, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (norm7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv8): Conv2d(704, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (norm8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (convFinal): Conv2d(768, 256, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (convT3): ConvTranspose2d(256, 64, kernel_size=(2, 2), stride=(2, 2))
#   (denseBlock7): DenseBlock(
#     (conv1): Conv2d(128, 32, kernel_size=(9, 9), stride=(1, 1), padding=same)
#     (norm1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv2): Conv2d(160, 32, kernel_size=(9, 9), stride=(1, 1), padding=same)
#     (norm2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv3): Conv2d(192, 32, kernel_size=(7, 7), stride=(1, 1), padding=same)
#     (norm3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv4): Conv2d(224, 32, kernel_size=(7, 7), stride=(1, 1), padding=same)
#     (norm4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv5): Conv2d(256, 32, kernel_size=(5, 5), stride=(1, 1), padding=same)
#     (norm5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv6): Conv2d(288, 32, kernel_size=(5, 5), stride=(1, 1), padding=same)
#     (norm6): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv7): Conv2d(320, 32, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (norm7): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv8): Conv2d(352, 32, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (norm8): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (convFinal): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv71): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm71): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv72): Conv2d(64, 16, kernel_size=(5, 5), stride=(1, 1), padding=same)
#   (norm72): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv73): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), padding=same)
#   (norm73): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %% [markdown]
# # Testing

# %%
threshold = 0.5

# %%
image, mask = next(iter(train_loader))
image = image.to(device)
mask = mask.to('cpu')
pred = unet(image).cpu()
pred1 = torch.relu(torch.sign(pred - threshold))
image = image.to('cpu')
image_show(image[0], mask[0], pred1[0])

# %%
IoU_value = 0
for image, mask in train_loader:
    image = image.to(device)
    mask = mask.to('cpu')
    pred = unet(image).cpu()
    pred = torch.relu(torch.sign(pred - threshold)) # Taking 0.4 as the threshold to make the value 1
    IoU_value += binaryJaccardIndex(pred, torch.round(mask).type(torch.int16))
print(f'Intersection Over Union value = {IoU_value/len(train_loader)}')
# Out:
# Intersection Over Union value = 0.6513023553162149

# %%
iou = IoU_value/len(train_loader)
dice_score = 2*iou/(1+iou)
print('Dice Score for Training data =',dice_score)
# Out:
# Dice Score for Training data = 0.7888347681687818

# %%
image, mask = next(iter(val_loader))
image = image.to(device)
mask = mask.to('cpu')
pred = unet(image).cpu()
pred1 = torch.relu(torch.sign(pred - threshold))
image = image.to('cpu')
image_show(image[0], mask[0], pred1[0])

# %%
IoU_value = 0
for image, mask in val_loader:
    image = image.to(device)
    mask = mask.to('cpu')
    pred = unet(image).cpu()
    pred = pred = torch.relu(torch.sign(pred - threshold))
    IoU_value += binaryJaccardIndex(pred, torch.round(mask).type(torch.int16))
print(f'Intersection Over Union value = {IoU_value/len(val_loader)}')
# Out:
# Intersection Over Union value = 0.32023100348478156

# %%
iou = IoU_value/len(val_loader)
dice_score = 2*iou/(1+iou)
print('Dice Score for Validation data =',dice_score)
# Out:
# Dice Score for Validation data = 0.492563509530598
