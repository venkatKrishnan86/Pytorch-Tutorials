# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
import torchvision
import torchvision.transforms as transforms
from torchvision.models.segmentation import deeplabv3_resnet101
from torchvision.models.segmentation.deeplabv3 import DeepLabHead
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from torchsummary import summary

import time
import copy
import os

# %%
data_dir = '../../../../IIT/IIT Sem 7/IE 643/Challenge_Dataset/Images'
mask_dir = '../../../../IIT/IIT Sem 7/IE 643/Challenge_Dataset/Masks'

# %%
data_transforms = {
    'Train': transforms.Compose([
        transforms.Resize((128,128)),
        # transforms.Grayscale(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ]),
    'Train2': transforms.Compose([
        transforms.Resize((128,128)),
        transforms.RandomHorizontalFlip(p=1),
        # transforms.Grayscale(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ]),
    'Validation': transforms.Compose([
        transforms.Resize((128,128)),
        # transforms.Grayscale(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])
}
mask_transforms = {
    'Train': transforms.Compose([
        transforms.Resize((128,128)),
        transforms.Grayscale(),
        transforms.ToTensor()
    ]),
    'Train2': transforms.Compose([
        transforms.Resize((128,128)),
        transforms.RandomHorizontalFlip(p=1),
        transforms.Grayscale(),
        transforms.ToTensor(),
    ]),
    'Validation': transforms.Compose([
        transforms.Resize((128,128)),
        transforms.Grayscale(),
        transforms.ToTensor()
    ])
}

# %%
class ImageMaskDataset(Dataset):
    def __init__(self, data_dir, mask_dir, train = True, transform = None, transform2 = None, mask_transform = None, mask_transform2 = None) -> None:
        super(ImageMaskDataset, self).__init__()
        self.imgs = []
        self.transform = transform
        if train:
            for file1 in os.scandir(data_dir+'/Train'):
                file2 = mask_dir+'/Train/'+file1.name[:-3]+'png'
                if self.transform is not None:
                    self.imgs.append((self.transform(Image.open(file1.path).convert('RGB')),mask_transform(Image.open(file2))))
                    for i in range(len(transform2)):
                        self.imgs.append((transform2[i](Image.open(file1.path).convert('RGB')),mask_transform2[i](Image.open(file2))))
                else:
                    self.imgs.append((Image.open(file1.path).convert('RGB'),Image.open(file2)))
        else:
            for file1 in os.scandir(data_dir+'/Validation'):
                file2 = mask_dir+'/Validation/'+file1.name[:-3]+'png'
                if self.transform is not None:
                    self.imgs.append((self.transform(Image.open(file1.path).convert('RGB')),mask_transform(Image.open(file2))))
                else:
                    self.imgs.append((Image.open(file1.path).convert('RGB'),Image.open(file2)))
                    # if self.imgs[-1][0].shape[0] == 1:
                    #     self.imgs[-1] = (self.imgs[-1][0].repeat(3,1,1), self.imgs[-1][1])
    
    def __len__(self):
        return len(self.imgs)
    
    def __getitem__(self, index):
        return self.imgs[index]

# %%
train_data = ImageMaskDataset(data_dir, mask_dir, train = True, transform=data_transforms['Train'], transform2=[data_transforms['Train2']], mask_transform=mask_transforms['Train'], mask_transform2=[mask_transforms['Train2']])
val_data = ImageMaskDataset(data_dir, mask_dir, train = False, transform=data_transforms['Validation'], mask_transform=mask_transforms['Validation'])

# %%
train_loader = DataLoader(
    train_data,
    batch_size = 250,
    shuffle = True,
)
val_loader = DataLoader(
    val_data,
    batch_size = 200,
    shuffle = True,
)

# %%
def image_show(image, mask, pred = None):
    image = image*0.5 + 0.5
    mask = mask*0.5 + 0.5
    plt.figure(figsize=(20,10))
    if pred is not None:
        plt.subplot(1,3,1)
        plt.title('Image')
        plt.imshow(image.numpy().transpose((1,2,0)), cmap='gray')
        plt.subplot(1,3,2)
        plt.title('True Mask')
        plt.imshow(mask.numpy().transpose((1,2,0)), cmap='gray')
        plt.subplot(1,3,3)
        plt.title('Predicted Mask')
        plt.imshow(pred.detach().numpy().transpose((1,2,0)), cmap='gray')
    else:
        plt.subplot(1,3,1)
        plt.title('Image')
        plt.imshow(image.numpy().transpose((1,2,0)), cmap='gray')
        plt.subplot(1,3,2)
        plt.title('Mask')
        plt.imshow(mask.numpy().transpose((1,2,0)), cmap='gray')

# %%
dataiter = iter(train_loader)
image, mask = next(dataiter)
index = 0
image_show(image[index], mask[index])

# %%
device = torch.device('mps' if torch.backends.mps.is_available() else 'cpu')
device
# Out:
# device(type='mps')

# %% [markdown]
# # Dense Block

# %%
class DenseBlock(nn.Sequential):
    def __init__(self, channels: int, output_channels: int) -> None:
        super(DenseBlock, self).__init__()
        self.conv1 = nn.Conv2d(channels+0*output_channels, output_channels, 3, 1, 'same', dilation=2)
        self.norm1 = nn.BatchNorm2d(output_channels)
        self.convFinal = nn.Conv2d(channels+1*output_channels, 1, 1)
        self.normFinal = nn.BatchNorm2d(1)
    
    def forward(self, x):
        temp = x
        x_temp = torch.relu(self.norm1(self.conv1(temp)))
        temp = torch.cat((temp, x_temp), 1)
        x = torch.sigmoid(self.normFinal(self.convFinal(temp)))
        return x

# %% [markdown]
# # DeepLab V3

# %%
deeplab = torch.load('../models/DeepLabV3_IoULoss_Image_Segmentation_Vertical.pt')
for params in deeplab.parameters():
    params.requires_grad_(False)
deeplab.classifier = DenseBlock(2048, 64).to(device)
deeplab.train()
# Out:
# DeepLabV3(
#   (backbone): IntermediateLayerGetter(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (6): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (7): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (8): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (9): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (10): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (11): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (12): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (13): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (14): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (15): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (16): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (17): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (18): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (19): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (20): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (21): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (22): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   (classifier): DenseBlock(
#     (conv1): Conv2d(2048, 64, kernel_size=(3, 3), stride=(1, 1), padding=same, dilation=(2, 2))
#     (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (convFinal): Conv2d(2112, 1, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (aux_classifier): FCNHead(
#     (0): Conv2d(1024, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Conv2d(256, 21, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
trainable_params = sum(param.numel() for param in deeplab.parameters() if param.requires_grad)
trainable_params
# Out:
# 1181955

# %%
deeplab = deeplab.to(device)

# %% [markdown]
# # IoU Function

# %%
class IoULoss(nn.Module):
    def __init__(self, weight=None, size_average=True):
        super(IoULoss, self).__init__()

    def forward(self, preds, masks):     
        preds = preds.view(-1)
        masks = masks.view(-1)
        
        #intersection is equivalent to True Positive count
        #union is the mutually inclusive area of all labels & predictions 
        intersection = (preds * masks).sum()
        total = (preds + masks).sum()
        union = total - intersection 
        
        IoU = intersection/union
                
        return 1 - IoU

# %%
def binaryJaccardIndex(preds, masks):
    intersection = 0
    union = 0
    preds = preds.view(-1) # Reshaping to a single array
    masks = masks.view(-1) # Reshaping to a single array

    intersection = (preds * masks).sum()
    total = (preds + masks).sum()
    union = total - intersection 
    
    IoU = intersection/union
            
    return IoU

# %% [markdown]
# # Dense Block

# %% [markdown]
# # Binary Cross Entropy Loss

# %%
criterion = IoULoss()
optimizer = torch.optim.SGD(list(deeplab.parameters()), lr=5e-1)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size = 5, gamma=0.8)

# %%
num_epochs = 50
batches = len(train_loader)
losses = []
print(batches)
# Out:
# 8

# %%
best_weights = copy.deepcopy(deeplab.state_dict())
max = 0
val_iou_score = 0
tic = time.time()
for epoch in range(num_epochs):
    deeplab.train()
    print(f'Epoch {epoch+1}/{num_epochs}; LR = {scheduler.get_last_lr()[0]}')
    for i, (images,masks) in enumerate(train_loader):
        images = images.to(device)
        masks = torch.round(masks).to(device)
        
        preds = deeplab(images)
        loss = criterion(preds['out'], masks)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        print(f'Step {i+1}/{batches}; Loss = {loss.item():.4f}')
        losses.append(loss.item())
    scheduler.step() # Decaying learning rate per 25 epochs by 0.2 times
    with torch.no_grad():
        deeplab.eval()
        val_iou_score = 0
        for image, mask in val_loader:
            image = image.to(device)
            mask = mask.to('cpu')
            pred = deeplab(image)['out'].cpu()
            pred = torch.round(pred)
            val_iou_score += binaryJaccardIndex(pred, torch.round(mask).type(torch.int16))
        val_iou_score = val_iou_score/len(val_loader)

        if (max <= val_iou_score):
            print('SAVED MODEL WEIGHTS')
            max = val_iou_score
            best_weights = copy.deepcopy(deeplab.state_dict())
    
    print(f'Validation IoU Score: {val_iou_score:.4f}')
    print(f'Validation Dice Score: {(2*val_iou_score)/(1+val_iou_score):.4f}')
    print("-"*20)
print('Finished Training!')
print(f'Time Taken = {(time.time() - tic)//60:.0f}m {(time.time() - tic)%60:.0f}s')
# Out:
# Epoch 1/50; LR = 0.5
# Step 1/8; Loss = 0.8312
# Step 2/8; Loss = 0.7461
# Step 3/8; Loss = 0.7476
# Step 4/8; Loss = 0.7314
# Step 5/8; Loss = 0.7285
# Step 6/8; Loss = 0.7235
# Step 7/8; Loss = 0.7118
# Step 8/8; Loss = 0.6901
# SAVED MODEL WEIGHTS
# Validation IoU Score: 0.4848
# Validation Dice Score: 0.6530
# --------------------
# Epoch 2/50; LR = 0.5
# Step 1/8; Loss = 0.6941
# Step 2/8; Loss = 0.6959
# Step 3/8; Loss = 0.7018
# Step 4/8; Loss = 0.6879
# Step 5/8; Loss = 0.6824
# Step 6/8; Loss = 0.6594
# Step 7/8; Loss = 0.6539
# Step 8/8; Loss = 0.6619
# SAVED MODEL WEIGHTS
# Validation IoU Score: 0.5233
# Validation Dice Score: 0.6871
# --------------------
# Epoch 3/50; LR = 0.5
# Step 1/8; Loss = 0.6544
# Step 2/8; Loss = 0.6530
# Step 3/8; Loss = 0.6204
# Step 4/8; Loss = 0.5917
# Step 5/8; Loss = 0.6301
# Step 6/8; Loss = 0.5958
# Step 7/8; Loss = 0.6008
# Step 8/8; Loss = 0.5980
# SAVED MODEL WEIGHTS
# Validation IoU Score: 0.5315
# Validation Dice Score: 0.6940
# --------------------
# Epoch 4/50; LR = 0.5
# Step 1/8; Loss = 0.5755
# Step 2/8; Loss = 0.5611
# Step 3/8; Loss = 0.5583
# Step 4/8; Loss = 0.5311
# Step 5/8; Loss = 0.5631
# Step 6/8; Loss = 0.5317
# Step 7/8; Loss = 0.5424
# Step 8/8; Loss = 0.5542
# SAVED MODEL WEIGHTS
# Validation IoU Score: 0.5335
# Validation Dice Score: 0.6958
# --------------------
# Epoch 5/50; LR = 0.5
# Step 1/8; Loss = 0.5158
# Step 2/8; Loss = 0.5088
# Step 3/8; Loss = 0.5139
# Step 4/8; Loss = 0.4958
# Step 5/8; Loss = 0.4768
# Step 6/8; Loss = 0.4729
# Step 7/8; Loss = 0.5005
# Step 8/8; Loss = 0.4722
# Validation IoU Score: 0.5284
# Validation Dice Score: 0.6915
# --------------------
# Epoch 6/50; LR = 0.4
# Step 1/8; Loss = 0.4841
# Step 2/8; Loss = 0.4549
# Step 3/8; Loss = 0.4605
# Step 4/8; Loss = 0.4482
# Step 5/8; Loss = 0.4576
# Step 6/8; Loss = 0.4547
# Step 7/8; Loss = 0.4394
# Step 8/8; Loss = 0.4375
# SAVED MODEL WEIGHTS
# Validation IoU Score: 0.5356
# Validation Dice Score: 0.6975
# --------------------
# Epoch 7/50; LR = 0.4
# Step 1/8; Loss = 0.4446
# Step 2/8; Loss = 0.4203
# Step 3/8; Loss = 0.4209
# Step 4/8; Loss = 0.4326
# Step 5/8; Loss = 0.4450
# Step 6/8; Loss = 0.4157
# Step 7/8; Loss = 0.4307
# Step 8/8; Loss = 0.4375
# Validation IoU Score: 0.5326
# Validation Dice Score: 0.6950
# --------------------
# Epoch 8/50; LR = 0.4
# Step 1/8; Loss = 0.4257
# Step 2/8; Loss = 0.4256
# Step 3/8; Loss = 0.4271
# Step 4/8; Loss = 0.4126
# Step 5/8; Loss = 0.4064
# Step 6/8; Loss = 0.3945
# Step 7/8; Loss = 0.4135
# Step 8/8; Loss = 0.3914
# Validation IoU Score: 0.5285
# Validation Dice Score: 0.6916
# --------------------
# Epoch 9/50; LR = 0.4
# Step 1/8; Loss = 0.3920
# Step 2/8; Loss = 0.3936
# Step 3/8; Loss = 0.4219
# Step 4/8; Loss = 0.4072
# Step 5/8; Loss = 0.4017
# Step 6/8; Loss = 0.3898
# Step 7/8; Loss = 0.4038
# Step 8/8; Loss = 0.3796
# Validation IoU Score: 0.5335
# Validation Dice Score: 0.6958
# --------------------
# Epoch 10/50; LR = 0.4
# Step 1/8; Loss = 0.4088
# Step 2/8; Loss = 0.3994
# Step 3/8; Loss = 0.3858
# Step 4/8; Loss = 0.3893
# Step 5/8; Loss = 0.3925
# Step 6/8; Loss = 0.3802
# Step 7/8; Loss = 0.3733
# Step 8/8; Loss = 0.3771
# Validation IoU Score: 0.5298
# Validation Dice Score: 0.6927
# --------------------
# Epoch 11/50; LR = 0.32000000000000006
# Step 1/8; Loss = 0.3903
# Step 2/8; Loss = 0.3679
# Step 3/8; Loss = 0.3807
# Step 4/8; Loss = 0.3830
# Step 5/8; Loss = 0.3969
# Step 6/8; Loss = 0.3881
# Step 7/8; Loss = 0.3713
# Step 8/8; Loss = 0.3645
# Validation IoU Score: 0.5301
# Validation Dice Score: 0.6929
# --------------------
# Epoch 12/50; LR = 0.32000000000000006
# Step 1/8; Loss = 0.3821
# Step 2/8; Loss = 0.3764
# Step 3/8; Loss = 0.3644
# Step 4/8; Loss = 0.3779
# Step 5/8; Loss = 0.3743
# Step 6/8; Loss = 0.3684
# Step 7/8; Loss = 0.3676
# Step 8/8; Loss = 0.3803
# Validation IoU Score: 0.5272
# Validation Dice Score: 0.6904
# --------------------
# Epoch 13/50; LR = 0.32000000000000006
# Step 1/8; Loss = 0.3718
# Step 2/8; Loss = 0.3791
# Step 3/8; Loss = 0.3801
# Step 4/8; Loss = 0.3683
# Step 5/8; Loss = 0.3544
# Step 6/8; Loss = 0.3640
# Step 7/8; Loss = 0.3847
# Step 8/8; Loss = 0.3560
# Validation IoU Score: 0.5254
# Validation Dice Score: 0.6889
# --------------------
# Epoch 14/50; LR = 0.32000000000000006
# Step 1/8; Loss = 0.3715
# Step 2/8; Loss = 0.3613
# Step 3/8; Loss = 0.3722
# Step 4/8; Loss = 0.3647
# Step 5/8; Loss = 0.3588
# Step 6/8; Loss = 0.3669
# Step 7/8; Loss = 0.3643
# Step 8/8; Loss = 0.3617
# Validation IoU Score: 0.5227
# Validation Dice Score: 0.6866
# --------------------
# Epoch 15/50; LR = 0.32000000000000006
# Step 1/8; Loss = 0.3724
# Step 2/8; Loss = 0.3495
# Step 3/8; Loss = 0.3722
# Step 4/8; Loss = 0.3611
# Step 5/8; Loss = 0.3661
# Step 6/8; Loss = 0.3598
# Step 7/8; Loss = 0.3676
# Step 8/8; Loss = 0.3525
# Validation IoU Score: 0.5323
# Validation Dice Score: 0.6948
# --------------------
# Epoch 16/50; LR = 0.25600000000000006
# Step 1/8; Loss = 0.3691
# Step 2/8; Loss = 0.3770
# Step 3/8; Loss = 0.3562
# Step 4/8; Loss = 0.3350
# Step 5/8; Loss = 0.3565
# Step 6/8; Loss = 0.3659
# Step 7/8; Loss = 0.3464
# Step 8/8; Loss = 0.3583
# Validation IoU Score: 0.5313
# Validation Dice Score: 0.6939
# --------------------
# Epoch 17/50; LR = 0.25600000000000006
# Step 1/8; Loss = 0.3916
# Step 2/8; Loss = 0.3506
# Step 3/8; Loss = 0.3541
# Step 4/8; Loss = 0.3438
# Step 5/8; Loss = 0.3494
# Step 6/8; Loss = 0.3606
# Step 7/8; Loss = 0.3555
# Step 8/8; Loss = 0.3447
# Validation IoU Score: 0.5162
# Validation Dice Score: 0.6809
# --------------------
# Epoch 18/50; LR = 0.25600000000000006
# Step 1/8; Loss = 0.3402
# Step 2/8; Loss = 0.3496
# Step 3/8; Loss = 0.3550
# Step 4/8; Loss = 0.3671
# Step 5/8; Loss = 0.3593
# Step 6/8; Loss = 0.3531
# Step 7/8; Loss = 0.3674
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/venkatakrishnanvk/Desktop/ML & DL/Deep Learning/Pytorch-Tutorial/advanced_tutorials/Tutorial 3.31 - DeepLabv3 Transfer Learning with Dense Block.ipynb Cell 23 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/Users/venkatakrishnanvk/Desktop/ML%20%26%20DL/Deep%20Learning/Pytorch-Tutorial/advanced_tutorials/Tutorial%203.31%20-%20DeepLabv3%20Transfer%20Learning%20with%20Dense%20Block.ipynb#X24sZmlsZQ%3D%3D?line=8'>9</a> images = images.to(device)
#      <a href='vscode-notebook-cell:/Users/venkatakrishnanvk/Desktop/ML%20%26%20DL/Deep%20Learning/Pytorch-Tutorial/advanced_tutorials/Tutorial%203.31%20-%20DeepLabv3%20Transfer%20Learning%20with%20Dense%20Block.ipynb#X24sZmlsZQ%3D%3D?line=9'>10</a> masks = torch.round(masks).to(device)
# ---> <a href='vscode-notebook-cell:/Users/venkatakrishnanvk/Desktop/ML%20%26%20DL/Deep%20Learning/Pytorch-Tutorial/advanced_tutorials/Tutorial%203.31%20-%20DeepLabv3%20Transfer%20Learning%20with%20Dense%20Block.ipynb#X24sZmlsZQ%3D%3D?line=11'>12</a> preds = deeplab(images)
#      <a href='vscode-notebook-cell:/Users/venkatakrishnanvk/Desktop/ML%20%26%20DL/Deep%20Learning/Pytorch-Tutorial/advanced_tutorials/Tutorial%203.31%20-%20DeepLabv3%20Transfer%20Learning%20with%20Dense%20Block.ipynb#X24sZmlsZQ%3D%3D?line=12'>13</a> loss = criterion(preds['out'], masks)
#      <a href='vscode-notebook-cell:/Users/venkatakrishnanvk/Desktop/ML%20%26%20DL/Deep%20Learning/Pytorch-Tutorial/advanced_tutorials/Tutorial%203.31%20-%20DeepLabv3%20Transfer%20Learning%20with%20Dense%20Block.ipynb#X24sZmlsZQ%3D%3D?line=14'>15</a> optimizer.zero_grad()
#
# File ~/miniforge3/lib/python3.10/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/lib/python3.10/site-packages/torchvision/models/segmentation/_utils.py:23, in _SimpleSegmentationModel.forward(self, x)
#      21 input_shape = x.shape[-2:]
#      22 # contract: features is a dict of tensors
# ---> 23 features = self.backbone(x)
#      25 result = OrderedDict()
#      26 x = features["out"]
#
# File ~/miniforge3/lib/python3.10/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/lib/python3.10/site-packages/torchvision/models/_utils.py:69, in IntermediateLayerGetter.forward(self, x)
#      67 out = OrderedDict()
#      68 for name, module in self.items():
# ---> 69     x = module(x)
#      70     if name in self.return_layers:
#      71         out_name = self.return_layers[name]
#
# File ~/miniforge3/lib/python3.10/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/lib/python3.10/site-packages/torch/nn/modules/container.py:204, in Sequential.forward(self, input)
#     202 def forward(self, input):
#     203     for module in self:
# --> 204         input = module(input)
#     205     return input
#
# File ~/miniforge3/lib/python3.10/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/lib/python3.10/site-packages/torchvision/models/resnet.py:146, in Bottleneck.forward(self, x)
#     143 def forward(self, x: Tensor) -> Tensor:
#     144     identity = x
# --> 146     out = self.conv1(x)
#     147     out = self.bn1(out)
#     148     out = self.relu(out)
#
# File ~/miniforge3/lib/python3.10/site-packages/torch/nn/modules/module.py:1190, in Module._call_impl(self, *input, **kwargs)
#    1186 # If we don't have any hooks, we want to skip the rest of the logic in
#    1187 # this function, and just call forward.
#    1188 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1189         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1190     return forward_call(*input, **kwargs)
#    1191 # Do not call functions when jit is used
#    1192 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/miniforge3/lib/python3.10/site-packages/torch/nn/modules/conv.py:463, in Conv2d.forward(self, input)
#     462 def forward(self, input: Tensor) -> Tensor:
# --> 463     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/miniforge3/lib/python3.10/site-packages/torch/nn/modules/conv.py:459, in Conv2d._conv_forward(self, input, weight, bias)
#     455 if self.padding_mode != 'zeros':
#     456     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     457                     weight, bias, self.stride,
#     458                     _pair(0), self.dilation, self.groups)
# --> 459 return F.conv2d(input, weight, bias, self.stride,
#     460                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
plt.plot(np.linspace(0,num_epochs,len(losses)),losses)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss vs Epochs')
# Out:
# Text(0.5, 1.0, 'Loss vs Epochs')

# %%
deeplab.load_state_dict(best_weights)
# torch.save(deeplab, '../models/DeepLabV3_IoULoss_Image_Segmentation.pt')

# %%
# deeplab = torch.load('../models/DeepLabV3_IoULoss_Image_Segmentation.pt')
deeplab.eval()
# Out:
# DeepLabV3(
#   (backbone): IntermediateLayerGetter(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (6): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (7): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (8): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (9): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (10): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (11): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (12): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (13): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (14): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (15): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (16): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (17): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (18): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (19): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (20): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (21): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (22): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(2, 2), dilation=(2, 2), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(4, 4), dilation=(4, 4), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   (classifier): DeepLabHead(
#     (0): ASPP(
#       (convs): ModuleList(
#         (0): Sequential(
#           (0): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (1): ASPPConv(
#           (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(12, 12), dilation=(12, 12), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (2): ASPPConv(
#           (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(24, 24), dilation=(24, 24), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (3): ASPPConv(
#           (0): Conv2d(2048, 256, kernel_size=(3, 3), stride=(1, 1), padding=(36, 36), dilation=(36, 36), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#         )
#         (4): ASPPPooling(
#           (0): AdaptiveAvgPool2d(output_size=1)
#           (1): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): ReLU()
#         )
#       )
#       (project): Sequential(
#         (0): Conv2d(1280, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Dropout(p=0.5, inplace=False)
#       )
#     )
#     (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU()
#     (4): Conv2d(256, 1, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (aux_classifier): FCNHead(
#     (0): Conv2d(1024, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Dropout(p=0.1, inplace=False)
#     (4): Conv2d(256, 21, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %% [markdown]
# # Testing

# %%
threshold = 0.5

# %%
with torch.no_grad():
    image, mask = next(iter(train_loader))
    image = image.to(device)
    mask = mask.to('cpu')
    pred = deeplab(image)['out'].cpu()
    pred1 = torch.relu(torch.sign(pred - threshold))
    image = image.to('cpu')
    image_show(image[0], mask[0], pred1[0])

# %%
IoU_value = 0
with torch.no_grad():
    for image, mask in train_loader:
        image = image.to(device)
        mask = mask.to('cpu')
        pred = deeplab(image)['out'].cpu()
        pred = torch.relu(torch.sign(pred - threshold)) # Taking 0.4 as the threshold to make the value 1
        IoU_value += binaryJaccardIndex(pred, torch.round(mask).type(torch.int16))
    print(f'Intersection Over Union value = {IoU_value/len(train_loader)}')
# Out:
# Intersection Over Union value = 0.7421835660934448

# %%
iou = IoU_value/len(train_loader)
dice_score = 2*iou/(1+iou)
print('Dice Score for Training data =',dice_score.item())
# Out:
# Dice Score for Training data = 0.8520153164863586

# %%
with torch.no_grad():
    image, mask = next(iter(val_loader))
    image = image.to(device)
    mask = mask.to('cpu')
    pred = deeplab(image)['out'].cpu()
    pred1 = torch.relu(torch.sign(pred - threshold))
    image = image.to('cpu')
    image_show(image[0], mask[0], pred1[0])

# %%
IoU_value = 0
with torch.no_grad():
    for image, mask in val_loader:
        image = image.to(device)
        mask = mask.to('cpu')
        pred = deeplab(image)['out'].cpu()
        pred = torch.relu(torch.sign(pred - threshold))
        IoU_value += binaryJaccardIndex(pred, torch.round(mask).type(torch.int16))
    print(f'Intersection Over Union value = {IoU_value/len(val_loader)}')
# Out:
# Intersection Over Union value = 0.5451464056968689

# %%
iou = IoU_value/len(val_loader)
dice_score = 2*iou/(1+iou)
print('Dice Score for Validation data =',dice_score.item())
# Out:
# Dice Score for Validation data = 0.7056242227554321

# %%
val_iou = iou

# %% [markdown]
# ## Training for 10 more epochs

# %%
deeplab = torch.load('../models/DeepLabV3_IoULoss_Image_Segmentation.pt')
num_epochs = 10
batches = len(train_loader)
losses = []
print(batches)
# Out:
# 125

# %%
criterion = IoULoss()
criterion2 = nn.BCELoss()
optimizer = torch.optim.SGD(deeplab.parameters(), lr=1e-2)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size = 1, gamma=0.6)

# %%
best_weights = copy.deepcopy(deeplab.state_dict())
max = val_iou
val_iou_score = 0
tic = time.time()
for epoch in range(num_epochs):
    deeplab.train()
    print(f'Epoch {epoch+1}/{num_epochs}; LR = {scheduler.get_last_lr()[0]}')
    for i, (images,masks) in enumerate(train_loader):
        images = images.to(device)
        masks = torch.round(masks).to(device)
        
        preds = deeplab(images)
        preds = torch.sigmoid(preds['out'])
        loss = criterion(preds, masks) + criterion2(preds, masks)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        print(f'Step {i+1}/{batches}; Loss = {loss.item():.4f}')
        losses.append(loss.item())
    scheduler.step() # Decaying learning rate per 25 epochs by 0.2 times
    with torch.no_grad():
        deeplab.eval()
        val_iou_score = 0
        for image, mask in val_loader:
            image = image.to(device)
            mask = mask.to('cpu')
            pred = deeplab(image)['out']
            pred = torch.sigmoid(pred).cpu()
            pred = torch.round(pred)
            val_iou_score += binaryJaccardIndex(pred, torch.round(mask).type(torch.int16))
        val_iou_score = val_iou_score/len(val_loader)

        if (max <= val_iou_score):
            print('SAVED MODEL WEIGHTS')
            max = val_iou_score
            best_weights = copy.deepcopy(deeplab.state_dict())
    
    print(f'Validation IoU Score: {val_iou_score:.4f}')
    print(f'Validation Dice Score: {(2*val_iou_score)/(1+val_iou_score):.4f}')
    print("-"*20)
print('Finished Training!')
print(f'Time Taken = {(time.time() - tic)//60:.0f}m {(time.time() - tic)%60:.0f}s')
# Out:
# Epoch 1/10; LR = 0.01
# Step 1/125; Loss = 0.5099
# Step 2/125; Loss = 0.5688
# Step 3/125; Loss = 0.4819
# Step 4/125; Loss = 0.4515
# Step 5/125; Loss = 0.5283
# Step 6/125; Loss = 0.5376
# Step 7/125; Loss = 0.5112
# Step 8/125; Loss = 0.6961
# Step 9/125; Loss = 0.5781
# Step 10/125; Loss = 0.5259
# Step 11/125; Loss = 0.5808
# Step 12/125; Loss = 0.7151
# Step 13/125; Loss = 0.4565
# Step 14/125; Loss = 0.6307
# Step 15/125; Loss = 0.4572
# Step 16/125; Loss = 0.5030
# Step 17/125; Loss = 0.4541
# Step 18/125; Loss = 0.7032
# Step 19/125; Loss = 0.5169
# Step 20/125; Loss = 0.6208
# Step 21/125; Loss = 0.4920
# Step 22/125; Loss = 0.4658
# Step 23/125; Loss = 0.4976
# Step 24/125; Loss = 0.5914
# Step 25/125; Loss = 0.4536
# Step 26/125; Loss = 0.3822
# Step 27/125; Loss = 0.5555
# Step 28/125; Loss = 0.5918
# Step 29/125; Loss = 0.5066
# Step 30/125; Loss = 0.4934
# Step 31/125; Loss = 0.4631
# Step 32/125; Loss = 0.5699
# Step 33/125; Loss = 0.4161
# Step 34/125; Loss = 0.4379
# Step 35/125; Loss = 0.7428
# Step 36/125; Loss = 0.6913
# Step 37/125; Loss = 0.4497
# Step 38/125; Loss = 0.4362
# Step 39/125; Loss = 0.4269
# Step 40/125; Loss = 0.3365
# Step 41/125; Loss = 0.5625
# Step 42/125; Loss = 0.4549
# Step 43/125; Loss = 0.4848
# Step 44/125; Loss = 0.6428
# Step 45/125; Loss = 0.5155
# Step 46/125; Loss = 0.3725
# Step 47/125; Loss = 0.3489
# Step 48/125; Loss = 0.5017
# Step 49/125; Loss = 0.6596
# Step 50/125; Loss = 0.6627
# Step 51/125; Loss = 0.4831
# Step 52/125; Loss = 0.3411
# Step 53/125; Loss = 0.3870
# Step 54/125; Loss = 0.7599
# Step 55/125; Loss = 0.7086
# Step 56/125; Loss = 0.5247
# Step 57/125; Loss = 0.3914
# Step 58/125; Loss = 0.4489
# Step 59/125; Loss = 0.4985
# Step 60/125; Loss = 0.4155
# Step 61/125; Loss = 0.4638
# Step 62/125; Loss = 0.4607
# Step 63/125; Loss = 0.4988
# Step 64/125; Loss = 0.4660
# Step 65/125; Loss = 0.6144
# Step 66/125; Loss = 0.4692
# Step 67/125; Loss = 0.5581
# Step 68/125; Loss = 0.5425
# Step 69/125; Loss = 0.5453
# Step 70/125; Loss = 0.6718
# Step 71/125; Loss = 0.4408
# Step 72/125; Loss = 0.5165
# Step 73/125; Loss = 0.5444
# Step 74/125; Loss = 0.4250
# Step 75/125; Loss = 0.5528
# Step 76/125; Loss = 0.3690
# Step 77/125; Loss = 0.4500
# Step 78/125; Loss = 0.5256
# Step 79/125; Loss = 0.4135
# Step 80/125; Loss = 0.4111
# Step 81/125; Loss = 0.4268
# Step 82/125; Loss = 0.5367
# Step 83/125; Loss = 0.5706
# Step 84/125; Loss = 0.6369
# Step 85/125; Loss = 0.4809
# Step 86/125; Loss = 0.4718
# Step 87/125; Loss = 0.4419
# Step 88/125; Loss = 0.6496
# Step 89/125; Loss = 0.5491
# Step 90/125; Loss = 0.5314
# Step 91/125; Loss = 0.5380
# Step 92/125; Loss = 0.4927
# Step 93/125; Loss = 0.3359
# Step 94/125; Loss = 0.7300
# Step 95/125; Loss = 0.5837
# Step 96/125; Loss = 0.4673
# Step 97/125; Loss = 0.4592
# Step 98/125; Loss = 0.4165
# Step 99/125; Loss = 0.4136
# Step 100/125; Loss = 0.4217
# Step 101/125; Loss = 0.3472
# Step 102/125; Loss = 0.5803
# Step 103/125; Loss = 0.5284
# Step 104/125; Loss = 0.4781
# Step 105/125; Loss = 0.5460
# Step 106/125; Loss = 0.4201
# Step 107/125; Loss = 0.3819
# Step 108/125; Loss = 0.4727
# Step 109/125; Loss = 0.3717
# Step 110/125; Loss = 0.4448
# Step 111/125; Loss = 0.4007
# Step 112/125; Loss = 0.5996
# Step 113/125; Loss = 0.5855
# Step 114/125; Loss = 0.5326
# Step 115/125; Loss = 0.4637
# Step 116/125; Loss = 0.4345
# Step 117/125; Loss = 0.3874
# Step 118/125; Loss = 0.5626
# Step 119/125; Loss = 0.4234
# Step 120/125; Loss = 0.4027
# Step 121/125; Loss = 0.3800
# Step 122/125; Loss = 0.4657
# Step 123/125; Loss = 0.4517
# Step 124/125; Loss = 0.4042
# Step 125/125; Loss = 0.6620
# SAVED MODEL WEIGHTS
# Validation IoU Score: 0.5502
# Validation Dice Score: 0.7099
# --------------------
# Epoch 2/10; LR = 0.006
# Step 1/125; Loss = 0.5340
# Step 2/125; Loss = 0.4252
# Step 3/125; Loss = 0.3838
# Step 4/125; Loss = 0.4950
# Step 5/125; Loss = 0.4221
# Step 6/125; Loss = 0.4021
# Step 7/125; Loss = 0.4580
# Step 8/125; Loss = 0.3923
# Step 9/125; Loss = 0.4135
# Step 10/125; Loss = 0.4565
# Step 11/125; Loss = 0.4168
# Step 12/125; Loss = 0.4998
# Step 13/125; Loss = 0.4185
# Step 14/125; Loss = 0.3797
# Step 15/125; Loss = 0.5213
# Step 16/125; Loss = 0.4082
# Step 17/125; Loss = 0.4814
# Step 18/125; Loss = 0.5473
# Step 19/125; Loss = 0.3943
# Step 20/125; Loss = 0.6004
# Step 21/125; Loss = 0.5296
# Step 22/125; Loss = 0.5303
# Step 23/125; Loss = 0.4185
# Step 24/125; Loss = 0.3928
# Step 25/125; Loss = 0.3984
# Step 26/125; Loss = 0.4700
# Step 27/125; Loss = 0.4439
# Step 28/125; Loss = 0.3447
# Step 29/125; Loss = 0.4054
# Step 30/125; Loss = 0.4610
# Step 31/125; Loss = 0.3332
# Step 32/125; Loss = 0.4241
# Step 33/125; Loss = 0.3820
# Step 34/125; Loss = 0.4287
# Step 35/125; Loss = 0.5854
# Step 36/125; Loss = 0.4569
# Step 37/125; Loss = 0.5013
# Step 38/125; Loss = 0.6778
# Step 39/125; Loss = 0.4672
# Step 40/125; Loss = 0.4130
# Step 41/125; Loss = 0.4534
# Step 42/125; Loss = 0.5212
# Step 43/125; Loss = 0.4540
# Step 44/125; Loss = 0.4059
# Step 45/125; Loss = 0.3991
# Step 46/125; Loss = 0.3420
# Step 47/125; Loss = 0.3349
# Step 48/125; Loss = 0.3330
# Step 49/125; Loss = 0.4546
# Step 50/125; Loss = 0.4272
# Step 51/125; Loss = 0.4177
# Step 52/125; Loss = 0.4270
# Step 53/125; Loss = 0.5261
# Step 54/125; Loss = 0.5506
# Step 55/125; Loss = 0.3717
# Step 56/125; Loss = 0.5341
# Step 57/125; Loss = 0.3918
# Step 58/125; Loss = 0.3577
# Step 59/125; Loss = 0.5014
# Step 60/125; Loss = 0.4272
# Step 61/125; Loss = 0.4272
# Step 62/125; Loss = 0.5806
# Step 63/125; Loss = 0.5053
# Step 64/125; Loss = 0.4383
# Step 65/125; Loss = 0.3345
# Step 66/125; Loss = 0.4089
# Step 67/125; Loss = 0.4963
# Step 68/125; Loss = 0.3774
# Step 69/125; Loss = 0.4533
# Step 70/125; Loss = 0.4271
# Step 71/125; Loss = 0.3295
# Step 72/125; Loss = 0.4211
# Step 73/125; Loss = 0.4749
# Step 74/125; Loss = 0.5469
# Step 75/125; Loss = 0.3432
# Step 76/125; Loss = 0.4791
# Step 77/125; Loss = 0.3393
# Step 78/125; Loss = 0.4845
# Step 79/125; Loss = 0.4770
# Step 80/125; Loss = 0.5241
# Step 81/125; Loss = 0.4733
# Step 82/125; Loss = 0.4601
# Step 83/125; Loss = 0.4177
# Step 84/125; Loss = 0.3906
# Step 85/125; Loss = 0.3818
# Step 86/125; Loss = 0.4127
# Step 87/125; Loss = 0.3754
# Step 88/125; Loss = 0.5057
# Step 89/125; Loss = 0.4392
# Step 90/125; Loss = 0.3120
# Step 91/125; Loss = 0.3605
# Step 92/125; Loss = 0.3520
# Step 93/125; Loss = 0.4851
# Step 94/125; Loss = 0.4840
# Step 95/125; Loss = 0.3642
# Step 96/125; Loss = 0.5611
# Step 97/125; Loss = 0.4898
# Step 98/125; Loss = 0.3195
# Step 99/125; Loss = 0.5667
# Step 100/125; Loss = 0.4584
# Step 101/125; Loss = 0.5420
# Step 102/125; Loss = 0.4014
# Step 103/125; Loss = 0.4224
# Step 104/125; Loss = 0.3845
# Step 105/125; Loss = 0.3600
# Step 106/125; Loss = 0.3652
# Step 107/125; Loss = 0.4024
# Step 108/125; Loss = 0.4731
# Step 109/125; Loss = 0.4250
# Step 110/125; Loss = 0.4302
# Step 111/125; Loss = 0.4974
# Step 112/125; Loss = 0.4247
# Step 113/125; Loss = 0.4215
# Step 114/125; Loss = 0.3431
# Step 115/125; Loss = 0.4391
# Step 116/125; Loss = 0.4300
# Step 117/125; Loss = 0.3889
# Step 118/125; Loss = 0.4451
# Step 119/125; Loss = 0.4652
# Step 120/125; Loss = 0.4407
# Step 121/125; Loss = 0.5764
# Step 122/125; Loss = 0.4389
# Step 123/125; Loss = 0.3856
# Step 124/125; Loss = 0.4232
# Step 125/125; Loss = 0.4166
# Validation IoU Score: 0.5456
# Validation Dice Score: 0.7060
# --------------------
# Epoch 3/10; LR = 0.0036
# Step 1/125; Loss = 0.3258
# Step 2/125; Loss = 0.3887
# Step 3/125; Loss = 0.4282
# Step 4/125; Loss = 0.3308
# Step 5/125; Loss = 0.3333
# Step 6/125; Loss = 0.3845
# Step 7/125; Loss = 0.4072
# Step 8/125; Loss = 0.4620
# Step 9/125; Loss = 0.3846
# Step 10/125; Loss = 0.3824
# Step 11/125; Loss = 0.3415
# Step 12/125; Loss = 0.5159
# Step 13/125; Loss = 0.4573
# Step 14/125; Loss = 0.4256
# Step 15/125; Loss = 0.5567
# Step 16/125; Loss = 0.3473
# Step 17/125; Loss = 0.3411
# Step 18/125; Loss = 0.3489
# Step 19/125; Loss = 0.4257
# Step 20/125; Loss = 0.3884
# Step 21/125; Loss = 0.4108
# Step 22/125; Loss = 0.3504
# Step 23/125; Loss = 0.5529
# Step 24/125; Loss = 0.3944
# Step 25/125; Loss = 0.4374
# Step 26/125; Loss = 0.3995
# Step 27/125; Loss = 0.3993
# Step 28/125; Loss = 0.3441
# Step 29/125; Loss = 0.3326
# Step 30/125; Loss = 0.4068
# Step 31/125; Loss = 0.4945
# Step 32/125; Loss = 0.4268
# Step 33/125; Loss = 0.4442
# Step 34/125; Loss = 0.3519
# Step 35/125; Loss = 0.4509
# Step 36/125; Loss = 0.2863
# Step 37/125; Loss = 0.4971
# Step 38/125; Loss = 0.4355
# Step 39/125; Loss = 0.4685
# Step 40/125; Loss = 0.4741
# Step 41/125; Loss = 0.4825
# Step 42/125; Loss = 0.3893
# Step 43/125; Loss = 0.5193
# Step 44/125; Loss = 0.3713
# Step 45/125; Loss = 0.3268
# Step 46/125; Loss = 0.4534
# Step 47/125; Loss = 0.3576
# Step 48/125; Loss = 0.3384
# Step 49/125; Loss = 0.4443
# Step 50/125; Loss = 0.4494
# Step 51/125; Loss = 0.4437
# Step 52/125; Loss = 0.3403
# Step 53/125; Loss = 0.3699
# Step 54/125; Loss = 0.3638
# Step 55/125; Loss = 0.3480
# Step 56/125; Loss = 0.3992
# Step 57/125; Loss = 0.3751
# Step 58/125; Loss = 0.4491
# Step 59/125; Loss = 0.3352
# Step 60/125; Loss = 0.4324
# Step 61/125; Loss = 0.4559
# Step 62/125; Loss = 0.3831
# Step 63/125; Loss = 0.4170
# Step 64/125; Loss = 0.4440
# Step 65/125; Loss = 0.5115
# Step 66/125; Loss = 0.4451
# Step 67/125; Loss = 0.4014
# Step 68/125; Loss = 0.4104
# Step 69/125; Loss = 0.4385
# Step 70/125; Loss = 0.5779
# Step 71/125; Loss = 0.5616
# Step 72/125; Loss = 0.4656
# Step 73/125; Loss = 0.5673
# Step 74/125; Loss = 0.4045
# Step 75/125; Loss = 0.4748
# Step 76/125; Loss = 0.3740
# Step 77/125; Loss = 0.3552
# Step 78/125; Loss = 0.3779
# Step 79/125; Loss = 0.3733
# Step 80/125; Loss = 0.6054
# Step 81/125; Loss = 0.3743
# Step 82/125; Loss = 0.4749
# Step 83/125; Loss = 0.3544
# Step 84/125; Loss = 0.3115
# Step 85/125; Loss = 0.4303
# Step 86/125; Loss = 0.3746
# Step 87/125; Loss = 0.4308
# Step 88/125; Loss = 0.3885
# Step 89/125; Loss = 0.4902
# Step 90/125; Loss = 0.4694
# Step 91/125; Loss = 0.3603
# Step 92/125; Loss = 0.3456
# Step 93/125; Loss = 0.4256
# Step 94/125; Loss = 0.4611
# Step 95/125; Loss = 0.3644
# Step 96/125; Loss = 0.4449
# Step 97/125; Loss = 0.3969
# Step 98/125; Loss = 0.4483
# Step 99/125; Loss = 0.3828
# Step 100/125; Loss = 0.3168
# Step 101/125; Loss = 0.4070
# Step 102/125; Loss = 0.3575
# Step 103/125; Loss = 0.4351
# Step 104/125; Loss = 0.4972
# Step 105/125; Loss = 0.2888
# Step 106/125; Loss = 0.7132
# Step 107/125; Loss = 0.4964
# Step 108/125; Loss = 0.4214
# Step 109/125; Loss = 0.4762
# Step 110/125; Loss = 0.4101
# Step 111/125; Loss = 0.3431
# Step 112/125; Loss = 0.3785
# Step 113/125; Loss = 0.3989
# Step 114/125; Loss = 0.3478
# Step 115/125; Loss = 0.4392
# Step 116/125; Loss = 0.3507
# Step 117/125; Loss = 0.4401
# Step 118/125; Loss = 0.4190
# Step 119/125; Loss = 0.5168
# Step 120/125; Loss = 0.3534
# Step 121/125; Loss = 0.3879
# Step 122/125; Loss = 0.4777
# Step 123/125; Loss = 0.4686
# Step 124/125; Loss = 0.4279
# Step 125/125; Loss = 0.3327
# SAVED MODEL WEIGHTS
# Validation IoU Score: 0.5532
# Validation Dice Score: 0.7124
# --------------------
# Epoch 4/10; LR = 0.00216
# Step 1/125; Loss = 0.3230
# Step 2/125; Loss = 0.3897
# Step 3/125; Loss = 0.4138
# Step 4/125; Loss = 0.4734
# Step 5/125; Loss = 0.4486
# Step 6/125; Loss = 0.3907
# Step 7/125; Loss = 0.3366
# Step 8/125; Loss = 0.3942
# Step 9/125; Loss = 0.4160
# Step 10/125; Loss = 0.5357
# Step 11/125; Loss = 0.4243
# Step 12/125; Loss = 0.4104
# Step 13/125; Loss = 0.3886
# Step 14/125; Loss = 0.4625
# Step 15/125; Loss = 0.3854
# Step 16/125; Loss = 0.3558
# Step 17/125; Loss = 0.3900
# Step 18/125; Loss = 0.3905
# Step 19/125; Loss = 0.4060
# Step 20/125; Loss = 0.4489
# Step 21/125; Loss = 0.3786
# Step 22/125; Loss = 0.4097
# Step 23/125; Loss = 0.3501
# Step 24/125; Loss = 0.3619
# Step 25/125; Loss = 0.4473
# Step 26/125; Loss = 0.3743
# Step 27/125; Loss = 0.4433
# Step 28/125; Loss = 0.5191
# Step 29/125; Loss = 0.3716
# Step 30/125; Loss = 0.5038
# Step 31/125; Loss = 0.4627
# Step 32/125; Loss = 0.3478
# Step 33/125; Loss = 0.4006
# Step 34/125; Loss = 0.3893
# Step 35/125; Loss = 0.3310
# Step 36/125; Loss = 0.3891
# Step 37/125; Loss = 0.4703
# Step 38/125; Loss = 0.3393
# Step 39/125; Loss = 0.3458
# Step 40/125; Loss = 0.3664
# Step 41/125; Loss = 0.5058
# Step 42/125; Loss = 0.4091
# Step 43/125; Loss = 0.3236
# Step 44/125; Loss = 0.3795
# Step 45/125; Loss = 0.3890
# Step 46/125; Loss = 0.4123
# Step 47/125; Loss = 0.4759
# Step 48/125; Loss = 0.3480
# Step 49/125; Loss = 0.4121
# Step 50/125; Loss = 0.2921
# Step 51/125; Loss = 0.3564
# Step 52/125; Loss = 0.4832
# Step 53/125; Loss = 0.3746
# Step 54/125; Loss = 0.3495
# Step 55/125; Loss = 0.5294
# Step 56/125; Loss = 0.3809
# Step 57/125; Loss = 0.3374
# Step 58/125; Loss = 0.3539
# Step 59/125; Loss = 0.3387
# Step 60/125; Loss = 0.4326
# Step 61/125; Loss = 0.3909
# Step 62/125; Loss = 0.3265
# Step 63/125; Loss = 0.3747
# Step 64/125; Loss = 0.3911
# Step 65/125; Loss = 0.3885
# Step 66/125; Loss = 0.3405
# Step 67/125; Loss = 0.3299
# Step 68/125; Loss = 0.3901
# Step 69/125; Loss = 0.4595
# Step 70/125; Loss = 0.3406
# Step 71/125; Loss = 0.4554
# Step 72/125; Loss = 0.3009
# Step 73/125; Loss = 0.4591
# Step 74/125; Loss = 0.4077
# Step 75/125; Loss = 0.4006
# Step 76/125; Loss = 0.3916
# Step 77/125; Loss = 0.3350
# Step 78/125; Loss = 0.4851
# Step 79/125; Loss = 0.3572
# Step 80/125; Loss = 0.4309
# Step 81/125; Loss = 0.2990
# Step 82/125; Loss = 0.3785
# Step 83/125; Loss = 0.3783
# Step 84/125; Loss = 0.3801
# Step 85/125; Loss = 0.4599
# Step 86/125; Loss = 0.4248
# Step 87/125; Loss = 0.4512
# Step 88/125; Loss = 0.3345
# Step 89/125; Loss = 0.3458
# Step 90/125; Loss = 0.4012
# Step 91/125; Loss = 0.4485
# Step 92/125; Loss = 0.4398
# Step 93/125; Loss = 0.3825
# Step 94/125; Loss = 0.3410
# Step 95/125; Loss = 0.3072
# Step 96/125; Loss = 0.4552
# Step 97/125; Loss = 0.3950
# Step 98/125; Loss = 0.4314
# Step 99/125; Loss = 0.3660
# Step 100/125; Loss = 0.4072
# Step 101/125; Loss = 0.4027
# Step 102/125; Loss = 0.2752
# Step 103/125; Loss = 0.4110
# Step 104/125; Loss = 0.3488
# Step 105/125; Loss = 0.3660
# Step 106/125; Loss = 0.4901
# Step 107/125; Loss = 0.4399
# Step 108/125; Loss = 0.4913
# Step 109/125; Loss = 0.4423
# Step 110/125; Loss = 0.4857
# Step 111/125; Loss = 0.4163
# Step 112/125; Loss = 0.4802
# Step 113/125; Loss = 0.3926
# Step 114/125; Loss = 0.3882
# Step 115/125; Loss = 0.4360
# Step 116/125; Loss = 0.4301
# Step 117/125; Loss = 0.4604
# Step 118/125; Loss = 0.3797
# Step 119/125; Loss = 0.4228
# Step 120/125; Loss = 0.3442
# Step 121/125; Loss = 0.3798
# Step 122/125; Loss = 0.4191
# Step 123/125; Loss = 0.4408
# Step 124/125; Loss = 0.3806
# Step 125/125; Loss = 0.5442
# Validation IoU Score: 0.5376
# Validation Dice Score: 0.6993
# --------------------
# Epoch 5/10; LR = 0.001296
# Step 1/125; Loss = 0.3128
# Step 2/125; Loss = 0.4101
# Step 3/125; Loss = 0.4096
# Step 4/125; Loss = 0.4280
# Step 5/125; Loss = 0.4437
# Step 6/125; Loss = 0.3662
# Step 7/125; Loss = 0.4155
# Step 8/125; Loss = 0.3187
# Step 9/125; Loss = 0.3417
# Step 10/125; Loss = 0.2520
# Step 11/125; Loss = 0.3202
# Step 12/125; Loss = 0.3601
# Step 13/125; Loss = 0.3602
# Step 14/125; Loss = 0.3334
# Step 15/125; Loss = 0.3162
# Step 16/125; Loss = 0.3204
# Step 17/125; Loss = 0.3891
# Step 18/125; Loss = 0.3592
# Step 19/125; Loss = 0.4603
# Step 20/125; Loss = 0.3823
# Step 21/125; Loss = 0.4129
# Step 22/125; Loss = 0.3784
# Step 23/125; Loss = 0.3591
# Step 24/125; Loss = 0.3770
# Step 25/125; Loss = 0.3707
# Step 26/125; Loss = 0.3836
# Step 27/125; Loss = 0.5044
# Step 28/125; Loss = 0.4684
# Step 29/125; Loss = 0.4111
# Step 30/125; Loss = 0.4827
# Step 31/125; Loss = 0.3568
# Step 32/125; Loss = 0.3482
# Step 33/125; Loss = 0.4059
# Step 34/125; Loss = 0.4277
# Step 35/125; Loss = 0.3970
# Step 36/125; Loss = 0.3799
# Step 37/125; Loss = 0.4053
# Step 38/125; Loss = 0.4115
# Step 39/125; Loss = 0.3884
# Step 40/125; Loss = 0.4071
# Step 41/125; Loss = 0.3295
# Step 42/125; Loss = 0.3850
# Step 43/125; Loss = 0.4220
# Step 44/125; Loss = 0.4580
# Step 45/125; Loss = 0.3411
# Step 46/125; Loss = 0.4305
# Step 47/125; Loss = 0.4023
# Step 48/125; Loss = 0.3676
# Step 49/125; Loss = 0.3889
# Step 50/125; Loss = 0.4516
# Step 51/125; Loss = 0.3959
# Step 52/125; Loss = 0.3535
# Step 53/125; Loss = 0.7280
# Step 54/125; Loss = 0.3749
# Step 55/125; Loss = 0.3792
# Step 56/125; Loss = 0.3195
# Step 57/125; Loss = 0.4808
# Step 58/125; Loss = 0.3723
# Step 59/125; Loss = 0.4418
# Step 60/125; Loss = 0.4020
# Step 61/125; Loss = 0.3525
# Step 62/125; Loss = 0.4224
# Step 63/125; Loss = 0.5202
# Step 64/125; Loss = 0.3744
# Step 65/125; Loss = 0.3975
# Step 66/125; Loss = 0.4280
# Step 67/125; Loss = 0.2912
# Step 68/125; Loss = 0.4989
# Step 69/125; Loss = 0.3509
# Step 70/125; Loss = 0.3144
# Step 71/125; Loss = 0.3776
# Step 72/125; Loss = 0.3733
# Step 73/125; Loss = 0.4237
# Step 74/125; Loss = 0.3469
# Step 75/125; Loss = 0.4483
# Step 76/125; Loss = 0.4032
# Step 77/125; Loss = 0.3781
# Step 78/125; Loss = 0.4214
# Step 79/125; Loss = 0.5233
# Step 80/125; Loss = 0.4752
# Step 81/125; Loss = 0.3499
# Step 82/125; Loss = 0.3174
# Step 83/125; Loss = 0.4163
# Step 84/125; Loss = 0.3496
# Step 85/125; Loss = 0.4928
# Step 86/125; Loss = 0.3328
# Step 87/125; Loss = 0.3274
# Step 88/125; Loss = 0.3553
# Step 89/125; Loss = 0.3608
# Step 90/125; Loss = 0.3669
# Step 91/125; Loss = 0.4292
# Step 92/125; Loss = 0.3414
# Step 93/125; Loss = 0.3648
# Step 94/125; Loss = 0.3497
# Step 95/125; Loss = 0.3744
# Step 96/125; Loss = 0.4982
# Step 97/125; Loss = 0.4202
# Step 98/125; Loss = 0.3663
# Step 99/125; Loss = 0.5081
# Step 100/125; Loss = 0.3974
# Step 101/125; Loss = 0.3271
# Step 102/125; Loss = 0.4138
# Step 103/125; Loss = 0.3585
# Step 104/125; Loss = 0.4141
# Step 105/125; Loss = 0.4366
# Step 106/125; Loss = 0.3891
# Step 107/125; Loss = 0.3666
# Step 108/125; Loss = 0.3656
# Step 109/125; Loss = 0.4394
# Step 110/125; Loss = 0.3554
# Step 111/125; Loss = 0.4337
# Step 112/125; Loss = 0.3673
# Step 113/125; Loss = 0.3889
# Step 114/125; Loss = 0.4473
# Step 115/125; Loss = 0.4011
# Step 116/125; Loss = 0.3786
# Step 117/125; Loss = 0.4245
# Step 118/125; Loss = 0.4500
# Step 119/125; Loss = 0.3712
# Step 120/125; Loss = 0.3598
# Step 121/125; Loss = 0.4841
# Step 122/125; Loss = 0.3398
# Step 123/125; Loss = 0.2948
# Step 124/125; Loss = 0.4765
# Step 125/125; Loss = 0.3283
# SAVED MODEL WEIGHTS
# Validation IoU Score: 0.5534
# Validation Dice Score: 0.7125
# --------------------
# Epoch 6/10; LR = 0.0007776
# Step 1/125; Loss = 0.3974
# Step 2/125; Loss = 0.3169
# Step 3/125; Loss = 0.5660
# Step 4/125; Loss = 0.3373
# Step 5/125; Loss = 0.3605
# Step 6/125; Loss = 0.3352
# Step 7/125; Loss = 0.3980
# Step 8/125; Loss = 0.3482
# Step 9/125; Loss = 0.3510
# Step 10/125; Loss = 0.3339
# Step 11/125; Loss = 0.3689
# Step 12/125; Loss = 0.4739
# Step 13/125; Loss = 0.3963
# Step 14/125; Loss = 0.4656
# Step 15/125; Loss = 0.3571
# Step 16/125; Loss = 0.4171
# Step 17/125; Loss = 0.4155
# Step 18/125; Loss = 0.4609
# Step 19/125; Loss = 0.2828
# Step 20/125; Loss = 0.3710
# Step 21/125; Loss = 0.4446
# Step 22/125; Loss = 0.3611
# Step 23/125; Loss = 0.3889
# Step 24/125; Loss = 0.4919
# Step 25/125; Loss = 0.4630
# Step 26/125; Loss = 0.4034
# Step 27/125; Loss = 0.3242
# Step 28/125; Loss = 0.4873
# Step 29/125; Loss = 0.3802
# Step 30/125; Loss = 0.3831
# Step 31/125; Loss = 0.3911
# Step 32/125; Loss = 0.3892
# Step 33/125; Loss = 0.3850
# Step 34/125; Loss = 0.3826
# Step 35/125; Loss = 0.4821
# Step 36/125; Loss = 0.4778
# Step 37/125; Loss = 0.3580
# Step 38/125; Loss = 0.5306
# Step 39/125; Loss = 0.3119
# Step 40/125; Loss = 0.2667
# Step 41/125; Loss = 0.3128
# Step 42/125; Loss = 0.3293
# Step 43/125; Loss = 0.3589
# Step 44/125; Loss = 0.3572
# Step 45/125; Loss = 0.4277
# Step 46/125; Loss = 0.4190
# Step 47/125; Loss = 0.4941
# Step 48/125; Loss = 0.4330
# Step 49/125; Loss = 0.3836
# Step 50/125; Loss = 0.5584
# Step 51/125; Loss = 0.3571
# Step 52/125; Loss = 0.4259
# Step 53/125; Loss = 0.2977
# Step 54/125; Loss = 0.4707
# Step 55/125; Loss = 0.3094
# Step 56/125; Loss = 0.4070
# Step 57/125; Loss = 0.6098
# Step 58/125; Loss = 0.3571
# Step 59/125; Loss = 0.3232
# Step 60/125; Loss = 0.3563
# Step 61/125; Loss = 0.3676
# Step 62/125; Loss = 0.3728
# Step 63/125; Loss = 0.2983
# Step 64/125; Loss = 0.3327
# Step 65/125; Loss = 0.4269
# Step 66/125; Loss = 0.4881
# Step 67/125; Loss = 0.3757
# Step 68/125; Loss = 0.4923
# Step 69/125; Loss = 0.3569
# Step 70/125; Loss = 0.3549
# Step 71/125; Loss = 0.4697
# Step 72/125; Loss = 0.5064
# Step 73/125; Loss = 0.5207
# Step 74/125; Loss = 0.4607
# Step 75/125; Loss = 0.3609
# Step 76/125; Loss = 0.3352
# Step 77/125; Loss = 0.3706
# Step 78/125; Loss = 0.4271
# Step 79/125; Loss = 0.3165
# Step 80/125; Loss = 0.4023
# Step 81/125; Loss = 0.3937
# Step 82/125; Loss = 0.3222
# Step 83/125; Loss = 0.4018
# Step 84/125; Loss = 0.4869
# Step 85/125; Loss = 0.4611
# Step 86/125; Loss = 0.3842
# Step 87/125; Loss = 0.3668
# Step 88/125; Loss = 0.3779
# Step 89/125; Loss = 0.3973
# Step 90/125; Loss = 0.3318
# Step 91/125; Loss = 0.3666
# Step 92/125; Loss = 0.3879
# Step 93/125; Loss = 0.3892
# Step 94/125; Loss = 0.3561
# Step 95/125; Loss = 0.3875
# Step 96/125; Loss = 0.3642
# Step 97/125; Loss = 0.3784
# Step 98/125; Loss = 0.4352
# Step 99/125; Loss = 0.4106
# Step 100/125; Loss = 0.3679
# Step 101/125; Loss = 0.3584
# Step 102/125; Loss = 0.4439
# Step 103/125; Loss = 0.4308
# Step 104/125; Loss = 0.3118
# Step 105/125; Loss = 0.3888
# Step 106/125; Loss = 0.3823
# Step 107/125; Loss = 0.4801
# Step 108/125; Loss = 0.4908
# Step 109/125; Loss = 0.3907
# Step 110/125; Loss = 0.3581
# Step 111/125; Loss = 0.3618
# Step 112/125; Loss = 0.3551
# Step 113/125; Loss = 0.3758
# Step 114/125; Loss = 0.3593
# Step 115/125; Loss = 0.3647
# Step 116/125; Loss = 0.5295
# Step 117/125; Loss = 0.3740
# Step 118/125; Loss = 0.4918
# Step 119/125; Loss = 0.3638
# Step 120/125; Loss = 0.4127
# Step 121/125; Loss = 0.3282
# Step 122/125; Loss = 0.3446
# Step 123/125; Loss = 0.3241
# Step 124/125; Loss = 0.3974
# Step 125/125; Loss = 0.3618
# Validation IoU Score: 0.5434
# Validation Dice Score: 0.7042
# --------------------
# Epoch 7/10; LR = 0.00046656
# Step 1/125; Loss = 0.5451
# Step 2/125; Loss = 0.3860
# Step 3/125; Loss = 0.3658
# Step 4/125; Loss = 0.4123
# Step 5/125; Loss = 0.3587
# Step 6/125; Loss = 0.3916
# Step 7/125; Loss = 0.4002
# Step 8/125; Loss = 0.3586
# Step 9/125; Loss = 0.4095
# Step 10/125; Loss = 0.3875
# Step 11/125; Loss = 0.3012
# Step 12/125; Loss = 0.4011
# Step 13/125; Loss = 0.3498
# Step 14/125; Loss = 0.3657
# Step 15/125; Loss = 0.3862
# Step 16/125; Loss = 0.3932
# Step 17/125; Loss = 0.4089
# Step 18/125; Loss = 0.3418
# Step 19/125; Loss = 0.3745
# Step 20/125; Loss = 0.3874
# Step 21/125; Loss = 0.3602
# Step 22/125; Loss = 0.4220
# Step 23/125; Loss = 0.4251
# Step 24/125; Loss = 0.4062
# Step 25/125; Loss = 0.3619
# Step 26/125; Loss = 0.3804
# Step 27/125; Loss = 0.5787
# Step 28/125; Loss = 0.4528
# Step 29/125; Loss = 0.4251
# Step 30/125; Loss = 0.4065
# Step 31/125; Loss = 0.3612
# Step 32/125; Loss = 0.3169
# Step 33/125; Loss = 0.5547
# Step 34/125; Loss = 0.4373
# Step 35/125; Loss = 0.3805
# Step 36/125; Loss = 0.3979
# Step 37/125; Loss = 0.2982
# Step 38/125; Loss = 0.3805
# Step 39/125; Loss = 0.3655
# Step 40/125; Loss = 0.4042
# Step 41/125; Loss = 0.3538
# Step 42/125; Loss = 0.3376
# Step 43/125; Loss = 0.3919
# Step 44/125; Loss = 0.3569
# Step 45/125; Loss = 0.3473
# Step 46/125; Loss = 0.3857
# Step 47/125; Loss = 0.4434
# Step 48/125; Loss = 0.3758
# Step 49/125; Loss = 0.3828
# Step 50/125; Loss = 0.3295
# Step 51/125; Loss = 0.3516
# Step 52/125; Loss = 0.3042
# Step 53/125; Loss = 0.3551
# Step 54/125; Loss = 0.3824
# Step 55/125; Loss = 0.4011
# Step 56/125; Loss = 0.4583
# Step 57/125; Loss = 0.3096
# Step 58/125; Loss = 0.3488
# Step 59/125; Loss = 0.3477
# Step 60/125; Loss = 0.4247
# Step 61/125; Loss = 0.4141
# Step 62/125; Loss = 0.3860
# Step 63/125; Loss = 0.3155
# Step 64/125; Loss = 0.3598
# Step 65/125; Loss = 0.4181
# Step 66/125; Loss = 0.3998
# Step 67/125; Loss = 0.3882
# Step 68/125; Loss = 0.3640
# Step 69/125; Loss = 0.4288
# Step 70/125; Loss = 0.4393
# Step 71/125; Loss = 0.5258
# Step 72/125; Loss = 0.3330
# Step 73/125; Loss = 0.4771
# Step 74/125; Loss = 0.4964
# Step 75/125; Loss = 0.3238
# Step 76/125; Loss = 0.3896
# Step 77/125; Loss = 0.3892
# Step 78/125; Loss = 0.3585
# Step 79/125; Loss = 0.4425
# Step 80/125; Loss = 0.4848
# Step 81/125; Loss = 0.3358
# Step 82/125; Loss = 0.3928
# Step 83/125; Loss = 0.3498
# Step 84/125; Loss = 0.3805
# Step 85/125; Loss = 0.3797
# Step 86/125; Loss = 0.4800
# Step 87/125; Loss = 0.2882
# Step 88/125; Loss = 0.3928
# Step 89/125; Loss = 0.4439
# Step 90/125; Loss = 0.3204
# Step 91/125; Loss = 0.3954
# Step 92/125; Loss = 0.3937
# Step 93/125; Loss = 0.3696
# Step 94/125; Loss = 0.3178
# Step 95/125; Loss = 0.4800
# Step 96/125; Loss = 0.4608
# Step 97/125; Loss = 0.3699
# Step 98/125; Loss = 0.4096
# Step 99/125; Loss = 0.3751
# Step 100/125; Loss = 0.2971
# Step 101/125; Loss = 0.2755
# Step 102/125; Loss = 0.4690
# Step 103/125; Loss = 0.3491
# Step 104/125; Loss = 0.3893
# Step 105/125; Loss = 0.2788
# Step 106/125; Loss = 0.3805
# Step 107/125; Loss = 0.3036
# Step 108/125; Loss = 0.3625
# Step 109/125; Loss = 0.4200
# Step 110/125; Loss = 0.4396
# Step 111/125; Loss = 0.3757
# Step 112/125; Loss = 0.3652
# Step 113/125; Loss = 0.3953
# Step 114/125; Loss = 0.4286
# Step 115/125; Loss = 0.3979
# Step 116/125; Loss = 0.3655
# Step 117/125; Loss = 0.4968
# Step 118/125; Loss = 0.5013
# Step 119/125; Loss = 0.5799
# Step 120/125; Loss = 0.3980
# Step 121/125; Loss = 0.4246
# Step 122/125; Loss = 0.3626
# Step 123/125; Loss = 0.3680
# Step 124/125; Loss = 0.3324
# Step 125/125; Loss = 0.2953
# Validation IoU Score: 0.5470
# Validation Dice Score: 0.7072
# --------------------
# Epoch 8/10; LR = 0.000279936
# Step 1/125; Loss = 0.3562
# Step 2/125; Loss = 0.3675
# Step 3/125; Loss = 0.3299
# Step 4/125; Loss = 0.4130
# Step 5/125; Loss = 0.3486
# Step 6/125; Loss = 0.3584
# Step 7/125; Loss = 0.3970
# Step 8/125; Loss = 0.4881
# Step 9/125; Loss = 0.5305
# Step 10/125; Loss = 0.5072
# Step 11/125; Loss = 0.3975
# Step 12/125; Loss = 0.3672
# Step 13/125; Loss = 0.3157
# Step 14/125; Loss = 0.3359
# Step 15/125; Loss = 0.4603
# Step 16/125; Loss = 0.4092
# Step 17/125; Loss = 0.3956
# Step 18/125; Loss = 0.2894
# Step 19/125; Loss = 0.3391
# Step 20/125; Loss = 0.3840
# Step 21/125; Loss = 0.4780
# Step 22/125; Loss = 0.4182
# Step 23/125; Loss = 0.4443
# Step 24/125; Loss = 0.3955
# Step 25/125; Loss = 0.3203
# Step 26/125; Loss = 0.3350
# Step 27/125; Loss = 0.3685
# Step 28/125; Loss = 0.4791
# Step 29/125; Loss = 0.3003
# Step 30/125; Loss = 0.4170
# Step 31/125; Loss = 0.3309
# Step 32/125; Loss = 0.4235
# Step 33/125; Loss = 0.3288
# Step 34/125; Loss = 0.3965
# Step 35/125; Loss = 0.3695
# Step 36/125; Loss = 0.4387
# Step 37/125; Loss = 0.4995
# Step 38/125; Loss = 0.5648
# Step 39/125; Loss = 0.3389
# Step 40/125; Loss = 0.3485
# Step 41/125; Loss = 0.3603
# Step 42/125; Loss = 0.3421
# Step 43/125; Loss = 0.3585
# Step 44/125; Loss = 0.2951
# Step 45/125; Loss = 0.5010
# Step 46/125; Loss = 0.4312
# Step 47/125; Loss = 0.4068
# Step 48/125; Loss = 0.3875
# Step 49/125; Loss = 0.4028
# Step 50/125; Loss = 0.4897
# Step 51/125; Loss = 0.3605
# Step 52/125; Loss = 0.3466
# Step 53/125; Loss = 0.3874
# Step 54/125; Loss = 0.3850
# Step 55/125; Loss = 0.3272
# Step 56/125; Loss = 0.3422
# Step 57/125; Loss = 0.3126
# Step 58/125; Loss = 0.4223
# Step 59/125; Loss = 0.4040
# Step 60/125; Loss = 0.3012
# Step 61/125; Loss = 0.3138
# Step 62/125; Loss = 0.4106
# Step 63/125; Loss = 0.4098
# Step 64/125; Loss = 0.3190
# Step 65/125; Loss = 0.4644
# Step 66/125; Loss = 0.4005
# Step 67/125; Loss = 0.4369
# Step 68/125; Loss = 0.4030
# Step 69/125; Loss = 0.3616
# Step 70/125; Loss = 0.3568
# Step 71/125; Loss = 0.3659
# Step 72/125; Loss = 0.3192
# Step 73/125; Loss = 0.4252
# Step 74/125; Loss = 0.4646
# Step 75/125; Loss = 0.4186
# Step 76/125; Loss = 0.3535
# Step 77/125; Loss = 0.4129
# Step 78/125; Loss = 0.4808
# Step 79/125; Loss = 0.3483
# Step 80/125; Loss = 0.4893
# Step 81/125; Loss = 0.4581
# Step 82/125; Loss = 0.3780
# Step 83/125; Loss = 0.3182
# Step 84/125; Loss = 0.3462
# Step 85/125; Loss = 0.3843
# Step 86/125; Loss = 0.5063
# Step 87/125; Loss = 0.3439
# Step 88/125; Loss = 0.3512
# Step 89/125; Loss = 0.3891
# Step 90/125; Loss = 0.6041
# Step 91/125; Loss = 0.3611
# Step 92/125; Loss = 0.4037
# Step 93/125; Loss = 0.3814
# Step 94/125; Loss = 0.5552
# Step 95/125; Loss = 0.5074
# Step 96/125; Loss = 0.3318
# Step 97/125; Loss = 0.3882
# Step 98/125; Loss = 0.3543
# Step 99/125; Loss = 0.3804
# Step 100/125; Loss = 0.3590
# Step 101/125; Loss = 0.3482
# Step 102/125; Loss = 0.3341
# Step 103/125; Loss = 0.3600
# Step 104/125; Loss = 0.3174
# Step 105/125; Loss = 0.4406
# Step 106/125; Loss = 0.4316
# Step 107/125; Loss = 0.3343
# Step 108/125; Loss = 0.5123
# Step 109/125; Loss = 0.4105
# Step 110/125; Loss = 0.3303
# Step 111/125; Loss = 0.3339
# Step 112/125; Loss = 0.3150
# Step 113/125; Loss = 0.3829
# Step 114/125; Loss = 0.3477
# Step 115/125; Loss = 0.3280
# Step 116/125; Loss = 0.3880
# Step 117/125; Loss = 0.4063
# Step 118/125; Loss = 0.4209
# Step 119/125; Loss = 0.3489
# Step 120/125; Loss = 0.3068
# Step 121/125; Loss = 0.4689
# Step 122/125; Loss = 0.3520
# Step 123/125; Loss = 0.4354
# Step 124/125; Loss = 0.4221
# Step 125/125; Loss = 0.4173
# Validation IoU Score: 0.5427
# Validation Dice Score: 0.7036
# --------------------
# Epoch 9/10; LR = 0.0001679616
# Step 1/125; Loss = 0.4466
# Step 2/125; Loss = 0.3537
# Step 3/125; Loss = 0.5996
# Step 4/125; Loss = 0.3521
# Step 5/125; Loss = 0.4977
# Step 6/125; Loss = 0.3790
# Step 7/125; Loss = 0.3904
# Step 8/125; Loss = 0.3984
# Step 9/125; Loss = 0.3483
# Step 10/125; Loss = 0.4237
# Step 11/125; Loss = 0.3881
# Step 12/125; Loss = 0.2956
# Step 13/125; Loss = 0.4601
# Step 14/125; Loss = 0.3219
# Step 15/125; Loss = 0.3571
# Step 16/125; Loss = 0.4170
# Step 17/125; Loss = 0.3833
# Step 18/125; Loss = 0.2889
# Step 19/125; Loss = 0.3561
# Step 20/125; Loss = 0.4935
# Step 21/125; Loss = 0.3819
# Step 22/125; Loss = 0.4741
# Step 23/125; Loss = 0.4059
# Step 24/125; Loss = 0.3523
# Step 25/125; Loss = 0.5442
# Step 26/125; Loss = 0.3662
# Step 27/125; Loss = 0.4566
# Step 28/125; Loss = 0.3516
# Step 29/125; Loss = 0.4006
# Step 30/125; Loss = 0.3434
# Step 31/125; Loss = 0.3434
# Step 32/125; Loss = 0.2877
# Step 33/125; Loss = 0.4299
# Step 34/125; Loss = 0.3319
# Step 35/125; Loss = 0.4026
# Step 36/125; Loss = 0.5165
# Step 37/125; Loss = 0.4518
# Step 38/125; Loss = 0.4165
# Step 39/125; Loss = 0.3045
# Step 40/125; Loss = 0.4335
# Step 41/125; Loss = 0.3934
# Step 42/125; Loss = 0.5243
# Step 43/125; Loss = 0.5035
# Step 44/125; Loss = 0.3150
# Step 45/125; Loss = 0.4066
# Step 46/125; Loss = 0.4753
# Step 47/125; Loss = 0.3718
# Step 48/125; Loss = 0.3933
# Step 49/125; Loss = 0.3458
# Step 50/125; Loss = 0.3707
# Step 51/125; Loss = 0.3783
# Step 52/125; Loss = 0.3357
# Step 53/125; Loss = 0.4295
# Step 54/125; Loss = 0.4634
# Step 55/125; Loss = 0.3771
# Step 56/125; Loss = 0.3579
# Step 57/125; Loss = 0.4774
# Step 58/125; Loss = 0.4072
# Step 59/125; Loss = 0.3605
# Step 60/125; Loss = 0.3592
# Step 61/125; Loss = 0.4503
# Step 62/125; Loss = 0.3127
# Step 63/125; Loss = 0.3965
# Step 64/125; Loss = 0.4053
# Step 65/125; Loss = 0.3723
# Step 66/125; Loss = 0.4200
# Step 67/125; Loss = 0.5011
# Step 68/125; Loss = 0.3851
# Step 69/125; Loss = 0.3647
# Step 70/125; Loss = 0.3104
# Step 71/125; Loss = 0.4073
# Step 72/125; Loss = 0.3893
# Step 73/125; Loss = 0.4281
# Step 74/125; Loss = 0.4646
# Step 75/125; Loss = 0.4788
# Step 76/125; Loss = 0.4103
# Step 77/125; Loss = 0.4436
# Step 78/125; Loss = 0.3503
# Step 79/125; Loss = 0.4166
# Step 80/125; Loss = 0.3359
# Step 81/125; Loss = 0.2887
# Step 82/125; Loss = 0.3150
# Step 83/125; Loss = 0.3476
# Step 84/125; Loss = 0.3894
# Step 85/125; Loss = 0.3615
# Step 86/125; Loss = 0.3717
# Step 87/125; Loss = 0.3286
# Step 88/125; Loss = 0.3952
# Step 89/125; Loss = 0.5815
# Step 90/125; Loss = 0.5216
# Step 91/125; Loss = 0.5460
# Step 92/125; Loss = 0.3544
# Step 93/125; Loss = 0.3502
# Step 94/125; Loss = 0.3298
# Step 95/125; Loss = 0.3634
# Step 96/125; Loss = 0.3194
# Step 97/125; Loss = 0.4343
# Step 98/125; Loss = 0.4510
# Step 99/125; Loss = 0.3153
# Step 100/125; Loss = 0.3693
# Step 101/125; Loss = 0.4135
# Step 102/125; Loss = 0.3331
# Step 103/125; Loss = 0.3231
# Step 104/125; Loss = 0.3460
# Step 105/125; Loss = 0.4015
# Step 106/125; Loss = 0.3039
# Step 107/125; Loss = 0.3535
# Step 108/125; Loss = 0.4097
# Step 109/125; Loss = 0.3437
# Step 110/125; Loss = 0.3065
# Step 111/125; Loss = 0.3193
# Step 112/125; Loss = 0.3080
# Step 113/125; Loss = 0.3264
# Step 114/125; Loss = 0.4116
# Step 115/125; Loss = 0.4677
# Step 116/125; Loss = 0.4134
# Step 117/125; Loss = 0.3512
# Step 118/125; Loss = 0.4035
# Step 119/125; Loss = 0.4743
# Step 120/125; Loss = 0.3675
# Step 121/125; Loss = 0.4352
# Step 122/125; Loss = 0.3854
# Step 123/125; Loss = 0.3426
# Step 124/125; Loss = 0.3403
# Step 125/125; Loss = 0.3953
# Validation IoU Score: 0.5386
# Validation Dice Score: 0.7001
# --------------------
# Epoch 10/10; LR = 0.00010077695999999998
# Step 1/125; Loss = 0.3906
# Step 2/125; Loss = 0.3746
# Step 3/125; Loss = 0.3902
# Step 4/125; Loss = 0.3278
# Step 5/125; Loss = 0.4597
# Step 6/125; Loss = 0.3990
# Step 7/125; Loss = 0.3847
# Step 8/125; Loss = 0.3875
# Step 9/125; Loss = 0.2743
# Step 10/125; Loss = 0.4082
# Step 11/125; Loss = 0.4041
# Step 12/125; Loss = 0.3929
# Step 13/125; Loss = 0.3536
# Step 14/125; Loss = 0.3967
# Step 15/125; Loss = 0.3537
# Step 16/125; Loss = 0.4208
# Step 17/125; Loss = 0.3373
# Step 18/125; Loss = 0.4329
# Step 19/125; Loss = 0.3427
# Step 20/125; Loss = 0.3795
# Step 21/125; Loss = 0.4124
# Step 22/125; Loss = 0.3608
# Step 23/125; Loss = 0.2974
# Step 24/125; Loss = 0.4188
# Step 25/125; Loss = 0.4951
# Step 26/125; Loss = 0.4499
# Step 27/125; Loss = 0.3917
# Step 28/125; Loss = 0.4772
# Step 29/125; Loss = 0.4908
# Step 30/125; Loss = 0.2824
# Step 31/125; Loss = 0.3293
# Step 32/125; Loss = 0.5176
# Step 33/125; Loss = 0.4091
# Step 34/125; Loss = 0.3757
# Step 35/125; Loss = 0.4740
# Step 36/125; Loss = 0.4165
# Step 37/125; Loss = 0.2959
# Step 38/125; Loss = 0.3447
# Step 39/125; Loss = 0.4234
# Step 40/125; Loss = 0.4096
# Step 41/125; Loss = 0.4733
# Step 42/125; Loss = 0.4329
# Step 43/125; Loss = 0.4065
# Step 44/125; Loss = 0.3259
# Step 45/125; Loss = 0.2834
# Step 46/125; Loss = 0.3987
# Step 47/125; Loss = 0.3926
# Step 48/125; Loss = 0.3351
# Step 49/125; Loss = 0.4224
# Step 50/125; Loss = 0.3763
# Step 51/125; Loss = 0.4061
# Step 52/125; Loss = 0.3607
# Step 53/125; Loss = 0.3634
# Step 54/125; Loss = 0.3757
# Step 55/125; Loss = 0.4222
# Step 56/125; Loss = 0.3875
# Step 57/125; Loss = 0.4376
# Step 58/125; Loss = 0.4927
# Step 59/125; Loss = 0.3772
# Step 60/125; Loss = 0.3186
# Step 61/125; Loss = 0.4087
# Step 62/125; Loss = 0.3517
# Step 63/125; Loss = 0.4819
# Step 64/125; Loss = 0.4110
# Step 65/125; Loss = 0.3345
# Step 66/125; Loss = 0.4257
# Step 67/125; Loss = 0.3764
# Step 68/125; Loss = 0.4017
# Step 69/125; Loss = 0.2814
# Step 70/125; Loss = 0.3971
# Step 71/125; Loss = 0.3733
# Step 72/125; Loss = 0.4132
# Step 73/125; Loss = 0.4115
# Step 74/125; Loss = 0.4487
# Step 75/125; Loss = 0.4010
# Step 76/125; Loss = 0.3917
# Step 77/125; Loss = 0.4837
# Step 78/125; Loss = 0.4052
# Step 79/125; Loss = 0.3785
# Step 80/125; Loss = 0.4295
# Step 81/125; Loss = 0.3772
# Step 82/125; Loss = 0.4115
# Step 83/125; Loss = 0.3082
# Step 84/125; Loss = 0.2948
# Step 85/125; Loss = 0.3304
# Step 86/125; Loss = 0.3165
# Step 87/125; Loss = 0.5213
# Step 88/125; Loss = 0.3451
# Step 89/125; Loss = 0.4197
# Step 90/125; Loss = 0.3432
# Step 91/125; Loss = 0.4269
# Step 92/125; Loss = 0.2734
# Step 93/125; Loss = 0.3547
# Step 94/125; Loss = 0.4319
# Step 95/125; Loss = 0.4053
# Step 96/125; Loss = 0.5463
# Step 97/125; Loss = 0.2897
# Step 98/125; Loss = 0.3895
# Step 99/125; Loss = 0.2967
# Step 100/125; Loss = 0.3932
# Step 101/125; Loss = 0.4689
# Step 102/125; Loss = 0.3893
# Step 103/125; Loss = 0.3736
# Step 104/125; Loss = 0.3457
# Step 105/125; Loss = 0.4066
# Step 106/125; Loss = 0.3524
# Step 107/125; Loss = 0.3860
# Step 108/125; Loss = 0.3744
# Step 109/125; Loss = 0.3285
# Step 110/125; Loss = 0.3257
# Step 111/125; Loss = 0.3801
# Step 112/125; Loss = 0.3541
# Step 113/125; Loss = 0.4814
# Step 114/125; Loss = 0.3229
# Step 115/125; Loss = 0.4512
# Step 116/125; Loss = 0.4257
# Step 117/125; Loss = 0.3354
# Step 118/125; Loss = 0.4633
# Step 119/125; Loss = 0.4085
# Step 120/125; Loss = 0.3779
# Step 121/125; Loss = 0.3449
# Step 122/125; Loss = 0.3791
# Step 123/125; Loss = 0.3673
# Step 124/125; Loss = 0.4367
# Step 125/125; Loss = 0.3872
# Validation IoU Score: 0.5452
# Validation Dice Score: 0.7057
# --------------------
# Finished Training!
# Time Taken = 7m 51s

# %%
deeplab.load_state_dict(best_weights)
# Out:
# <All keys matched successfully>

# %%
threshold = 0.5

# %%
with torch.no_grad():
    image, mask = next(iter(train_loader))
    image = image.to(device)
    mask = mask.to('cpu')
    pred = deeplab(image)['out'].cpu()
    pred1 = torch.relu(torch.sign(pred - threshold))
    image = image.to('cpu')
    image_show(image[0], mask[0], pred1[0])

# %%
IoU_value = 0
with torch.no_grad():
    for image, mask in train_loader:
        image = image.to(device)
        mask = mask.to('cpu')
        pred = deeplab(image)['out'].cpu()
        pred = torch.relu(torch.sign(pred - threshold)) # Taking 0.4 as the threshold to make the value 1
        IoU_value += binaryJaccardIndex(pred, torch.round(mask).type(torch.int16))
    print(f'Intersection Over Union value = {IoU_value/len(train_loader)}')
    iou = IoU_value/len(train_loader)
    dice_score = 2*iou/(1+iou)
    print('Dice Score for Training data =',dice_score.item())
# Out:
# Intersection Over Union value = 0.7790948152542114
# Dice Score for Training data = 0.8758327960968018

# %%
with torch.no_grad():
    image, mask = next(iter(val_loader))
    image = image.to(device)
    mask = mask.to('cpu')
    pred = deeplab(image)['out'].cpu()
    pred1 = torch.relu(torch.sign(pred - threshold))
    image = image.to('cpu')
    image_show(image[0], mask[0], pred1[0])

# %%
IoU_value = 0
with torch.no_grad():
    for image, mask in val_loader:
        image = image.to(device)
        mask = mask.to('cpu')
        pred = deeplab(image)['out'].cpu()
        pred = torch.relu(torch.sign(pred - threshold)) # Taking 0.4 as the threshold to make the value 1
        IoU_value += binaryJaccardIndex(pred, torch.round(mask).type(torch.int16))
    print(f'Intersection Over Union value = {IoU_value/len(val_loader)}')
    iou = IoU_value/len(val_loader)
    dice_score = 2*iou/(1+iou)
    print('Dice Score for Training data =',dice_score.item())
# Out:
# Intersection Over Union value = 0.5503674149513245
# Dice Score for Training data = 0.709983229637146

# %%
torch.save(deeplab, '../models/DeepLabV3_IoULoss_Image_Segmentation2.pt')
