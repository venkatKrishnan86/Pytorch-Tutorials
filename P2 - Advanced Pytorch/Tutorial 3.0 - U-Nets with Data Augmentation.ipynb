# %% [markdown]
# # Importing Packages

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from torchsummary import summary

import time
import copy
import os

# %%
data_dir = '../datasets/camouflage_image_segmentation/Images'
mask_dir = '../datasets/camouflage_image_segmentation/Masks'

# %%
data_transforms = {
    'Train': transforms.Compose([
        transforms.Resize((128,128)),
        transforms.ColorJitter(),
        # transforms.Grayscale(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ]),
    'Train2': transforms.Compose([
        transforms.Resize((128,128)),
        transforms.RandomHorizontalFlip(p=1),
        # transforms.Grayscale(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ]),
    'Train3': transforms.Compose([
        transforms.Resize((128,128)),
        transforms.RandomVerticalFlip(p=1),
        # transforms.Grayscale(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ]),
    'Validation': transforms.Compose([
        transforms.Resize((128,128)),
        # transforms.Grayscale(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])
}
mask_transforms = {
    'Train': transforms.Compose([
        transforms.Resize((128,128)),
        transforms.Grayscale(),
        transforms.ToTensor()
    ]),
    'Train2': transforms.Compose([
        transforms.Resize((128,128)),
        transforms.RandomHorizontalFlip(p=1),
        transforms.Grayscale(),
        transforms.ToTensor(),
    ]),
    'Train3': transforms.Compose([
        transforms.Resize((128,128)),
        transforms.RandomVerticalFlip(p=1),
        transforms.Grayscale(),
        transforms.ToTensor(),
    ]),
    'Validation': transforms.Compose([
        transforms.Resize((128,128)),
        transforms.Grayscale(),
        transforms.ToTensor()
    ])
}

# %% [markdown]
# ## PyTorch Custom Dataset

# %%
class ImageMaskDataset(Dataset):
    def __init__(self, data_dir, mask_dir, train = True, transform = None, transform2 = None, mask_transform = None, mask_transform2 = None) -> None:
        super(ImageMaskDataset, self).__init__()
        self.imgs = []
        self.transform = transform
        if train:
            for file1 in os.scandir(data_dir+'/Train'):
                file2 = mask_dir+'/Train/'+file1.name[:-3]+'png'
                if self.transform is not None:
                    self.imgs.append((self.transform(Image.open(file1.path).convert('RGB')),mask_transform(Image.open(file2))))
                    for i in range(len(transform2)):
                        self.imgs.append((transform2[i](Image.open(file1.path).convert('RGB')),mask_transform2[i](Image.open(file2))))
                else:
                    self.imgs.append((Image.open(file1.path).convert('RGB'),Image.open(file2)))
        else:
            for file1 in os.scandir(data_dir+'/Validation'):
                file2 = mask_dir+'/Validation/'+file1.name[:-3]+'png'
                if self.transform is not None:
                    self.imgs.append((self.transform(Image.open(file1.path).convert('RGB')),mask_transform(Image.open(file2))))
                else:
                    self.imgs.append((Image.open(file1.path).convert('RGB'),Image.open(file2)))
                    # if self.imgs[-1][0].shape[0] == 1:
                    #     self.imgs[-1] = (self.imgs[-1][0].repeat(3,1,1), self.imgs[-1][1])
    
    def __len__(self):
        return len(self.imgs)
    
    def __getitem__(self, index):
        return self.imgs[index]

# %%
train_data = ImageMaskDataset(data_dir, mask_dir, train = True, transform=data_transforms['Train'], transform2=[data_transforms['Train2'], data_transforms['Train3']], mask_transform=mask_transforms['Train'], mask_transform2=[mask_transforms['Train2'],mask_transforms['Train3']])
val_data = ImageMaskDataset(data_dir, mask_dir, train = False, transform=data_transforms['Validation'], mask_transform=mask_transforms['Validation'])

# %%
train_loader = DataLoader(
    train_data,
    batch_size = 64,
    shuffle = True,
)
val_loader = DataLoader(
    val_data,
    batch_size = 64,
    shuffle = True,
)

# %% [markdown]
# ## Image plot

# %%
def image_show(image, mask, pred = None):
    print(max(image))
    image = image*0.5 + 0.5
    mask = mask*0.5 + 0.5
    plt.figure(figsize=(20,10))
    if pred is not None:
        plt.subplot(1,3,1)
        plt.title('Image')
        plt.imshow(image.numpy().transpose((1,2,0)), cmap='gray')
        plt.subplot(1,3,2)
        plt.title('True Mask')
        plt.imshow(mask.numpy().transpose((1,2,0)), cmap='gray')
        plt.subplot(1,3,3)
        plt.title('Predicted Mask')
        plt.imshow(pred.detach().numpy().transpose((1,2,0)), cmap='gray')
    else:
        plt.subplot(1,3,1)
        plt.title('Image')
        plt.imshow(image.numpy().transpose((1,2,0)), cmap='gray')
        plt.subplot(1,3,2)
        plt.title('Mask')
        plt.imshow(mask.numpy().transpose((1,2,0)), cmap='gray')

# %%
dataiter = iter(train_loader)
image, mask = next(dataiter)
index = 0
image_show(image[index], mask[index])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/venkatakrishnanvk/Desktop/ML & DL/Deep Learning/Pytorch-Tutorial/advanced_tutorials/Tutorial 3.02 - U-Nets with Data Augmentation.ipynb Cell 11 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/venkatakrishnanvk/Desktop/ML%20%26%20DL/Deep%20Learning/Pytorch-Tutorial/advanced_tutorials/Tutorial%203.02%20-%20U-Nets%20with%20Data%20Augmentation.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> image, mask = next(dataiter)
#       <a href='vscode-notebook-cell:/Users/venkatakrishnanvk/Desktop/ML%20%26%20DL/Deep%20Learning/Pytorch-Tutorial/advanced_tutorials/Tutorial%203.02%20-%20U-Nets%20with%20Data%20Augmentation.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> index = 0
# ----> <a href='vscode-notebook-cell:/Users/venkatakrishnanvk/Desktop/ML%20%26%20DL/Deep%20Learning/Pytorch-Tutorial/advanced_tutorials/Tutorial%203.02%20-%20U-Nets%20with%20Data%20Augmentation.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a> image_show(image[index], mask[index])
#
# /Users/venkatakrishnanvk/Desktop/ML & DL/Deep Learning/Pytorch-Tutorial/advanced_tutorials/Tutorial 3.02 - U-Nets with Data Augmentation.ipynb Cell 11 in image_show(image, mask, pred)
#       <a href='vscode-notebook-cell:/Users/venkatakrishnanvk/Desktop/ML%20%26%20DL/Deep%20Learning/Pytorch-Tutorial/advanced_tutorials/Tutorial%203.02%20-%20U-Nets%20with%20Data%20Augmentation.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> def image_show(image, mask, pred = None):
# ----> <a href='vscode-notebook-cell:/Users/venkatakrishnanvk/Desktop/ML%20%26%20DL/Deep%20Learning/Pytorch-Tutorial/advanced_tutorials/Tutorial%203.02%20-%20U-Nets%20with%20Data%20Augmentation.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a>     print(max(image.numpy().any()))
#       <a href='vscode-notebook-cell:/Users/venkatakrishnanvk/Desktop/ML%20%26%20DL/Deep%20Learning/Pytorch-Tutorial/advanced_tutorials/Tutorial%203.02%20-%20U-Nets%20with%20Data%20Augmentation.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a>     image = image*0.5 + 0.5
#       <a href='vscode-notebook-cell:/Users/venkatakrishnanvk/Desktop/ML%20%26%20DL/Deep%20Learning/Pytorch-Tutorial/advanced_tutorials/Tutorial%203.02%20-%20U-Nets%20with%20Data%20Augmentation.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a>     mask = mask*0.5 + 0.5
#
# TypeError: 'numpy.bool_' object is not iterable

# %%
device = torch.device('mps' if torch.backends.mps.is_available() else 'cpu') # mps: Metal Performance Shaders - For Apple M1 GPU
device
# Out:
# device(type='mps')

# %% [markdown]
# # U-Net

# %%
class UNet(nn.Module):
    def __init__(self) -> None:
        super(UNet, self).__init__()

        # ENCODER
        self.conv11 = nn.Conv2d(3, 8, 7, 1, 'same') # 200, 200, 3 --> 200, 200, 8
        self.norm11 = nn.BatchNorm2d(8)
        self.conv12 = nn.Conv2d(8, 32, 5, 1, 'same') # 200, 200, 8 --> 200, 200, 32
        self.norm12 = nn.BatchNorm2d(32)
        self.conv13 = nn.Conv2d(32, 64, 3, 1, 'same') # 200, 200, 32 --> 200, 200, 64
        self.norm13 = nn.BatchNorm2d(64)

        self.maxpool1 = nn.MaxPool2d(2,2) # 100, 100, 64

        self.conv21 = nn.Conv2d(64, 128, 7, 1, 'same') # 100, 100, 64 --> 100, 100, 128
        self.norm21 = nn.BatchNorm2d(128)
        self.conv22 = nn.Conv2d(128, 128, 5, 1, 'same') # 100, 100, 128 --> 100, 100, 128
        self.norm22 = nn.BatchNorm2d(128)
        self.conv23 = nn.Conv2d(128, 128, 3, 1, 'same') # 100, 100, 128 --> 100, 100, 128
        self.norm23 = nn.BatchNorm2d(128)

        self.maxpool2 = nn.MaxPool2d(2,2) # 50, 50, 128

        self.conv31 = nn.Conv2d(128, 256, 5, 1, 'same') # 50, 50, 128 --> 50, 50, 256
        self.norm31 = nn.BatchNorm2d(256)
        self.conv32 = nn.Conv2d(256, 256, 5, 1, 'same') # 50, 50, 256 --> 50, 50, 256
        self.norm32 = nn.BatchNorm2d(256)
        self.conv33 = nn.Conv2d(256, 256, 3, 1, 'same') # 50, 50, 256 --> 50, 50, 256
        self.norm33 = nn.BatchNorm2d(256)

        self.maxpool3 = nn.MaxPool2d(2,2) # 25, 25, 128

        self.conv41 = nn.Conv2d(256, 512, 3, 1, 1) # 25, 25, 256 --> 25, 25, 512
        self.norm41 = nn.BatchNorm2d(512)
        self.conv42 = nn.Conv2d(512, 512, 3, 1, 1) # 25, 25, 512 --> 25, 25, 512
        self.norm42 = nn.BatchNorm2d(512)
        self.conv43 = nn.Conv2d(512, 1024, 3, 1, 1) # 25, 25, 512 --> 25, 25, 1024
        self.norm43 = nn.BatchNorm2d(1024)

        # DECODER
        self.convT1 = nn.ConvTranspose2d(1024, 256, 2, 2)

        self.conv51 = nn.Conv2d(512, 512, 3, 1, 'same')
        self.norm51 = nn.BatchNorm2d(512)
        self.conv52 = nn.Conv2d(512, 512, 3, 1, 'same')
        self.norm52 = nn.BatchNorm2d(512)
        self.conv53 = nn.Conv2d(512, 512, 5, 1, 'same')
        self.norm53 = nn.BatchNorm2d(512)

        self.convT2 = nn.ConvTranspose2d(512, 128, 2, 2)

        self.conv61 = nn.Conv2d(256, 256, 3, 1, 'same')
        self.norm61 = nn.BatchNorm2d(256)
        self.conv62 = nn.Conv2d(256, 256, 5, 1, 'same')
        self.norm62 = nn.BatchNorm2d(256)
        self.conv63 = nn.Conv2d(256, 256, 5, 1, 'same')
        self.norm63 = nn.BatchNorm2d(256)

        self.convT3 = nn.ConvTranspose2d(256, 64, 2, 2)

        self.conv71 = nn.Conv2d(128, 64, 3, 1, 'same')
        self.norm71 = nn.BatchNorm2d(64)
        self.conv72 = nn.Conv2d(64, 16, 5, 1, 'same')
        self.norm72 = nn.BatchNorm2d(16)
        self.conv73 = nn.Conv2d(16, 1, 7, 1, 'same')
        self.norm73 = nn.BatchNorm2d(1)

    def forward(self, x):
        # ENCODER
        x = torch.relu(self.norm11(self.conv11(x)))
        x = torch.relu(self.norm12(self.conv12(x)))
        x_temp1 = torch.relu(self.norm13(self.conv13(x)))

        x = self.maxpool1(x_temp1)

        x = torch.relu(self.norm21(self.conv21(x)))
        x = torch.relu(self.norm22(self.conv22(x)))
        x_temp2 = torch.relu(self.norm23(self.conv23(x)))

        x = self.maxpool2(x_temp2)

        x = torch.relu(self.norm31(self.conv31(x)))
        x = torch.relu(self.norm32(self.conv32(x)))
        x_temp3 = torch.relu(self.norm33(self.conv33(x)))

        x = self.maxpool3(x_temp3)

        x = torch.relu(self.norm41(self.conv41(x)))
        x = torch.relu(self.norm42(self.conv42(x)))
        x = torch.relu(self.norm43(self.conv43(x)))

        # DECODER
        x = self.convT1(x)

        x = torch.cat((x,x_temp3), 1)

        x = torch.relu(self.norm51(self.conv51(x)))
        x = torch.relu(self.norm52(self.conv52(x)))
        x = torch.relu(self.norm53(self.conv53(x)))

        x = self.convT2(x)

        x = torch.cat((x,x_temp2), 1)

        x = torch.relu(self.norm61(self.conv61(x)))
        x = torch.relu(self.norm62(self.conv62(x)))
        x = torch.relu(self.norm63(self.conv63(x)))

        x = self.convT3(x)   

        x = torch.cat((x,x_temp1), 1)

        x = torch.relu(self.norm71(self.conv71(x)))
        x = torch.relu(self.norm72(self.conv72(x)))
        x = torch.sigmoid(self.norm73(self.conv73(x)))

        return x

# %%
unet = UNet().to(device)

# %%
summary(copy.deepcopy(unet).to('cpu'), (3, 128, 128))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 8, 128, 128]           1,184
#        BatchNorm2d-2          [-1, 8, 128, 128]              16
#             Conv2d-3         [-1, 32, 128, 128]           6,432
#        BatchNorm2d-4         [-1, 32, 128, 128]              64
#             Conv2d-5         [-1, 64, 128, 128]          18,496
#        BatchNorm2d-6         [-1, 64, 128, 128]             128
#          MaxPool2d-7           [-1, 64, 64, 64]               0
#             Conv2d-8          [-1, 128, 64, 64]         401,536
#        BatchNorm2d-9          [-1, 128, 64, 64]             256
#            Conv2d-10          [-1, 128, 64, 64]         409,728
#       BatchNorm2d-11          [-1, 128, 64, 64]             256
#            Conv2d-12          [-1, 128, 64, 64]         147,584
#       BatchNorm2d-13          [-1, 128, 64, 64]             256
#         MaxPool2d-14          [-1, 128, 32, 32]               0
#            Conv2d-15          [-1, 256, 32, 32]         819,456
#       BatchNorm2d-16          [-1, 256, 32, 32]             512
#            Conv2d-17          [-1, 256, 32, 32]       1,638,656
#       BatchNorm2d-18          [-1, 256, 32, 32]             512
#            Conv2d-19          [-1, 256, 32, 32]         590,080
#       BatchNorm2d-20          [-1, 256, 32, 32]             512
#         MaxPool2d-21          [-1, 256, 16, 16]               0
#            Conv2d-22          [-1, 512, 16, 16]       1,180,160
#       BatchNorm2d-23          [-1, 512, 16, 16]           1,024
#            Conv2d-24          [-1, 512, 16, 16]       2,359,808
#       BatchNorm2d-25          [-1, 512, 16, 16]           1,024
#            Conv2d-26         [-1, 1024, 16, 16]       4,719,616
#       BatchNorm2d-27         [-1, 1024, 16, 16]           2,048
#   ConvTranspose2d-28          [-1, 256, 32, 32]       1,048,832
#            Conv2d-29          [-1, 512, 32, 32]       2,359,808
#       BatchNorm2d-30          [-1, 512, 32, 32]           1,024
#            Conv2d-31          [-1, 512, 32, 32]       2,359,808
#       BatchNorm2d-32          [-1, 512, 32, 32]           1,024
#            Conv2d-33          [-1, 512, 32, 32]       6,554,112
#       BatchNorm2d-34          [-1, 512, 32, 32]           1,024
#   ConvTranspose2d-35          [-1, 128, 64, 64]         262,272
#            Conv2d-36          [-1, 256, 64, 64]         590,080
#       BatchNorm2d-37          [-1, 256, 64, 64]             512
#            Conv2d-38          [-1, 256, 64, 64]       1,638,656
#       BatchNorm2d-39          [-1, 256, 64, 64]             512
#            Conv2d-40          [-1, 256, 64, 64]       1,638,656
#       BatchNorm2d-41          [-1, 256, 64, 64]             512
#   ConvTranspose2d-42         [-1, 64, 128, 128]          65,600
#            Conv2d-43         [-1, 64, 128, 128]          73,792
#       BatchNorm2d-44         [-1, 64, 128, 128]             128
#            Conv2d-45         [-1, 16, 128, 128]          25,616
#       BatchNorm2d-46         [-1, 16, 128, 128]              32
#            Conv2d-47          [-1, 1, 128, 128]             785
#       BatchNorm2d-48          [-1, 1, 128, 128]               2
# ================================================================
# Total params: 28,922,131
# Trainable params: 28,922,131
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 179.75
# Params size (MB): 110.33
# Estimated Total Size (MB): 290.27
# ----------------------------------------------------------------

# %% [markdown]
# # Loss and Optimizer

# %%
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(unet.parameters(), lr=4e-1)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size = 1, gamma=0.65)

# %%
num_epochs = 25
batches = len(train_loader)
losses = []

# %%
batches
# Out:
# 32

# %%
tic = time.time()
for epoch in range(num_epochs):
    print(f'Epoch {epoch+1}/{num_epochs} (LR: {scheduler.get_last_lr()[0]:.5f})')
    for i, (images,masks) in enumerate(train_loader):
        images = images.to(device)
        masks = torch.round(masks.to(device))

        preds = unet.forward(images)
        loss = criterion(preds, masks)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        print(f'Step {i+1}/{batches}; Loss = {loss.item():.4f}')
        losses.append(loss.item())
    scheduler.step()
print('Finished Training!')
print(f'Time Taken = {(time.time() - tic)//60:.0f}m {(time.time() - tic)%60:.0f}s')
# Out:
# Epoch 1/25 (LR: 0.40000)
# Step 1/32; Loss = 0.8002
# Step 2/32; Loss = 0.6057
# Step 3/32; Loss = 0.5131
# Step 4/32; Loss = 0.4625
# Step 5/32; Loss = 0.4714
# Step 6/32; Loss = 0.4801
# Step 7/32; Loss = 0.5050
# Step 8/32; Loss = 0.4531
# Step 9/32; Loss = 0.4685
# Step 10/32; Loss = 0.4053
# Step 11/32; Loss = 0.4918
# Step 12/32; Loss = 0.4562
# Step 13/32; Loss = 0.4173
# Step 14/32; Loss = 0.3648
# Step 15/32; Loss = 0.4237
# Step 16/32; Loss = 0.3903
# Step 17/32; Loss = 0.4142
# Step 18/32; Loss = 0.3161
# Step 19/32; Loss = 0.3870
# Step 20/32; Loss = 0.3620
# Step 21/32; Loss = 0.3943
# Step 22/32; Loss = 0.3660
# Step 23/32; Loss = 0.3845
# Step 24/32; Loss = 0.3263
# Step 25/32; Loss = 0.3643
# Step 26/32; Loss = 0.3452
# Step 27/32; Loss = 0.3618
# Step 28/32; Loss = 0.3642
# Step 29/32; Loss = 0.3778
# Step 30/32; Loss = 0.3608
# Step 31/32; Loss = 0.3301
# Step 32/32; Loss = 0.3594
# Epoch 2/25 (LR: 0.26000)
# Step 1/32; Loss = 0.3709
# Step 2/32; Loss = 0.3949
# Step 3/32; Loss = 0.3571
# Step 4/32; Loss = 0.3848
# Step 5/32; Loss = 0.3707
# Step 6/32; Loss = 0.3278
# Step 7/32; Loss = 0.3541
# Step 8/32; Loss = 0.3180
# Step 9/32; Loss = 0.3623
# Step 10/32; Loss = 0.3461
# Step 11/32; Loss = 0.3302
# Step 12/32; Loss = 0.3208
# Step 13/32; Loss = 0.3145
# Step 14/32; Loss = 0.3875
# Step 15/32; Loss = 0.3590
# Step 16/32; Loss = 0.3647
# Step 17/32; Loss = 0.3702
# Step 18/32; Loss = 0.3075
# Step 19/32; Loss = 0.3601
# Step 20/32; Loss = 0.3776
# Step 21/32; Loss = 0.3464
# Step 22/32; Loss = 0.3441
# Step 23/32; Loss = 0.3482
# Step 24/32; Loss = 0.3615
# Step 25/32; Loss = 0.3507
# Step 26/32; Loss = 0.3807
# Step 27/32; Loss = 0.3443
# Step 28/32; Loss = 0.3598
# Step 29/32; Loss = 0.3605
# Step 30/32; Loss = 0.3441
# Step 31/32; Loss = 0.3292
# Step 32/32; Loss = 0.3032
# Epoch 3/25 (LR: 0.16900)
# Step 1/32; Loss = 0.3667
# Step 2/32; Loss = 0.3369
# Step 3/32; Loss = 0.3268
# Step 4/32; Loss = 0.3328
# Step 5/32; Loss = 0.3654
# Step 6/32; Loss = 0.3671
# Step 7/32; Loss = 0.3338
# Step 8/32; Loss = 0.3434
# Step 9/32; Loss = 0.3541
# Step 10/32; Loss = 0.3601
# Step 11/32; Loss = 0.3429
# Step 12/32; Loss = 0.3583
# Step 13/32; Loss = 0.3234
# Step 14/32; Loss = 0.3530
# Step 15/32; Loss = 0.3498
# Step 16/32; Loss = 0.3852
# Step 17/32; Loss = 0.3612
# Step 18/32; Loss = 0.3530
# Step 19/32; Loss = 0.3698
# Step 20/32; Loss = 0.3570
# Step 21/32; Loss = 0.3485
# Step 22/32; Loss = 0.3396
# Step 23/32; Loss = 0.3532
# Step 24/32; Loss = 0.3778
# Step 25/32; Loss = 0.3395
# Step 26/32; Loss = 0.3509
# Step 27/32; Loss = 0.3786
# Step 28/32; Loss = 0.3547
# Step 29/32; Loss = 0.3160
# Step 30/32; Loss = 0.3398
# Step 31/32; Loss = 0.3484
# Step 32/32; Loss = 0.2978
# Epoch 4/25 (LR: 0.10985)
# Step 1/32; Loss = 0.3616
# Step 2/32; Loss = 0.3553
# Step 3/32; Loss = 0.3495
# Step 4/32; Loss = 0.3297
# Step 5/32; Loss = 0.3510
# Step 6/32; Loss = 0.3617
# Step 7/32; Loss = 0.3197
# Step 8/32; Loss = 0.3240
# Step 9/32; Loss = 0.3620
# Step 10/32; Loss = 0.3424
# Step 11/32; Loss = 0.3610
# Step 12/32; Loss = 0.3441
# Step 13/32; Loss = 0.3484
# Step 14/32; Loss = 0.3259
# Step 15/32; Loss = 0.3519
# Step 16/32; Loss = 0.3216
# Step 17/32; Loss = 0.3959
# Step 18/32; Loss = 0.3772
# Step 19/32; Loss = 0.3225
# Step 20/32; Loss = 0.3870
# Step 21/32; Loss = 0.3322
# Step 22/32; Loss = 0.3272
# Step 23/32; Loss = 0.3583
# Step 24/32; Loss = 0.3276
# Step 25/32; Loss = 0.3213
# Step 26/32; Loss = 0.3350
# Step 27/32; Loss = 0.3654
# Step 28/32; Loss = 0.3567
# Step 29/32; Loss = 0.3937
# Step 30/32; Loss = 0.3483
# Step 31/32; Loss = 0.3642
# Step 32/32; Loss = 0.3584
# Epoch 5/25 (LR: 0.07140)
# Step 1/32; Loss = 0.3754
# Step 2/32; Loss = 0.3441
# Step 3/32; Loss = 0.3701
# Step 4/32; Loss = 0.3476
# Step 5/32; Loss = 0.3372
# Step 6/32; Loss = 0.3470
# Step 7/32; Loss = 0.4151
# Step 8/32; Loss = 0.3389
# Step 9/32; Loss = 0.3160
# Step 10/32; Loss = 0.3387
# Step 11/32; Loss = 0.3351
# Step 12/32; Loss = 0.3550
# Step 13/32; Loss = 0.3532
# Step 14/32; Loss = 0.3094
# Step 15/32; Loss = 0.3580
# Step 16/32; Loss = 0.3585
# Step 17/32; Loss = 0.3580
# Step 18/32; Loss = 0.3400
# Step 19/32; Loss = 0.3557
# Step 20/32; Loss = 0.3491
# Step 21/32; Loss = 0.3848
# Step 22/32; Loss = 0.3678
# Step 23/32; Loss = 0.3214
# Step 24/32; Loss = 0.3539
# Step 25/32; Loss = 0.3414
# Step 26/32; Loss = 0.3486
# Step 27/32; Loss = 0.3529
# Step 28/32; Loss = 0.3322
# Step 29/32; Loss = 0.3360
# Step 30/32; Loss = 0.3234
# Step 31/32; Loss = 0.3028
# Step 32/32; Loss = 0.3391
# Epoch 6/25 (LR: 0.04641)
# Step 1/32; Loss = 0.3358
# Step 2/32; Loss = 0.3627
# Step 3/32; Loss = 0.3434
# Step 4/32; Loss = 0.3752
# Step 5/32; Loss = 0.3320
# Step 6/32; Loss = 0.3407
# Step 7/32; Loss = 0.3005
# Step 8/32; Loss = 0.3272
# Step 9/32; Loss = 0.3364
# Step 10/32; Loss = 0.3644
# Step 11/32; Loss = 0.3428
# Step 12/32; Loss = 0.3120
# Step 13/32; Loss = 0.3491
# Step 14/32; Loss = 0.3382
# Step 15/32; Loss = 0.3132
# Step 16/32; Loss = 0.3357
# Step 17/32; Loss = 0.3757
# Step 18/32; Loss = 0.3636
# Step 19/32; Loss = 0.3434
# Step 20/32; Loss = 0.3344
# Step 21/32; Loss = 0.3586
# Step 22/32; Loss = 0.3469
# Step 23/32; Loss = 0.3938
# Step 24/32; Loss = 0.3435
# Step 25/32; Loss = 0.3574
# Step 26/32; Loss = 0.3687
# Step 27/32; Loss = 0.3506
# Step 28/32; Loss = 0.3503
# Step 29/32; Loss = 0.3111
# Step 30/32; Loss = 0.3378
# Step 31/32; Loss = 0.3542
# Step 32/32; Loss = 0.3394
# Epoch 7/25 (LR: 0.03017)
# Step 1/32; Loss = 0.3698
# Step 2/32; Loss = 0.3526
# Step 3/32; Loss = 0.3406
# Step 4/32; Loss = 0.3410
# Step 5/32; Loss = 0.3128
# Step 6/32; Loss = 0.3175
# Step 7/32; Loss = 0.3542
# Step 8/32; Loss = 0.3392
# Step 9/32; Loss = 0.3353
# Step 10/32; Loss = 0.3284
# Step 11/32; Loss = 0.3384
# Step 12/32; Loss = 0.3215
# Step 13/32; Loss = 0.3623
# Step 14/32; Loss = 0.3680
# Step 15/32; Loss = 0.3347
# Step 16/32; Loss = 0.3378
# Step 17/32; Loss = 0.3226
# Step 18/32; Loss = 0.3237
# Step 19/32; Loss = 0.3300
# Step 20/32; Loss = 0.3287
# Step 21/32; Loss = 0.3759
# Step 22/32; Loss = 0.3470
# Step 23/32; Loss = 0.3370
# Step 24/32; Loss = 0.4012
# Step 25/32; Loss = 0.3267
# Step 26/32; Loss = 0.3598
# Step 27/32; Loss = 0.3700
# Step 28/32; Loss = 0.3275
# Step 29/32; Loss = 0.3280
# Step 30/32; Loss = 0.3573
# Step 31/32; Loss = 0.3309
# Step 32/32; Loss = 0.5385
# Epoch 8/25 (LR: 0.01961)
# Step 1/32; Loss = 0.3355
# Step 2/32; Loss = 0.3481
# Step 3/32; Loss = 0.3567
# Step 4/32; Loss = 0.3450
# Step 5/32; Loss = 0.3557
# Step 6/32; Loss = 0.3440
# Step 7/32; Loss = 0.3717
# Step 8/32; Loss = 0.3471
# Step 9/32; Loss = 0.3014
# Step 10/32; Loss = 0.3476
# Step 11/32; Loss = 0.3948
# Step 12/32; Loss = 0.3326
# Step 13/32; Loss = 0.3105
# Step 14/32; Loss = 0.3403
# Step 15/32; Loss = 0.3622
# Step 16/32; Loss = 0.3318
# Step 17/32; Loss = 0.3249
# Step 18/32; Loss = 0.2992
# Step 19/32; Loss = 0.3546
# Step 20/32; Loss = 0.3252
# Step 21/32; Loss = 0.3384
# Step 22/32; Loss = 0.3498
# Step 23/32; Loss = 0.3574
# Step 24/32; Loss = 0.3458
# Step 25/32; Loss = 0.3497
# Step 26/32; Loss = 0.3469
# Step 27/32; Loss = 0.3194
# Step 28/32; Loss = 0.3763
# Step 29/32; Loss = 0.3372
# Step 30/32; Loss = 0.3716
# Step 31/32; Loss = 0.3121
# Step 32/32; Loss = 0.3755
# Epoch 9/25 (LR: 0.01275)
# Step 1/32; Loss = 0.3313
# Step 2/32; Loss = 0.3035
# Step 3/32; Loss = 0.3339
# Step 4/32; Loss = 0.3913
# Step 5/32; Loss = 0.3301
# Step 6/32; Loss = 0.3502
# Step 7/32; Loss = 0.3969
# Step 8/32; Loss = 0.3135
# Step 9/32; Loss = 0.3455
# Step 10/32; Loss = 0.3619
# Step 11/32; Loss = 0.3280
# Step 12/32; Loss = 0.3516
# Step 13/32; Loss = 0.3419
# Step 14/32; Loss = 0.3184
# Step 15/32; Loss = 0.3393
# Step 16/32; Loss = 0.3315
# Step 17/32; Loss = 0.3401
# Step 18/32; Loss = 0.3748
# Step 19/32; Loss = 0.3466
# Step 20/32; Loss = 0.3625
# Step 21/32; Loss = 0.3520
# Step 22/32; Loss = 0.3633
# Step 23/32; Loss = 0.3289
# Step 24/32; Loss = 0.3515
# Step 25/32; Loss = 0.3630
# Step 26/32; Loss = 0.3263
# Step 27/32; Loss = 0.3379
# Step 28/32; Loss = 0.3146
# Step 29/32; Loss = 0.3066
# Step 30/32; Loss = 0.3423
# Step 31/32; Loss = 0.3144
# Step 32/32; Loss = 0.3715
# Epoch 10/25 (LR: 0.00828)
# Step 1/32; Loss = 0.3564
# Step 2/32; Loss = 0.3431
# Step 3/32; Loss = 0.3180
# Step 4/32; Loss = 0.3188
# Step 5/32; Loss = 0.3366
# Step 6/32; Loss = 0.2965
# Step 7/32; Loss = 0.3345
# Step 8/32; Loss = 0.3370
# Step 9/32; Loss = 0.3601
# Step 10/32; Loss = 0.3459
# Step 11/32; Loss = 0.3528
# Step 12/32; Loss = 0.3427
# Step 13/32; Loss = 0.3571
# Step 14/32; Loss = 0.3407
# Step 15/32; Loss = 0.3524
# Step 16/32; Loss = 0.3068
# Step 17/32; Loss = 0.4008
# Step 18/32; Loss = 0.3478
# Step 19/32; Loss = 0.3471
# Step 20/32; Loss = 0.3290
# Step 21/32; Loss = 0.3410
# Step 22/32; Loss = 0.3062
# Step 23/32; Loss = 0.3397
# Step 24/32; Loss = 0.3158
# Step 25/32; Loss = 0.3936
# Step 26/32; Loss = 0.3436
# Step 27/32; Loss = 0.3361
# Step 28/32; Loss = 0.3599
# Step 29/32; Loss = 0.3262
# Step 30/32; Loss = 0.3391
# Step 31/32; Loss = 0.3530
# Step 32/32; Loss = 0.3230
# Epoch 11/25 (LR: 0.00539)
# Step 1/32; Loss = 0.3602
# Step 2/32; Loss = 0.3236
# Step 3/32; Loss = 0.3314
# Step 4/32; Loss = 0.3727
# Step 5/32; Loss = 0.3502
# Step 6/32; Loss = 0.3618
# Step 7/32; Loss = 0.3350
# Step 8/32; Loss = 0.3563
# Step 9/32; Loss = 0.2767
# Step 10/32; Loss = 0.3428
# Step 11/32; Loss = 0.3381
# Step 12/32; Loss = 0.3862
# Step 13/32; Loss = 0.3631
# Step 14/32; Loss = 0.3126
# Step 15/32; Loss = 0.3601
# Step 16/32; Loss = 0.3228
# Step 17/32; Loss = 0.3020
# Step 18/32; Loss = 0.3143
# Step 19/32; Loss = 0.3955
# Step 20/32; Loss = 0.3380
# Step 21/32; Loss = 0.3655
# Step 22/32; Loss = 0.3145
# Step 23/32; Loss = 0.3339
# Step 24/32; Loss = 0.3327
# Step 25/32; Loss = 0.3209
# Step 26/32; Loss = 0.3680
# Step 27/32; Loss = 0.3241
# Step 28/32; Loss = 0.3178
# Step 29/32; Loss = 0.3515
# Step 30/32; Loss = 0.3307
# Step 31/32; Loss = 0.3301
# Step 32/32; Loss = 0.4172
# Epoch 12/25 (LR: 0.00350)
# Step 1/32; Loss = 0.3494
# Step 2/32; Loss = 0.3302
# Step 3/32; Loss = 0.3397
# Step 4/32; Loss = 0.3279
# Step 5/32; Loss = 0.3019
# Step 6/32; Loss = 0.3979
# Step 7/32; Loss = 0.3616
# Step 8/32; Loss = 0.3091
# Step 9/32; Loss = 0.3835
# Step 10/32; Loss = 0.3705
# Step 11/32; Loss = 0.3384
# Step 12/32; Loss = 0.3196
# Step 13/32; Loss = 0.3211
# Step 14/32; Loss = 0.3452
# Step 15/32; Loss = 0.3268
# Step 16/32; Loss = 0.3356
# Step 17/32; Loss = 0.3623
# Step 18/32; Loss = 0.3415
# Step 19/32; Loss = 0.3372
# Step 20/32; Loss = 0.3375
# Step 21/32; Loss = 0.3139
# Step 22/32; Loss = 0.3731
# Step 23/32; Loss = 0.3252
# Step 24/32; Loss = 0.3280
# Step 25/32; Loss = 0.3253
# Step 26/32; Loss = 0.3257
# Step 27/32; Loss = 0.3495
# Step 28/32; Loss = 0.3563
# Step 29/32; Loss = 0.3342
# Step 30/32; Loss = 0.3368
# Step 31/32; Loss = 0.3481
# Step 32/32; Loss = 0.3356
# Epoch 13/25 (LR: 0.00228)
# Step 1/32; Loss = 0.3290
# Step 2/32; Loss = 0.3526
# Step 3/32; Loss = 0.3408
# Step 4/32; Loss = 0.3175
# Step 5/32; Loss = 0.3219
# Step 6/32; Loss = 0.3112
# Step 7/32; Loss = 0.3325
# Step 8/32; Loss = 0.3162
# Step 9/32; Loss = 0.3127
# Step 10/32; Loss = 0.3905
# Step 11/32; Loss = 0.3562
# Step 12/32; Loss = 0.3245
# Step 13/32; Loss = 0.3174
# Step 14/32; Loss = 0.3372
# Step 15/32; Loss = 0.3688
# Step 16/32; Loss = 0.3508
# Step 17/32; Loss = 0.3464
# Step 18/32; Loss = 0.3412
# Step 19/32; Loss = 0.3125
# Step 20/32; Loss = 0.3676
# Step 21/32; Loss = 0.3320
# Step 22/32; Loss = 0.3469
# Step 23/32; Loss = 0.3512
# Step 24/32; Loss = 0.3619
# Step 25/32; Loss = 0.3362
# Step 26/32; Loss = 0.3475
# Step 27/32; Loss = 0.3319
# Step 28/32; Loss = 0.3749
# Step 29/32; Loss = 0.3208
# Step 30/32; Loss = 0.3544
# Step 31/32; Loss = 0.3432
# Step 32/32; Loss = 0.3343
# Epoch 14/25 (LR: 0.00148)
# Step 1/32; Loss = 0.3375
# Step 2/32; Loss = 0.3225
# Step 3/32; Loss = 0.3219
# Step 4/32; Loss = 0.2927
# Step 5/32; Loss = 0.3195
# Step 6/32; Loss = 0.3457
# Step 7/32; Loss = 0.2918
# Step 8/32; Loss = 0.3286
# Step 9/32; Loss = 0.3451
# Step 10/32; Loss = 0.3307
# Step 11/32; Loss = 0.3259
# Step 12/32; Loss = 0.3330
# Step 13/32; Loss = 0.3205
# Step 14/32; Loss = 0.3771
# Step 15/32; Loss = 0.3444
# Step 16/32; Loss = 0.3617
# Step 17/32; Loss = 0.3615
# Step 18/32; Loss = 0.3696
# Step 19/32; Loss = 0.3406
# Step 20/32; Loss = 0.3266
# Step 21/32; Loss = 0.3507
# Step 22/32; Loss = 0.3763
# Step 23/32; Loss = 0.3458
# Step 24/32; Loss = 0.3219
# Step 25/32; Loss = 0.3488
# Step 26/32; Loss = 0.3384
# Step 27/32; Loss = 0.3597
# Step 28/32; Loss = 0.3637
# Step 29/32; Loss = 0.3459
# Step 30/32; Loss = 0.3723
# Step 31/32; Loss = 0.3130
# Step 32/32; Loss = 0.3208
# Epoch 15/25 (LR: 0.00096)
# Step 1/32; Loss = 0.3047
# Step 2/32; Loss = 0.3174
# Step 3/32; Loss = 0.3302
# Step 4/32; Loss = 0.3070
# Step 5/32; Loss = 0.3446
# Step 6/32; Loss = 0.3771
# Step 7/32; Loss = 0.3402
# Step 8/32; Loss = 0.3595
# Step 9/32; Loss = 0.3435
# Step 10/32; Loss = 0.3566
# Step 11/32; Loss = 0.3808
# Step 12/32; Loss = 0.3312
# Step 13/32; Loss = 0.4159
# Step 14/32; Loss = 0.3385
# Step 15/32; Loss = 0.3377
# Step 16/32; Loss = 0.3583
# Step 17/32; Loss = 0.3110
# Step 18/32; Loss = 0.3805
# Step 19/32; Loss = 0.3069
# Step 20/32; Loss = 0.3197
# Step 21/32; Loss = 0.3240
# Step 22/32; Loss = 0.3829
# Step 23/32; Loss = 0.3407
# Step 24/32; Loss = 0.3236
# Step 25/32; Loss = 0.3085
# Step 26/32; Loss = 0.3457
# Step 27/32; Loss = 0.3122
# Step 28/32; Loss = 0.3470
# Step 29/32; Loss = 0.3405
# Step 30/32; Loss = 0.3210
# Step 31/32; Loss = 0.3320
# Step 32/32; Loss = 0.3448
# Epoch 16/25 (LR: 0.00062)
# Step 1/32; Loss = 0.3528
# Step 2/32; Loss = 0.3196
# Step 3/32; Loss = 0.3279
# Step 4/32; Loss = 0.3442
# Step 5/32; Loss = 0.3114
# Step 6/32; Loss = 0.3327
# Step 7/32; Loss = 0.3385
# Step 8/32; Loss = 0.3553
# Step 9/32; Loss = 0.3163
# Step 10/32; Loss = 0.3584
# Step 11/32; Loss = 0.3103
# Step 12/32; Loss = 0.3649
# Step 13/32; Loss = 0.3376
# Step 14/32; Loss = 0.3275
# Step 15/32; Loss = 0.3862
# Step 16/32; Loss = 0.3810
# Step 17/32; Loss = 0.3666
# Step 18/32; Loss = 0.3585
# Step 19/32; Loss = 0.3334
# Step 20/32; Loss = 0.3281
# Step 21/32; Loss = 0.2922
# Step 22/32; Loss = 0.3029
# Step 23/32; Loss = 0.3298
# Step 24/32; Loss = 0.3195
# Step 25/32; Loss = 0.3317
# Step 26/32; Loss = 0.3753
# Step 27/32; Loss = 0.3898
# Step 28/32; Loss = 0.3588
# Step 29/32; Loss = 0.3102
# Step 30/32; Loss = 0.3328
# Step 31/32; Loss = 0.3332
# Step 32/32; Loss = 0.3109
# Epoch 17/25 (LR: 0.00041)
# Step 1/32; Loss = 0.3543
# Step 2/32; Loss = 0.3214
# Step 3/32; Loss = 0.3276
# Step 4/32; Loss = 0.3112
# Step 5/32; Loss = 0.3278
# Step 6/32; Loss = 0.3285
# Step 7/32; Loss = 0.3240
# Step 8/32; Loss = 0.3475
# Step 9/32; Loss = 0.3420
# Step 10/32; Loss = 0.3597
# Step 11/32; Loss = 0.3816
# Step 12/32; Loss = 0.3448
# Step 13/32; Loss = 0.3379
# Step 14/32; Loss = 0.3229
# Step 15/32; Loss = 0.4012
# Step 16/32; Loss = 0.3556
# Step 17/32; Loss = 0.3386
# Step 18/32; Loss = 0.3315
# Step 19/32; Loss = 0.2925
# Step 20/32; Loss = 0.3430
# Step 21/32; Loss = 0.3551
# Step 22/32; Loss = 0.3338
# Step 23/32; Loss = 0.3577
# Step 24/32; Loss = 0.3534
# Step 25/32; Loss = 0.3328
# Step 26/32; Loss = 0.3656
# Step 27/32; Loss = 0.3430
# Step 28/32; Loss = 0.3627
# Step 29/32; Loss = 0.2882
# Step 30/32; Loss = 0.3263
# Step 31/32; Loss = 0.3093
# Step 32/32; Loss = 0.3576
# Epoch 18/25 (LR: 0.00026)
# Step 1/32; Loss = 0.3301
# Step 2/32; Loss = 0.3270
# Step 3/32; Loss = 0.3470
# Step 4/32; Loss = 0.3408
# Step 5/32; Loss = 0.3495
# Step 6/32; Loss = 0.3656
# Step 7/32; Loss = 0.3018
# Step 8/32; Loss = 0.3415
# Step 9/32; Loss = 0.3337
# Step 10/32; Loss = 0.3421
# Step 11/32; Loss = 0.3581
# Step 12/32; Loss = 0.3332
# Step 13/32; Loss = 0.3206
# Step 14/32; Loss = 0.3582
# Step 15/32; Loss = 0.3401
# Step 16/32; Loss = 0.3595
# Step 17/32; Loss = 0.3138
# Step 18/32; Loss = 0.3476
# Step 19/32; Loss = 0.3234
# Step 20/32; Loss = 0.3480
# Step 21/32; Loss = 0.3526
# Step 22/32; Loss = 0.3484
# Step 23/32; Loss = 0.3481
# Step 24/32; Loss = 0.3520
# Step 25/32; Loss = 0.3131
# Step 26/32; Loss = 0.3479
# Step 27/32; Loss = 0.3825
# Step 28/32; Loss = 0.3253
# Step 29/32; Loss = 0.3376
# Step 30/32; Loss = 0.3318
# Step 31/32; Loss = 0.3214
# Step 32/32; Loss = 0.2871
# Epoch 19/25 (LR: 0.00017)
# Step 1/32; Loss = 0.3558
# Step 2/32; Loss = 0.3349
# Step 3/32; Loss = 0.3240
# Step 4/32; Loss = 0.3422
# Step 5/32; Loss = 0.3046
# Step 6/32; Loss = 0.3428
# Step 7/32; Loss = 0.3538
# Step 8/32; Loss = 0.3137
# Step 9/32; Loss = 0.3120
# Step 10/32; Loss = 0.3394
# Step 11/32; Loss = 0.3046
# Step 12/32; Loss = 0.3361
# Step 13/32; Loss = 0.3270
# Step 14/32; Loss = 0.3445
# Step 15/32; Loss = 0.3485
# Step 16/32; Loss = 0.3522
# Step 17/32; Loss = 0.3473
# Step 18/32; Loss = 0.3599
# Step 19/32; Loss = 0.3199
# Step 20/32; Loss = 0.3334
# Step 21/32; Loss = 0.3740
# Step 22/32; Loss = 0.3490
# Step 23/32; Loss = 0.3812
# Step 24/32; Loss = 0.3275
# Step 25/32; Loss = 0.3263
# Step 26/32; Loss = 0.3349
# Step 27/32; Loss = 0.3406
# Step 28/32; Loss = 0.3587
# Step 29/32; Loss = 0.3670
# Step 30/32; Loss = 0.3418
# Step 31/32; Loss = 0.3316
# Step 32/32; Loss = 0.3478
# Epoch 20/25 (LR: 0.00011)
# Step 1/32; Loss = 0.3531
# Step 2/32; Loss = 0.3132
# Step 3/32; Loss = 0.3424
# Step 4/32; Loss = 0.3327
# Step 5/32; Loss = 0.3357
# Step 6/32; Loss = 0.3272
# Step 7/32; Loss = 0.3636
# Step 8/32; Loss = 0.3083
# Step 9/32; Loss = 0.3381
# Step 10/32; Loss = 0.3421
# Step 11/32; Loss = 0.3444
# Step 12/32; Loss = 0.3181
# Step 13/32; Loss = 0.3607
# Step 14/32; Loss = 0.3218
# Step 15/32; Loss = 0.3057
# Step 16/32; Loss = 0.4265
# Step 17/32; Loss = 0.3507
# Step 18/32; Loss = 0.3501
# Step 19/32; Loss = 0.2989
# Step 20/32; Loss = 0.3247
# Step 21/32; Loss = 0.3362
# Step 22/32; Loss = 0.3346
# Step 23/32; Loss = 0.3259
# Step 24/32; Loss = 0.3414
# Step 25/32; Loss = 0.3570
# Step 26/32; Loss = 0.3156
# Step 27/32; Loss = 0.3364
# Step 28/32; Loss = 0.3900
# Step 29/32; Loss = 0.3537
# Step 30/32; Loss = 0.3404
# Step 31/32; Loss = 0.3383
# Step 32/32; Loss = 0.3215
# Epoch 21/25 (LR: 0.00007)
# Step 1/32; Loss = 0.3691
# Step 2/32; Loss = 0.3332
# Step 3/32; Loss = 0.3742
# Step 4/32; Loss = 0.3329
# Step 5/32; Loss = 0.3321
# Step 6/32; Loss = 0.3383
# Step 7/32; Loss = 0.3472
# Step 8/32; Loss = 0.2942
# Step 9/32; Loss = 0.3356
# Step 10/32; Loss = 0.3694
# Step 11/32; Loss = 0.3666
# Step 12/32; Loss = 0.3422
# Step 13/32; Loss = 0.3414
# Step 14/32; Loss = 0.3349
# Step 15/32; Loss = 0.3314
# Step 16/32; Loss = 0.3085
# Step 17/32; Loss = 0.3151
# Step 18/32; Loss = 0.3328
# Step 19/32; Loss = 0.3196
# Step 20/32; Loss = 0.3429
# Step 21/32; Loss = 0.3349
# Step 22/32; Loss = 0.3407
# Step 23/32; Loss = 0.3379
# Step 24/32; Loss = 0.3169
# Step 25/32; Loss = 0.3486
# Step 26/32; Loss = 0.3568
# Step 27/32; Loss = 0.3712
# Step 28/32; Loss = 0.3308
# Step 29/32; Loss = 0.3686
# Step 30/32; Loss = 0.3171
# Step 31/32; Loss = 0.3360
# Step 32/32; Loss = 0.3237
# Epoch 22/25 (LR: 0.00005)
# Step 1/32; Loss = 0.3210
# Step 2/32; Loss = 0.3437
# Step 3/32; Loss = 0.3129
# Step 4/32; Loss = 0.3235
# Step 5/32; Loss = 0.3373
# Step 6/32; Loss = 0.3462
# Step 7/32; Loss = 0.3575
# Step 8/32; Loss = 0.3494
# Step 9/32; Loss = 0.3087
# Step 10/32; Loss = 0.3531
# Step 11/32; Loss = 0.3335
# Step 12/32; Loss = 0.3061
# Step 13/32; Loss = 0.3443
# Step 14/32; Loss = 0.3241
# Step 15/32; Loss = 0.3322
# Step 16/32; Loss = 0.3678
# Step 17/32; Loss = 0.3822
# Step 18/32; Loss = 0.3519
# Step 19/32; Loss = 0.3591
# Step 20/32; Loss = 0.3044
# Step 21/32; Loss = 0.3471
# Step 22/32; Loss = 0.3297
# Step 23/32; Loss = 0.3200
# Step 24/32; Loss = 0.3144
# Step 25/32; Loss = 0.3302
# Step 26/32; Loss = 0.3494
# Step 27/32; Loss = 0.3532
# Step 28/32; Loss = 0.3177
# Step 29/32; Loss = 0.3662
# Step 30/32; Loss = 0.3798
# Step 31/32; Loss = 0.3400
# Step 32/32; Loss = 0.3499
# Epoch 23/25 (LR: 0.00003)
# Step 1/32; Loss = 0.3196
# Step 2/32; Loss = 0.3839
# Step 3/32; Loss = 0.3077
# Step 4/32; Loss = 0.3408
# Step 5/32; Loss = 0.3515
# Step 6/32; Loss = 0.3503
# Step 7/32; Loss = 0.3376
# Step 8/32; Loss = 0.3349
# Step 9/32; Loss = 0.3791
# Step 10/32; Loss = 0.3247
# Step 11/32; Loss = 0.3063
# Step 12/32; Loss = 0.3788
# Step 13/32; Loss = 0.3234
# Step 14/32; Loss = 0.3205
# Step 15/32; Loss = 0.3154
# Step 16/32; Loss = 0.3444
# Step 17/32; Loss = 0.3596
# Step 18/32; Loss = 0.3422
# Step 19/32; Loss = 0.3087
# Step 20/32; Loss = 0.3142
# Step 21/32; Loss = 0.3470
# Step 22/32; Loss = 0.3315
# Step 23/32; Loss = 0.3787
# Step 24/32; Loss = 0.3342
# Step 25/32; Loss = 0.3449
# Step 26/32; Loss = 0.3703
# Step 27/32; Loss = 0.3326
# Step 28/32; Loss = 0.3053
# Step 29/32; Loss = 0.3505
# Step 30/32; Loss = 0.3380
# Step 31/32; Loss = 0.3405
# Step 32/32; Loss = 0.3436
# Epoch 24/25 (LR: 0.00002)
# Step 1/32; Loss = 0.3930
# Step 2/32; Loss = 0.2891
# Step 3/32; Loss = 0.3579
# Step 4/32; Loss = 0.3259
# Step 5/32; Loss = 0.3373
# Step 6/32; Loss = 0.3268
# Step 7/32; Loss = 0.3534
# Step 8/32; Loss = 0.3238
# Step 9/32; Loss = 0.3137
# Step 10/32; Loss = 0.3206
# Step 11/32; Loss = 0.3409
# Step 12/32; Loss = 0.3337
# Step 13/32; Loss = 0.3779
# Step 14/32; Loss = 0.3353
# Step 15/32; Loss = 0.2949
# Step 16/32; Loss = 0.3342
# Step 17/32; Loss = 0.2966
# Step 18/32; Loss = 0.3572
# Step 19/32; Loss = 0.3428
# Step 20/32; Loss = 0.3265
# Step 21/32; Loss = 0.3382
# Step 22/32; Loss = 0.3504
# Step 23/32; Loss = 0.3765
# Step 24/32; Loss = 0.3270
# Step 25/32; Loss = 0.3219
# Step 26/32; Loss = 0.3384
# Step 27/32; Loss = 0.3580
# Step 28/32; Loss = 0.3335
# Step 29/32; Loss = 0.3242
# Step 30/32; Loss = 0.3631
# Step 31/32; Loss = 0.3730
# Step 32/32; Loss = 0.4260
# Epoch 25/25 (LR: 0.00001)
# Step 1/32; Loss = 0.3126
# Step 2/32; Loss = 0.3385
# Step 3/32; Loss = 0.3162
# Step 4/32; Loss = 0.3055
# Step 5/32; Loss = 0.3386
# Step 6/32; Loss = 0.3851
# Step 7/32; Loss = 0.3432
# Step 8/32; Loss = 0.3448
# Step 9/32; Loss = 0.3358
# Step 10/32; Loss = 0.3371
# Step 11/32; Loss = 0.3309
# Step 12/32; Loss = 0.3572
# Step 13/32; Loss = 0.3083
# Step 14/32; Loss = 0.3758
# Step 15/32; Loss = 0.3365
# Step 16/32; Loss = 0.3487
# Step 17/32; Loss = 0.3360
# Step 18/32; Loss = 0.3812
# Step 19/32; Loss = 0.3259
# Step 20/32; Loss = 0.3025
# Step 21/32; Loss = 0.3507
# Step 22/32; Loss = 0.3425
# Step 23/32; Loss = 0.3287
# Step 24/32; Loss = 0.3241
# Step 25/32; Loss = 0.3797
# Step 26/32; Loss = 0.3439
# Step 27/32; Loss = 0.3314
# Step 28/32; Loss = 0.3108
# Step 29/32; Loss = 0.3253
# Step 30/32; Loss = 0.3411
# Step 31/32; Loss = 0.3741
# Step 32/32; Loss = 0.4239
# Finished Training!
# Time Taken = 38m 6s

# %%
plt.figure(figsize=(20,10))
plt.plot(losses)
plt.title('Loss')
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
# torch.save(unet, 'models/U-Net_Image_Segmentation_IE643_2.pt')

# %%
# unet = torch.load('../models/U-Net_Image_Segmentation_IE643_2.pt')
unet.eval()
# Out:
# UNet(
#   (conv11): Conv2d(3, 8, kernel_size=(7, 7), stride=(1, 1), padding=same)
#   (norm11): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv12): Conv2d(8, 32, kernel_size=(5, 5), stride=(1, 1), padding=same)
#   (norm12): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv13): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm13): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv21): Conv2d(64, 128, kernel_size=(7, 7), stride=(1, 1), padding=same)
#   (norm21): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv22): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=same)
#   (norm22): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv23): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm23): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv31): Conv2d(128, 256, kernel_size=(5, 5), stride=(1, 1), padding=same)
#   (norm31): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv32): Conv2d(256, 256, kernel_size=(5, 5), stride=(1, 1), padding=same)
#   (norm32): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv33): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm33): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv41): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv42): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm42): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv43): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm43): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (convT1): ConvTranspose2d(1024, 256, kernel_size=(2, 2), stride=(2, 2))
#   (conv51): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm51): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv52): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm52): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv53): Conv2d(512, 512, kernel_size=(5, 5), stride=(1, 1), padding=same)
#   (norm53): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (convT2): ConvTranspose2d(512, 128, kernel_size=(2, 2), stride=(2, 2))
#   (conv61): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm61): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv62): Conv2d(256, 256, kernel_size=(5, 5), stride=(1, 1), padding=same)
#   (norm62): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv63): Conv2d(256, 256, kernel_size=(5, 5), stride=(1, 1), padding=same)
#   (norm63): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (convT3): ConvTranspose2d(256, 64, kernel_size=(2, 2), stride=(2, 2))
#   (conv71): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm71): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv72): Conv2d(64, 16, kernel_size=(5, 5), stride=(1, 1), padding=same)
#   (norm72): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv73): Conv2d(16, 1, kernel_size=(7, 7), stride=(1, 1), padding=same)
#   (norm73): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
def binaryJaccardIndex(preds, masks):
    intersection = 0
    union = 0
    for pred, mask in zip(preds, masks):
        for pred_row, mask_row in zip(pred[0],mask[0]):
            for i,j in zip(pred_row, mask_row):
                if i==1 or j==1:
                    union+=1
                if i==1 and j==1:
                    intersection+=1
    return(intersection/union)

# %%
threshold = 0.4

# %%
image, mask = next(iter(train_loader))
image = image.to(device)
mask = mask.to('cpu')
pred = unet(image).cpu()
pred1 = torch.relu(torch.sign(pred - threshold))
image = image.to('cpu')
image_show(image[0], mask[0], pred1[0])

# %%
binaryJaccardIndex(pred1, torch.round(mask).type(torch.int16))
# Out:
# 0.29256463357605716

# %%
IoU_value = 0
for image, mask in train_loader:
    image = image.to(device)
    mask = mask.to('cpu')
    pred = unet(image).cpu()
    pred = torch.round(pred)
    IoU_value += binaryJaccardIndex(pred, torch.round(mask).type(torch.int16))
print(f'Intersection Over Union value = {IoU_value/len(train_loader)}')
# Out:
# Intersection Over Union value = 0.5173639189451933

# %%
iou = IoU_value/len(train_loader)
dice_score = 2*iou/(1+iou)
print('Dice Score for Training data =',dice_score)

# %%
image, mask = next(iter(val_loader))
image = image.to(device)
mask = mask.to('cpu')
pred = unet(image).cpu()
pred1 = torch.round(pred)
image = image.to('cpu')
image_show(image[0], mask[0], pred1[0])

# %%
binaryJaccardIndex(pred1, torch.round(mask).type(torch.int16))
# Out:
# 0.22118883350929314

# %%
IoU_value = 0
for image, mask in val_loader:
    image = image.to(device)
    mask = mask.to('cpu')
    pred = unet(image).cpu()
    pred = torch.round(pred)
    IoU_value += binaryJaccardIndex(pred, torch.round(mask).type(torch.int16))
print(f'Intersection Over Union value = {IoU_value/len(val_loader)}')
# Out:
# Intersection Over Union value = 0.2077820295364275

# %%
iou = IoU_value/len(val_loader)
dice_score = 2*iou/(1+iou)
print('Dice Score for Validation data =',dice_score)
# Out:
# Dice Score for Validation data = 0.34407206673902685
