# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from torchsummary import summary

import time
import copy
import os

# %%
data_dir = '../datasets/camouflage_image_segmentation/Images'
mask_dir = '../datasets/camouflage_image_segmentation/Masks'

# %%
data_transforms = {
    'Train': transforms.Compose([
        transforms.Resize((128,128)),
        transforms.ColorJitter(),
        # transforms.Grayscale(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ]),
    'Validation': transforms.Compose([
        transforms.Resize((128,128)),
        # transforms.Grayscale(),
        transforms.ToTensor(),
        transforms.Normalize((0.5), (0.5))
    ])
}
mask_transforms = {
    'Train': transforms.Compose([
        transforms.Resize((128,128)),
        transforms.Grayscale(),
        transforms.ToTensor()
    ]),
    'Validation': transforms.Compose([
        transforms.Resize((128,128)),
        transforms.Grayscale(),
        transforms.ToTensor()
    ])
}

# %%
class ImageMaskDataset(Dataset):
    def __init__(self, data_dir, mask_dir, train = True, transform = None, mask_transform = None) -> None:
        super(ImageMaskDataset, self).__init__()
        self.imgs = []
        self.transform = transform
        if train:
            for file1 in os.scandir(data_dir+'/Train'):
                file2 = mask_dir+'/Train/'+file1.name[:-3]+'png'
                if self.transform is not None:
                    self.imgs.append((self.transform(Image.open(file1.path).convert('RGB')),mask_transform(Image.open(file2))))
                else:
                    self.imgs.append((Image.open(file1.path).convert('RGB'),Image.open(file2)))
        else:
            for file1 in os.scandir(data_dir+'/Validation'):
                file2 = mask_dir+'/Validation/'+file1.name[:-3]+'png'
                if self.transform is not None:
                    self.imgs.append((self.transform(Image.open(file1.path).convert('RGB')),mask_transform(Image.open(file2))))
                else:
                    self.imgs.append((Image.open(file1.path).convert('RGB'),Image.open(file2)))
                    # if self.imgs[-1][0].shape[0] == 1:
                    #     self.imgs[-1] = (self.imgs[-1][0].repeat(3,1,1), self.imgs[-1][1])
    
    def __len__(self):
        return len(self.imgs)
    
    def __getitem__(self, index):
        return self.imgs[index]

# %%
train_data = ImageMaskDataset(data_dir, mask_dir, train = True, transform=data_transforms['Train'], mask_transform=mask_transforms['Train'])
val_data = ImageMaskDataset(data_dir, mask_dir, train = False, transform=data_transforms['Validation'], mask_transform=mask_transforms['Validation'])

# %%
train_loader = DataLoader(
    train_data,
    batch_size = 64,
    shuffle = True,
)
val_loader = DataLoader(
    val_data,
    batch_size = 64,
    shuffle = True,
)

# %%
def image_show(image, mask, pred = None):
    image = image*0.5 + 0.5
    mask = mask*0.5 + 0.5
    plt.figure(figsize=(20,10))
    if pred is not None:
        plt.subplot(1,3,1)
        plt.title('Image')
        plt.imshow(image.numpy().transpose((1,2,0)), cmap='gray')
        plt.subplot(1,3,2)
        plt.title('True Mask')
        plt.imshow(mask.numpy().transpose((1,2,0)), cmap='gray')
        plt.subplot(1,3,3)
        plt.title('Predicted Mask')
        plt.imshow(pred.detach().numpy().transpose((1,2,0)), cmap='gray')
    else:
        plt.subplot(1,3,1)
        plt.title('Image')
        plt.imshow(image.numpy().transpose((1,2,0)), cmap='gray')
        plt.subplot(1,3,2)
        plt.title('Mask')
        plt.imshow(mask.numpy().transpose((1,2,0)), cmap='gray')

# %%
dataiter = iter(train_loader)
image, mask = next(dataiter)
index = 0
image_show(image[index], mask[index])

# %%
device = torch.device('mps' if torch.backends.mps.is_available() else 'cpu')
device
# Out:
# device(type='mps')

# %%
class DenseBlock(nn.Module):
    def __init__(self, channels: int, output_channels: int, depth = 8) -> None:
        super(DenseBlock, self).__init__()
        self.depth = depth
        self.norm=[]
        self.conv=[]
        for i in range(depth):
            self.conv.append(nn.Conv2d(channels+i*output_channels, output_channels, 1+((i//2)*2), 1, 'same', device=device))
            self.norm.append(nn.BatchNorm2d(output_channels, device=device))
        self.convFinal = nn.Conv2d(channels+depth*output_channels, channels, 1, device=device)
        self.normFinal = nn.BatchNorm2d(channels, device=device)
    
    def forward(self, x):
        for layer in range(self.depth):
            if layer == 0:
                temp = x
            x_temp = torch.relu(self.norm[layer](self.conv[layer](temp)))
            temp = torch.cat((temp, x_temp), 1)
        x = torch.relu(self.normFinal(self.convFinal(temp)))
        return x

# %%
class UNet(nn.Module):
    def __init__(self) -> None:
        super(UNet, self).__init__()

        # ENCODER
        self.conv1 = nn.Conv2d(3, 64, 3, 1, 'same') # 128, 128, 3 --> 128, 128, 64
        self.norm1 = nn.BatchNorm2d(64)
        self.denseBlock1 = DenseBlock(64, 8, 8).to(device)

        self.maxpool1 = nn.MaxPool2d(2,2) # 64, 64, 64

        self.conv2 = nn.Conv2d(64, 128, 3, 1, 'same') # 64, 64, 64 --> 64, 64, 128
        self.norm2 = nn.BatchNorm2d(128)
        self.denseBlock2 = DenseBlock(128, 16, 8).to(device) # 64, 64, 128

        self.maxpool2 = nn.MaxPool2d(2,2) # 32, 32, 128

        self.conv3 = nn.Conv2d(128, 256, 3, 1, 'same') # 32, 32, 128 --> 32, 32, 256
        self.norm3 = nn.BatchNorm2d(256)
        self.denseBlock3 = DenseBlock(256, 32, 8).to(device) # 32, 32, 256

        self.maxpool3 = nn.MaxPool2d(2,2) # 16, 16, 256

        self.conv4 = nn.Conv2d(256, 512, 3, 1, 1) # 16, 16, 256 --> 16, 16, 512
        self.norm4 = nn.BatchNorm2d(512)
        self.denseBlock4 = DenseBlock(512, 64, 8).to(device) # 16, 16, 512


        # DECODER
        self.convT1 = nn.ConvTranspose2d(512, 256, 2, 2)

        self.denseBlock5 = DenseBlock(512, 64, 8).to(device)

        self.convT2 = nn.ConvTranspose2d(512, 128, 2, 2)

        self.denseBlock6 = DenseBlock(256, 32, 8).to(device)

        self.convT3 = nn.ConvTranspose2d(256, 64, 2, 2)

        self.denseBlock7 = DenseBlock(128, 16, 8).to(device)

        self.conv71 = nn.Conv2d(128, 64, 3, 1, 'same')
        self.norm71 = nn.BatchNorm2d(64)
        self.conv72 = nn.Conv2d(64, 16, 5, 1, 'same')
        self.norm72 = nn.BatchNorm2d(16)
        self.conv73 = nn.Conv2d(16, 1, 7, 1, 'same')
        self.norm73 = nn.BatchNorm2d(1)

    def forward(self, x):
        # ENCODER
        x = torch.relu(self.norm1(self.conv1(x)))
        x_temp1 = self.denseBlock1(x)

        x = self.maxpool1(x_temp1)

        x = torch.relu(self.norm2(self.conv2(x)))
        x_temp2 = self.denseBlock2(x)

        x = self.maxpool2(x_temp2)

        x = torch.relu(self.norm3(self.conv3(x)))
        x_temp3 = self.denseBlock3(x)

        x = self.maxpool3(x_temp3)

        x = torch.relu(self.norm4(self.conv4(x)))
        x = self.denseBlock4(x)

        # DECODER
        x = self.convT1(x)

        x = torch.cat((x,x_temp3), 1)

        x = self.denseBlock5(x)

        x = self.convT2(x)

        x = torch.cat((x,x_temp2), 1)

        x = self.denseBlock6(x)

        x = self.convT3(x)   

        x = torch.cat((x,x_temp1), 1)

        x = self.denseBlock7(x)

        x = torch.relu(self.norm71(self.conv71(x)))
        x = torch.relu(self.norm72(self.conv72(x)))
        x = torch.sigmoid(self.norm73(self.conv73(x)))

        return x

# %%
unet = UNet().to(device)
den = DenseBlock(1,1).to(device)

# %%
summary(copy.deepcopy(unet).to('cpu'), (3, 128,128))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 128, 128]           1,792
#        BatchNorm2d-2         [-1, 64, 128, 128]             128
#             Conv2d-3         [-1, 64, 128, 128]           8,256
#        BatchNorm2d-4         [-1, 64, 128, 128]             128
#         DenseBlock-5         [-1, 64, 128, 128]               0
#          MaxPool2d-6           [-1, 64, 64, 64]               0
#             Conv2d-7          [-1, 128, 64, 64]          73,856
#        BatchNorm2d-8          [-1, 128, 64, 64]             256
#             Conv2d-9          [-1, 128, 64, 64]          32,896
#       BatchNorm2d-10          [-1, 128, 64, 64]             256
#        DenseBlock-11          [-1, 128, 64, 64]               0
#         MaxPool2d-12          [-1, 128, 32, 32]               0
#            Conv2d-13          [-1, 256, 32, 32]         295,168
#       BatchNorm2d-14          [-1, 256, 32, 32]             512
#            Conv2d-15          [-1, 256, 32, 32]         131,328
#       BatchNorm2d-16          [-1, 256, 32, 32]             512
#        DenseBlock-17          [-1, 256, 32, 32]               0
#         MaxPool2d-18          [-1, 256, 16, 16]               0
#            Conv2d-19          [-1, 512, 16, 16]       1,180,160
#       BatchNorm2d-20          [-1, 512, 16, 16]           1,024
#            Conv2d-21          [-1, 512, 16, 16]         524,800
#       BatchNorm2d-22          [-1, 512, 16, 16]           1,024
#        DenseBlock-23          [-1, 512, 16, 16]               0
#   ConvTranspose2d-24          [-1, 256, 32, 32]         524,544
#            Conv2d-25          [-1, 512, 32, 32]         524,800
#       BatchNorm2d-26          [-1, 512, 32, 32]           1,024
#        DenseBlock-27          [-1, 512, 32, 32]               0
#   ConvTranspose2d-28          [-1, 128, 64, 64]         262,272
#            Conv2d-29          [-1, 256, 64, 64]         131,328
#       BatchNorm2d-30          [-1, 256, 64, 64]             512
#        DenseBlock-31          [-1, 256, 64, 64]               0
#   ConvTranspose2d-32         [-1, 64, 128, 128]          65,600
#            Conv2d-33        [-1, 128, 128, 128]          32,896
#       BatchNorm2d-34        [-1, 128, 128, 128]             256
#        DenseBlock-35        [-1, 128, 128, 128]               0
#            Conv2d-36         [-1, 64, 128, 128]          73,792
#       BatchNorm2d-37         [-1, 64, 128, 128]             128
#            Conv2d-38         [-1, 16, 128, 128]          25,616
#       BatchNorm2d-39         [-1, 16, 128, 128]              32
#            Conv2d-40          [-1, 1, 128, 128]             785
#       BatchNorm2d-41          [-1, 1, 128, 128]               2
# ================================================================
# Total params: 3,895,683
# Trainable params: 3,895,683
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 196.75
# Params size (MB): 14.86
# Estimated Total Size (MB): 211.80
# ----------------------------------------------------------------

# %% [markdown]
# # Binary Cross Entropy Loss

# %%
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(unet.parameters(), lr=4e-1)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size = 1, gamma=0.5)

# %%
num_epochs = 10
batches = len(train_loader)
losses = []
print(batches)
# Out:
# 16

# %%
tic = time.time()
for epoch in range(num_epochs):
    print(f'Epoch {epoch+1}/{num_epochs}; LR = {scheduler.get_last_lr()[0]}')
    for i, (images,masks) in enumerate(train_loader):
        images = images.to(device)
        masks = torch.round(masks).to(device)

        preds = unet.forward(images)
        loss = criterion(preds, masks)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        print(f'Step {i+1}/{batches}; Loss = {loss.item():.4f}')
        losses.append(loss.item())
    scheduler.step()
print('Finished Training!')
print(f'Time Taken = {(time.time() - tic)//60:.0f}m {(time.time() - tic)%60:.0f}s')
# Out:
# Epoch 1/10; LR = 0.4
# Step 1/16; Loss = 0.7928
# Step 2/16; Loss = 0.6052
# Step 3/16; Loss = 0.4877
# Step 4/16; Loss = 0.4566
# Step 5/16; Loss = 0.4289
# Step 6/16; Loss = 0.4297
# Step 7/16; Loss = 0.4488
# Step 8/16; Loss = 0.3822
# Step 9/16; Loss = 0.4000
# Step 10/16; Loss = 0.3629
# Step 11/16; Loss = 0.4141
# Step 12/16; Loss = 0.4137
# Step 13/16; Loss = 0.3537
# Step 14/16; Loss = 0.4037
# Step 15/16; Loss = 0.4218
# Step 16/16; Loss = 0.3636
# Epoch 2/10; LR = 0.2
# Step 1/16; Loss = 0.4027
# Step 2/16; Loss = 0.4139
# Step 3/16; Loss = 0.3572
# Step 4/16; Loss = 0.3835
# Step 5/16; Loss = 0.3679
# Step 6/16; Loss = 0.3961
# Step 7/16; Loss = 0.3655
# Step 8/16; Loss = 0.3515
# Step 9/16; Loss = 0.3734
# Step 10/16; Loss = 0.3751
# Step 11/16; Loss = 0.3452
# Step 12/16; Loss = 0.3225
# Step 13/16; Loss = 0.4009
# Step 14/16; Loss = 0.3877
# Step 15/16; Loss = 0.3636
# Step 16/16; Loss = 0.3554
# Epoch 3/10; LR = 0.1
# Step 1/16; Loss = 0.3313
# Step 2/16; Loss = 0.3737
# Step 3/16; Loss = 0.3698
# Step 4/16; Loss = 0.3578
# Step 5/16; Loss = 0.3388
# Step 6/16; Loss = 0.3333
# Step 7/16; Loss = 0.4117
# Step 8/16; Loss = 0.3420
# Step 9/16; Loss = 0.3921
# Step 10/16; Loss = 0.3958
# Step 11/16; Loss = 0.4193
# Step 12/16; Loss = 0.3035
# Step 13/16; Loss = 0.3790
# Step 14/16; Loss = 0.3221
# Step 15/16; Loss = 0.3359
# Step 16/16; Loss = 0.3204
# Epoch 4/10; LR = 0.05
# Step 1/16; Loss = 0.3329
# Step 2/16; Loss = 0.3582
# Step 3/16; Loss = 0.3267
# Step 4/16; Loss = 0.3667
# Step 5/16; Loss = 0.3705
# Step 6/16; Loss = 0.3704
# Step 7/16; Loss = 0.3541
# Step 8/16; Loss = 0.3401
# Step 9/16; Loss = 0.3189
# Step 10/16; Loss = 0.3578
# Step 11/16; Loss = 0.3276
# Step 12/16; Loss = 0.3593
# Step 13/16; Loss = 0.3199
# Step 14/16; Loss = 0.3594
# Step 15/16; Loss = 0.3772
# Step 16/16; Loss = 0.3671
# Epoch 5/10; LR = 0.025
# Step 1/16; Loss = 0.3414
# Step 2/16; Loss = 0.3194
# Step 3/16; Loss = 0.3455
# Step 4/16; Loss = 0.3625
# Step 5/16; Loss = 0.3228
# Step 6/16; Loss = 0.3614
# Step 7/16; Loss = 0.3665
# Step 8/16; Loss = 0.3773
# Step 9/16; Loss = 0.3293
# Step 10/16; Loss = 0.3319
# Step 11/16; Loss = 0.3443
# Step 12/16; Loss = 0.3354
# Step 13/16; Loss = 0.3544
# Step 14/16; Loss = 0.3279
# Step 15/16; Loss = 0.3307
# Step 16/16; Loss = 0.3844
# Epoch 6/10; LR = 0.0125
# Step 1/16; Loss = 0.3026
# Step 2/16; Loss = 0.3036
# Step 3/16; Loss = 0.3658
# Step 4/16; Loss = 0.3932
# Step 5/16; Loss = 0.3470
# Step 6/16; Loss = 0.3198
# Step 7/16; Loss = 0.3176
# Step 8/16; Loss = 0.3481
# Step 9/16; Loss = 0.3218
# Step 10/16; Loss = 0.3653
# Step 11/16; Loss = 0.3670
# Step 12/16; Loss = 0.3510
# Step 13/16; Loss = 0.3457
# Step 14/16; Loss = 0.2979
# Step 15/16; Loss = 0.3917
# Step 16/16; Loss = 0.3292
# Epoch 7/10; LR = 0.00625
# Step 1/16; Loss = 0.3135
# Step 2/16; Loss = 0.3337
# Step 3/16; Loss = 0.3647
# Step 4/16; Loss = 0.3125
# Step 5/16; Loss = 0.3344
# Step 6/16; Loss = 0.3299
# Step 7/16; Loss = 0.3773
# Step 8/16; Loss = 0.3697
# Step 9/16; Loss = 0.3445
# Step 10/16; Loss = 0.3524
# Step 11/16; Loss = 0.3723
# Step 12/16; Loss = 0.3181
# Step 13/16; Loss = 0.3217
# Step 14/16; Loss = 0.3469
# Step 15/16; Loss = 0.3164
# Step 16/16; Loss = 0.3219
# Epoch 8/10; LR = 0.003125
# Step 1/16; Loss = 0.3684
# Step 2/16; Loss = 0.3421
# Step 3/16; Loss = 0.3668
# Step 4/16; Loss = 0.3370
# Step 5/16; Loss = 0.3195
# Step 6/16; Loss = 0.3322
# Step 7/16; Loss = 0.3900
# Step 8/16; Loss = 0.3071
# Step 9/16; Loss = 0.3484
# Step 10/16; Loss = 0.3286
# Step 11/16; Loss = 0.3580
# Step 12/16; Loss = 0.3459
# Step 13/16; Loss = 0.3029
# Step 14/16; Loss = 0.3201
# Step 15/16; Loss = 0.3371
# Step 16/16; Loss = 0.3182
# Epoch 9/10; LR = 0.0015625
# Step 1/16; Loss = 0.3350
# Step 2/16; Loss = 0.3367
# Step 3/16; Loss = 0.3203
# Step 4/16; Loss = 0.3519
# Step 5/16; Loss = 0.3733
# Step 6/16; Loss = 0.3674
# Step 7/16; Loss = 0.3349
# Step 8/16; Loss = 0.3221
# Step 9/16; Loss = 0.3543
# Step 10/16; Loss = 0.3455
# Step 11/16; Loss = 0.3535
# Step 12/16; Loss = 0.3067
# Step 13/16; Loss = 0.3283
# Step 14/16; Loss = 0.3437
# Step 15/16; Loss = 0.3190
# Step 16/16; Loss = 0.3104
# Epoch 10/10; LR = 0.00078125
# Step 1/16; Loss = 0.3345
# Step 2/16; Loss = 0.3365
# Step 3/16; Loss = 0.3298
# Step 4/16; Loss = 0.3260
# Step 5/16; Loss = 0.3407
# Step 6/16; Loss = 0.3186
# Step 7/16; Loss = 0.3194
# Step 8/16; Loss = 0.3713
# Step 9/16; Loss = 0.3796
# Step 10/16; Loss = 0.2859
# Step 11/16; Loss = 0.3633
# Step 12/16; Loss = 0.3357
# Step 13/16; Loss = 0.3580
# Step 14/16; Loss = 0.3532
# Step 15/16; Loss = 0.3111
# Step 16/16; Loss = 0.3468
# Finished Training!
# Time Taken = 126m 36s

# %%
# torch.save(unet, '../models/U-Net_Image_Segmentation_IE643_Dense.pt')

# %%
unet = torch.load('../models/U-Net_Image_Segmentation_IE643_Dense.pt')
unet.eval()
# Out:
# UNet(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (denseBlock1): DenseBlock(
#     (convFinal): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (denseBlock2): DenseBlock(
#     (convFinal): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (denseBlock3): DenseBlock(
#     (convFinal): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv4): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (denseBlock4): DenseBlock(
#     (convFinal): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (convT1): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2))
#   (denseBlock5): DenseBlock(
#     (convFinal): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (convT2): ConvTranspose2d(512, 128, kernel_size=(2, 2), stride=(2, 2))
#   (denseBlock6): DenseBlock(
#     (convFinal): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (convT3): ConvTranspose2d(256, 64, kernel_size=(2, 2), stride=(2, 2))
#   (denseBlock7): DenseBlock(
#     (convFinal): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv71): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm71): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv72): Conv2d(64, 16, kernel_size=(5, 5), stride=(1, 1), padding=same)
#   (norm72): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv73): Conv2d(16, 1, kernel_size=(7, 7), stride=(1, 1), padding=same)
#   (norm73): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %% [markdown]
# # IoU Function

# %%
def binaryJaccardIndex(preds, masks):
    intersection = 0
    union = 0
    for pred, mask in zip(preds, masks):
        for pred_row, mask_row in zip(pred[0],mask[0]):
            for i,j in zip(pred_row, mask_row):
                if i==1 or j==1:
                    union+=1
                if i==1 and j==1:
                    intersection+=1
    return(intersection/union)

# %% [markdown]
# ## Testing

# %%
threshold = 0.4

# %%
image, mask = next(iter(train_loader))
image = image.to(device)
mask = mask.to('cpu')
pred = unet(image).cpu()
pred1 = torch.relu(torch.sign(pred - threshold))
image = image.to('cpu')
image_show(image[0], mask[0], pred1[0])

# %%
IoU_value = 0
for image, mask in train_loader:
    image = image.to(device)
    mask = mask.to('cpu')
    pred = unet(image).cpu()
    pred = torch.relu(torch.sign(pred - threshold)) # Taking 0.4 as the threshold to make the value 1
    IoU_value += binaryJaccardIndex(pred, torch.round(mask).type(torch.int16))
print(f'Intersection Over Union value = {IoU_value/len(train_loader)}')
# Out:
# Intersection Over Union value = 0.34148184642748697

# %%
iou = IoU_value/len(train_loader)
dice_score = 2*iou/(1+iou)
print('Dice Score for Training data =',dice_score)
# Out:
# Dice Score for Training data = 0.5091113939959613

# %%
image, mask = next(iter(val_loader))
image = image.to(device)
mask = mask.to('cpu')
pred = unet(image).cpu()
pred1 = torch.relu(torch.sign(pred - threshold))
image = image.to('cpu')
image_show(image[0], mask[0], pred1[0])

# %%
IoU_value = 0
for image, mask in val_loader:
    image = image.to(device)
    mask = mask.to('cpu')
    pred = unet(image).cpu()
    pred = pred = torch.relu(torch.sign(pred - threshold))
    IoU_value += binaryJaccardIndex(pred, torch.round(mask).type(torch.int16))
print(f'Intersection Over Union value = {IoU_value/len(val_loader)}')
# Out:
# Intersection Over Union value = 0.3113798786025718

# %%
iou = IoU_value/len(val_loader)
dice_score = 2*iou/(1+iou)
print('Dice Score for Validation data =',dice_score)
# Out:
# Dice Score for Validation data = 0.47488890699525355

# %% [markdown]
# ## Continuing to Train for 10 more epochs

# %%
criterion = nn.BCELoss()
optimizer = torch.optim.Adam(unet.parameters(), lr=4e-2)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size = 1, gamma=0.6)

# %%
num_epochs = 10
losses=[]
batches = len(train_loader)
print(batches)
# Out:
# 16

# %%
unet.train()
# Out:
# UNet(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (denseBlock1): DenseBlock(
#     (convFinal): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (denseBlock2): DenseBlock(
#     (convFinal): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (denseBlock3): DenseBlock(
#     (convFinal): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv4): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (denseBlock4): DenseBlock(
#     (convFinal): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (convT1): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2))
#   (denseBlock5): DenseBlock(
#     (convFinal): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (convT2): ConvTranspose2d(512, 128, kernel_size=(2, 2), stride=(2, 2))
#   (denseBlock6): DenseBlock(
#     (convFinal): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (convT3): ConvTranspose2d(256, 64, kernel_size=(2, 2), stride=(2, 2))
#   (denseBlock7): DenseBlock(
#     (convFinal): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv71): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm71): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv72): Conv2d(64, 16, kernel_size=(5, 5), stride=(1, 1), padding=same)
#   (norm72): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv73): Conv2d(16, 1, kernel_size=(7, 7), stride=(1, 1), padding=same)
#   (norm73): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
tic = time.time()
for epoch in range(num_epochs):
    print(f'Epoch {epoch+1}/{num_epochs}; LR = {scheduler.get_last_lr()[0]}')
    for i, (images,masks) in enumerate(train_loader):
        images = images.to(device)
        masks = torch.round(masks).to(device)

        preds = unet(images)
        loss = criterion(preds, masks)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        print(f'Step {i+1}/{batches}; Loss = {loss.item():.4f}')
        losses.append(loss.item())
    scheduler.step()
print('Finished Training!')
print(f'Time Taken = {(time.time() - tic)//60:.0f}m {(time.time() - tic)%60:.0f}s')
# Out:
# Epoch 1/10; LR = 0.04
# Step 1/16; Loss = 0.3605
# Step 2/16; Loss = 0.3644
# Step 3/16; Loss = 0.3761
# Step 4/16; Loss = 0.3260
# Step 5/16; Loss = 0.3675
# Step 6/16; Loss = 0.3408
# Step 7/16; Loss = 0.3029
# Step 8/16; Loss = 0.3432
# Step 9/16; Loss = 0.3670
# Step 10/16; Loss = 0.3504
# Step 11/16; Loss = 0.3321
# Step 12/16; Loss = 0.3190
# Step 13/16; Loss = 0.3544
# Step 14/16; Loss = 0.3344
# Step 15/16; Loss = 0.3192
# Step 16/16; Loss = 0.3372
# Epoch 2/10; LR = 0.024
# Step 1/16; Loss = 0.3194
# Step 2/16; Loss = 0.3475
# Step 3/16; Loss = 0.3653
# Step 4/16; Loss = 0.3461
# Step 5/16; Loss = 0.3580
# Step 6/16; Loss = 0.3248
# Step 7/16; Loss = 0.3016
# Step 8/16; Loss = 0.3123
# Step 9/16; Loss = 0.3019
# Step 10/16; Loss = 0.3751
# Step 11/16; Loss = 0.3602
# Step 12/16; Loss = 0.3138
# Step 13/16; Loss = 0.3183
# Step 14/16; Loss = 0.3306
# Step 15/16; Loss = 0.3762
# Step 16/16; Loss = 0.3072
# Epoch 3/10; LR = 0.0144
# Step 1/16; Loss = 0.3615
# Step 2/16; Loss = 0.3219
# Step 3/16; Loss = 0.3528
# Step 4/16; Loss = 0.3097
# Step 5/16; Loss = 0.3281
# Step 6/16; Loss = 0.3341
# Step 7/16; Loss = 0.3046
# Step 8/16; Loss = 0.3480
# Step 9/16; Loss = 0.3158
# Step 10/16; Loss = 0.3927
# Step 11/16; Loss = 0.3323
# Step 12/16; Loss = 0.3202
# Step 13/16; Loss = 0.2866
# Step 14/16; Loss = 0.3255
# Step 15/16; Loss = 0.3270
# Step 16/16; Loss = 0.3424
# Epoch 4/10; LR = 0.00864
# Step 1/16; Loss = 0.3627
# Step 2/16; Loss = 0.3247
# Step 3/16; Loss = 0.3447
# Step 4/16; Loss = 0.3493
# Step 5/16; Loss = 0.3031
# Step 6/16; Loss = 0.2949
# Step 7/16; Loss = 0.3054
# Step 8/16; Loss = 0.3482
# Step 9/16; Loss = 0.3332
# Step 10/16; Loss = 0.3009
# Step 11/16; Loss = 0.3361
# Step 12/16; Loss = 0.3263
# Step 13/16; Loss = 0.3121
# Step 14/16; Loss = 0.3273
# Step 15/16; Loss = 0.3773
# Step 16/16; Loss = 0.2919
# Epoch 5/10; LR = 0.005184
# Step 1/16; Loss = 0.3421
# Step 2/16; Loss = 0.3459
# Step 3/16; Loss = 0.3410
# Step 4/16; Loss = 0.3341
# Step 5/16; Loss = 0.3036
# Step 6/16; Loss = 0.2779
# Step 7/16; Loss = 0.3306
# Step 8/16; Loss = 0.3313
# Step 9/16; Loss = 0.3218
# Step 10/16; Loss = 0.3224
# Step 11/16; Loss = 0.3430
# Step 12/16; Loss = 0.3536
# Step 13/16; Loss = 0.3032
# Step 14/16; Loss = 0.3441
# Step 15/16; Loss = 0.3065
# Step 16/16; Loss = 0.3007
# Epoch 6/10; LR = 0.0031104
# Step 1/16; Loss = 0.3128
# Step 2/16; Loss = 0.3123
# Step 3/16; Loss = 0.3454
# Step 4/16; Loss = 0.3564
# Step 5/16; Loss = 0.3147
# Step 6/16; Loss = 0.3499
# Step 7/16; Loss = 0.2879
# Step 8/16; Loss = 0.3374
# Step 9/16; Loss = 0.3306
# Step 10/16; Loss = 0.3431
# Step 11/16; Loss = 0.3080
# Step 12/16; Loss = 0.3214
# Step 13/16; Loss = 0.3189
# Step 14/16; Loss = 0.3273
# Step 15/16; Loss = 0.3141
# Step 16/16; Loss = 0.2889
# Epoch 7/10; LR = 0.00186624
# Step 1/16; Loss = 0.3490
# Step 2/16; Loss = 0.3243
# Step 3/16; Loss = 0.3229
# Step 4/16; Loss = 0.3739
# Step 5/16; Loss = 0.3053
# Step 6/16; Loss = 0.2967
# Step 7/16; Loss = 0.3252
# Step 8/16; Loss = 0.3229
# Step 9/16; Loss = 0.3067
# Step 10/16; Loss = 0.2943
# Step 11/16; Loss = 0.3145
# Step 12/16; Loss = 0.3250
# Step 13/16; Loss = 0.3105
# Step 14/16; Loss = 0.3684
# Step 15/16; Loss = 0.3071
# Step 16/16; Loss = 0.3193
# Epoch 8/10; LR = 0.001119744
# Step 1/16; Loss = 0.3132
# Step 2/16; Loss = 0.3357
# Step 3/16; Loss = 0.3076
# Step 4/16; Loss = 0.3080
# Step 5/16; Loss = 0.3266
# Step 6/16; Loss = 0.2983
# Step 7/16; Loss = 0.3097
# Step 8/16; Loss = 0.3644
# Step 9/16; Loss = 0.3233
# Step 10/16; Loss = 0.3138
# Step 11/16; Loss = 0.3568
# Step 12/16; Loss = 0.3178
# Step 13/16; Loss = 0.3576
# Step 14/16; Loss = 0.3066
# Step 15/16; Loss = 0.2972
# Step 16/16; Loss = 0.3086
# Epoch 9/10; LR = 0.0006718464
# Step 1/16; Loss = 0.3142
# Step 2/16; Loss = 0.3466
# Step 3/16; Loss = 0.3584
# Step 4/16; Loss = 0.3069
# Step 5/16; Loss = 0.3195
# Step 6/16; Loss = 0.2899
# Step 7/16; Loss = 0.3369
# Step 8/16; Loss = 0.3104
# Step 9/16; Loss = 0.3292
# Step 10/16; Loss = 0.3204
# Step 11/16; Loss = 0.3391
# Step 12/16; Loss = 0.3349
# Step 13/16; Loss = 0.3160
# Step 14/16; Loss = 0.3106
# Step 15/16; Loss = 0.2918
# Step 16/16; Loss = 0.3281
# Epoch 10/10; LR = 0.00040310783999999994
# Step 1/16; Loss = 0.3119
# Step 2/16; Loss = 0.3133
# Step 3/16; Loss = 0.3312
# Step 4/16; Loss = 0.3538
# Step 5/16; Loss = 0.3199
# Step 6/16; Loss = 0.3052
# Step 7/16; Loss = 0.3337
# Step 8/16; Loss = 0.3468
# Step 9/16; Loss = 0.2919
# Step 10/16; Loss = 0.2932
# Step 11/16; Loss = 0.2941
# Step 12/16; Loss = 0.3299
# Step 13/16; Loss = 0.3450
# Step 14/16; Loss = 0.3173
# Step 15/16; Loss = 0.3522
# Step 16/16; Loss = 0.3138
# Finished Training!
# Time Taken = 134m 51s

# %%
plt.plot(losses)

# %%
# unet = torch.load('../models/U-Net_Image_Segmentation_IE643_Dense.pt')
unet.eval()
# Out:
# UNet(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (denseBlock1): DenseBlock(
#     (convFinal): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (denseBlock2): DenseBlock(
#     (convFinal): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (denseBlock3): DenseBlock(
#     (convFinal): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv4): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (denseBlock4): DenseBlock(
#     (convFinal): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (convT1): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2))
#   (denseBlock5): DenseBlock(
#     (convFinal): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (convT2): ConvTranspose2d(512, 128, kernel_size=(2, 2), stride=(2, 2))
#   (denseBlock6): DenseBlock(
#     (convFinal): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (convT3): ConvTranspose2d(256, 64, kernel_size=(2, 2), stride=(2, 2))
#   (denseBlock7): DenseBlock(
#     (convFinal): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv71): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm71): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv72): Conv2d(64, 16, kernel_size=(5, 5), stride=(1, 1), padding=same)
#   (norm72): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv73): Conv2d(16, 1, kernel_size=(7, 7), stride=(1, 1), padding=same)
#   (norm73): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
threshold = 0.4 # Changed Threshold

# %%
image, mask = next(iter(train_loader))
image = image.to(device)
mask = mask.to('cpu')
pred = unet(image).cpu()
pred1 = torch.relu(torch.sign(pred - threshold))
image = image.to('cpu')
image_show(image[0], mask[0], pred1[0])

# %%
IoU = JaccardIndex(num_classes=2)
IoU_value = 0
for image, mask in train_loader:
    image = image.to(device)
    mask = mask.to('cpu')
    pred = unet(image).cpu()
    pred = torch.relu(torch.sign(pred - threshold)) # Taking 0.4 as the threshold to make the value 1
    IoU_value += IoU(pred, torch.round(mask).type(torch.int16)).item()
print(f'Intersection Over Union value = {IoU_value/len(train_loader)}')
# Out:
# Intersection Over Union value = 0.6010907478630543

# %%
image, mask = next(iter(val_loader))
image = image.to(device)
mask = mask.to('cpu')
pred = unet(image).cpu()
pred1 = torch.relu(torch.sign(pred - threshold))
image = image.to('cpu')
image_show(image[0], mask[0], pred1[0])

# %%
IoU = JaccardIndex(num_classes=2)
IoU_value = 0
for image, mask in val_loader:
    image = image.to(device)
    mask = mask.to('cpu')
    pred = unet(image).cpu()
    pred = torch.relu(torch.sign(pred - 0.4))
    IoU_value += IoU(pred, torch.round(mask).type(torch.int16)).item()
print(f'Intersection Over Union value = {IoU_value/len(val_loader)}')
# Out:
# Intersection Over Union value = 0.5906559079885483

# %%
IoU_value = IoU_value/len(val_loader)
dice_score = 2*IoU_value/(1+IoU_value)
print('Dice Score =',dice_score)
# Out:
# Dice Score = 0.7426570448356209

# %%
# torch.save(unet, '../models/U-Net_Image_Segmentation_IE643_Dense_20_epochs.pt')

# %%
unet = torch.load('../models/U-Net_Image_Segmentation_IE643_Dense_20_epochs.pt')
unet.eval()
# Out:
# UNet(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (denseBlock1): DenseBlock(
#     (convFinal): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (denseBlock2): DenseBlock(
#     (convFinal): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (denseBlock3): DenseBlock(
#     (convFinal): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv4): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (norm4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (denseBlock4): DenseBlock(
#     (convFinal): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (convT1): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2))
#   (denseBlock5): DenseBlock(
#     (convFinal): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (convT2): ConvTranspose2d(512, 128, kernel_size=(2, 2), stride=(2, 2))
#   (denseBlock6): DenseBlock(
#     (convFinal): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (convT3): ConvTranspose2d(256, 64, kernel_size=(2, 2), stride=(2, 2))
#   (denseBlock7): DenseBlock(
#     (convFinal): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#     (normFinal): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv71): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#   (norm71): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv72): Conv2d(64, 16, kernel_size=(5, 5), stride=(1, 1), padding=same)
#   (norm72): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv73): Conv2d(16, 1, kernel_size=(7, 7), stride=(1, 1), padding=same)
#   (norm73): BatchNorm2d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
def binaryJaccardIndex(preds, masks):
    intersection = 0
    union = 0
    for pred, mask in zip(preds, masks):
        for pred_row, mask_row in zip(pred[0],mask[0]):
            for i,j in zip(pred_row, mask_row):
                if i==1 or j==1:
                    union+=1
                if i==1 and j==1:
                    intersection+=1
    return(intersection/union)

# %%
threshold = 0.4

# %%
image, mask = next(iter(val_loader))
image = image.to(device)
mask = mask.to('cpu')
pred = unet(image).cpu()
pred1 = torch.relu(torch.sign(pred - threshold))
image = image.to('cpu')
image_show(image[0], mask[0], pred1[0])

# %%
binaryJaccardIndex(pred1, torch.round(mask).type(torch.int16))
# Out:
# 0.33456579969520867

# %%
IoU_value = 0
for image, mask in val_loader:
    image = image.to(device)
    mask = mask.to('cpu')
    pred = unet(image).cpu()
    pred = torch.relu(torch.sign(pred - 0.4))
    IoU_value += binaryJaccardIndex(pred, torch.round(mask).type(torch.int16))
print(f'Intersection Over Union value = {IoU_value/len(val_loader)}')
# Out:
# Intersection Over Union value = 0.3247543194224404

# %%
dice_score = 2*0.3247543194224404/(1+0.3247543194224404)
dice_score
# Out:
# 0.4902861076369618
